# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
pd.read_csv("billwerder_schadstoffe_2012-2023.csv")
# Out:
#       Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0              0  02.01.2012               11.0                    11.0
# 1              1  03.01.2012               10.0                     5.0
# 2              2  04.01.2012               11.0                     9.0
# 3              3  05.01.2012               12.0                     5.0
# 4              4  06.01.2012               11.0                     3.0
# ...          ...         ...                ...                     ...
# 4132        4368  27.04.2023               14.0                     3.0
# 4133        4369  28.04.2023               20.0                     3.0
# 4134        4370  29.04.2023               14.0                     3.0
# 4135        4371  30.04.2023               16.0                     3.0
# 4136        4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# ...

# %%
pd.read_csv("billwerder_schadstoffe_2012-2023.csv")
# Out:
#       Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0              0  02.01.2012               11.0                    11.0
# 1              1  03.01.2012               10.0                     5.0
# 2              2  04.01.2012               11.0                     9.0
# 3              3  05.01.2012               12.0                     5.0
# 4              4  06.01.2012               11.0                     3.0
# ...          ...         ...                ...                     ...
# 4132        4368  27.04.2023               14.0                     3.0
# 4133        4369  28.04.2023               20.0                     3.0
# 4134        4370  29.04.2023               14.0                     3.0
# 4135        4371  30.04.2023               16.0                     3.0
# 4136        4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# ...

# %%
df=pd.read_csv("billwerder_schadstoffe_2012-2023.csv")

# %%
df
# Out:
#       Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0              0  02.01.2012               11.0                    11.0
# 1              1  03.01.2012               10.0                     5.0
# 2              2  04.01.2012               11.0                     9.0
# 3              3  05.01.2012               12.0                     5.0
# 4              4  06.01.2012               11.0                     3.0
# ...          ...         ...                ...                     ...
# 4132        4368  27.04.2023               14.0                     3.0
# 4133        4369  28.04.2023               20.0                     3.0
# 4134        4370  29.04.2023               14.0                     3.0
# 4135        4371  30.04.2023               16.0                     3.0
# 4136        4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Messzeit', 'Feinstaub (µg/m3)', 'Schwefeldioxid (µg/m3)',
#        'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0           0  02.01.2012               11.0                    11.0
# 1           1  03.01.2012               10.0                     5.0
# 2           2  04.01.2012               11.0                     9.0
# 3           3  05.01.2012               12.0                     5.0
# 4           4  06.01.2012               11.0                     3.0
#
#    Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# 0                      26.0                        5.0
# 1                      16.0                        4.0
# 2                      22.0                        5.0
# 3                      17.0                        5.0
# 4                      30.0                        7.0

# %%
df.tail(6)
# Out:
#       Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 4131        4367  26.04.2023               11.0                     3.0
# 4132        4368  27.04.2023               14.0                     3.0
# 4133        4369  28.04.2023               20.0                     3.0
# 4134        4370  29.04.2023               14.0                     3.0
# 4135        4371  30.04.2023               16.0                     3.0
# 4136        4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# 4131                      18.0                        3.0
# 4132                      25.0                        4.0
# 4133                      17.0                        2.0
# 4134                       7.0                        2.0
# 4135                      13.0                        2.0
# 4136                       8.0                        2.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4137, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Messzeit', 'Feinstaub (µg/m3)', 'Schwefeldioxid (µg/m3)',
#        'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)'],
#       dtype='object')

# %%
df.to_numpy()
# Out:
# array([[0, '02.01.2012', 11.0, 11.0, 26.0, 5.0],
#        [1, '03.01.2012', 10.0, 5.0, 16.0, 4.0],
#        [2, '04.01.2012', 11.0, 9.0, 22.0, 5.0],
#        ...,
#        [4370, '29.04.2023', 14.0, 3.0, 7.0, 2.0],
#        [4371, '30.04.2023', 16.0, 3.0, 13.0, 2.0],
#        [4372, '01.05.2023', 13.0, 3.0, 8.0, 2.0]], dtype=object)

# %%
df.describe()
# Out:
#         Unnamed: 0  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# count  4137.000000        3919.000000             4072.000000
# mean   2076.182741          17.201582                4.138752
# std    1207.361717          10.021528                2.372911
# min       0.000000           2.000000                3.000000
# 25%    1035.000000          11.000000                3.000000
# 50%    2069.000000          15.000000                3.000000
# 75%    3103.000000          21.000000                4.000000
# max    4372.000000         130.000000               35.000000
#
#        Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# count               4075.000000                4073.000000
# mean                  22.623804                   8.028235
# std                   10.447713                  12.623669
# min                    2.000000                   2.000000
# 25%                   15.000000                   2.000000
# ...

# %%
df.T
# Out:
#                                  0           1           2           3     \
# Unnamed: 0                          0           1           2           3
# Messzeit                   02.01.2012  03.01.2012  04.01.2012  05.01.2012
# Feinstaub (µg/m3)                11.0        10.0        11.0        12.0
# Schwefeldioxid (µg/m3)           11.0         5.0         9.0         5.0
# Stickstoffdioxid (µg/m3)         26.0        16.0        22.0        17.0
# Stickstoffmonoxid (µg/m3)         5.0         4.0         5.0         5.0
#
#                                  4           5           6           7     \
# Unnamed: 0                          4           5           6           7
# Messzeit                   06.01.2012  07.01.2012  08.01.2012  09.01.2012
# Feinstaub (µg/m3)                11.0        14.0        13.0        13.0
# Schwefeldioxid (µg/m3)            3.0        10.0         3.0         3.0
# Stickstoffdioxid (µg/m3)         30.0        18.0        15.0        35.0
# ...

# %%
df["Feinstaub (µg/m3)"]
# Out:
# 0       11.0
# 1       10.0
# 2       11.0
# 3       12.0
# 4       11.0
#         ...
# 4132    14.0
# 4133    20.0
# 4134    14.0
# 4135    16.0
# 4136    13.0
# Name: Feinstaub (µg/m3), Length: 4137, dtype: float64

# %%
df[40:50]
# Out:
#     Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 40          40  11.02.2012               20.0                     3.0
# 41          41  12.02.2012               40.0                    11.0
# 42          42  13.02.2012               34.0                     7.0
# 43          43  14.02.2012               31.0                     3.0
# 44          44  15.02.2012               29.0                     3.0
# 45          45  16.02.2012               31.0                     9.0
# 46          46  17.02.2012               24.0                     3.0
# 47          47  18.02.2012               32.0                     3.0
# 48          48  19.02.2012                NaN                     6.0
# 49          49  20.02.2012                NaN                     6.0
#
#     Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# 40                      20.0                        2.0
# 41                      34.0                        5.0
# ...

# %%
df.loc[3333]
# Out:
# Unnamed: 0                         3334
# Messzeit                     17.02.2021
# Feinstaub (µg/m3)                  18.0
# Schwefeldioxid (µg/m3)              5.0
# Stickstoffdioxid (µg/m3)           34.0
# Stickstoffmonoxid (µg/m3)           7.0
# Name: 3333, dtype: object

# %%
df.loc[:, ["Feinstaub (µg/m3)", "Schwefeldioxid (µg/m3)"]]
# Out:
#       Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)
# 0                  11.0                    11.0
# 1                  10.0                     5.0
# 2                  11.0                     9.0
# 3                  12.0                     5.0
# 4                  11.0                     3.0
# ...                 ...                     ...
# 4132               14.0                     3.0
# 4133               20.0                     3.0
# 4134               14.0                     3.0
# 4135               16.0                     3.0
# 4136               13.0                     3.0
#
# [4137 rows x 2 columns]

# %%
df[df["Feinstaub (µg/m3)"] > 0]
# Out:
#       Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0              0  02.01.2012               11.0                    11.0
# 1              1  03.01.2012               10.0                     5.0
# 2              2  04.01.2012               11.0                     9.0
# 3              3  05.01.2012               12.0                     5.0
# 4              4  06.01.2012               11.0                     3.0
# ...          ...         ...                ...                     ...
# 4132        4368  27.04.2023               14.0                     3.0
# 4133        4369  28.04.2023               20.0                     3.0
# 4134        4370  29.04.2023               14.0                     3.0
# 4135        4371  30.04.2023               16.0                     3.0
# 4136        4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# ...

# %%
df.mean()
# Out:
# C:\Users\Praktikant\AppData\Local\Temp\ipykernel_16064\972437606.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Unnamed: 0                   2076.182741
# Feinstaub (µg/m3)              17.201582
# Schwefeldioxid (µg/m3)          4.138752
# Stickstoffdioxid (µg/m3)       22.623804
# Stickstoffmonoxid (µg/m3)       8.028235
# dtype: float64

# %%
df['Feinstaub (µg/m3)'].plot()
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#       Unnamed: 0    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0              0  02.01.2012               11.0                    11.0
# 1              1  03.01.2012               10.0                     5.0
# 2              2  04.01.2012               11.0                     9.0
# 3              3  05.01.2012               12.0                     5.0
# 4              4  06.01.2012               11.0                     3.0
# ...          ...         ...                ...                     ...
# 4132        4368  27.04.2023               14.0                     3.0
# 4133        4369  28.04.2023               20.0                     3.0
# 4134        4370  29.04.2023               14.0                     3.0
# 4135        4371  30.04.2023               16.0                     3.0
# 4136        4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)
# ...

# %%
import seaborn as sns

# %%
sns.lineplot(data=df, x="Messzeit", y="Feinstaub (µg/m3)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='Feinstaub (µg/m3)'>

# %%
sns.lineplot(data=df, x="Messzeit", y="Schwefeldioxid (µg/m3)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='Schwefeldioxid (µg/m3)'>

# %%
sns.lineplot(data=df, x="Messzeit", y="Stickstoffdioxid (µg/m3)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='Stickstoffdioxid (µg/m3)'>

# %%
sns.lineplot(data=df, x="Messzeit", y="Stickstoffmonoxid (µg/m3)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='Stickstoffmonoxid (µg/m3)'>

# %%
df2=pd.read_csv("billwerder_wetter_2012-2023.csv")

# %%
df2
# Out:
#       Unnamed: 0    Messzeit  Temperatur (°C)  rel. Luftfeuchte (%)  \
# 0              0  02.01.2012              8.2                  86.4
# 1              1  03.01.2012              5.6                  84.3
# 2              2  04.01.2012              5.3                  79.4
# 3              3  05.01.2012              5.8                  82.3
# 4              4  06.01.2012              3.9                  79.0
# ...          ...         ...              ...                   ...
# 4132        4368  27.04.2023              7.6                  67.2
# 4133        4369  28.04.2023              9.7                  69.3
# 4134        4370  29.04.2023             10.3                  69.7
# 4135        4371  30.04.2023              9.8                  54.0
# 4136        4372  01.05.2023             12.8                  53.6
#
#       Windgeschwindigkeit (m/s)  Windrichtung (°)  Luftdruck (hPa)
# 0                           3.1             243.0           1003.5
# ...

# %%
sns.lineplot(data=df2, x="Messzeit", y="Temperatur (°C)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='Temperatur (°C)'>

# %%
sns.lineplot(data=df2, x="Messzeit", y="rel. Luftfeuchte (%)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='rel. Luftfeuchte (%)'>

# %%
sns.lineplot(data=df2, x="Messzeit", y="Windgeschwindigkeit (m/s)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='Windgeschwindigkeit (m/s)'>
# Error in callback <function _draw_all_if_interactive at 0x0000016F877759E0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\envs\praktikum\Lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~\anaconda3\envs\praktikum\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\envs\praktikum\Lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
# ...

# %%
sns.lineplot(data=df2, x="Messzeit", y="Windrichtung (°)")
# Out:
# <Axes: xlabel='Messzeit', ylabel='Windrichtung (°)'>

# %%
sns.lineplot(data=df2, x="Messzeit", y="Luftdruck (hPa)")

# %%
sns.lineplot(data=df2, x="Messzeit", y="Luftdruck (hPa)")
plt.xlim("02.01.2012", "31.12.2012")

# %%
sns.lineplot(data=df2, x="Messzeit", y="Luftdruck (hPa)")
plt.xlim("02.01.2012", "09.01.2012")
