# %%
import pandas as pd 
df1=pd.read_csv("billwerder_schadstoffe_2012-2023.csv")
df2=pd.read_csv("billwerder_wetter_2012-2023.csv")

# %%
df=pd.merge(df1, df2, on="Messzeit")

# %%
df
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0                0  02.01.2012               11.0                    11.0
# 1                1  03.01.2012               10.0                     5.0
# 2                2  04.01.2012               11.0                     9.0
# 3                3  05.01.2012               12.0                     5.0
# 4                4  06.01.2012               11.0                     3.0
# ...            ...         ...                ...                     ...
# 4132          4368  27.04.2023               14.0                     3.0
# 4133          4369  28.04.2023               20.0                     3.0
# 4134          4370  29.04.2023               14.0                     3.0
# 4135          4371  30.04.2023               16.0                     3.0
# 4136          4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 0                         26.0                        5.0             0
# 1                         16.0                        4.0             1
# 2                         22.0                        5.0             2
# 3                         17.0                        5.0             3
# 4                         30.0                        7.0             4
# ...                        ...                        ...           ...
# 4132                      25.0                        4.0          4368
# 4133                      17.0                        2.0          4369
# 4134                       7.0                        2.0          4370
# 4135                      13.0                        2.0          4371
# 4136                       8.0                        2.0          4372
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 0                 8.2                  86.4                        3.1
# 1                 5.6                  84.3                        5.2
# 2                 5.3                  79.4                        5.2
# 3                 5.8                  82.3                        5.3
# 4                 3.9                  79.0                        3.3
# ...               ...                   ...                        ...
# 4132              7.6                  67.2                        1.8
# 4133              9.7                  69.3                        2.4
# 4134             10.3                  69.7                        3.5
# 4135              9.8                  54.0                        1.8
# 4136             12.8                  53.6                        1.9
#
#       Windrichtung (°)  Luftdruck (hPa)
# 0                243.0           1003.5
# 1                211.0           1002.5
# 2                243.0           1001.0
# 3                272.0            980.3
# 4                301.0           1006.5
# ...                ...              ...
# 4132             278.0           1019.2
# 4133             102.0           1013.1
# 4134             322.0           1015.8
# 4135             305.0           1022.5
# 4136             229.0           1015.3
#
# [4137 rows x 12 columns]

# %%
df.loc[df['Messzeit'] == "01.01.2020"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2920          2921  01.01.2020               57.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2920                      34.0                        7.0          2921
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2920             200.0           1031.4

# %%
df_train = df.iloc[:2920,:]
df_test = df.iloc[2920:,:]

# %%
df_train = df_train.dropna()
df_test = df_test.dropna()

# %%
df_test
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2920          2921  01.01.2020               57.0                     3.0
# 2921          2922  02.01.2020               27.0                     4.0
# 2922          2923  03.01.2020               10.0                     5.0
# 2923          2924  04.01.2020               15.0                     4.0
# 2924          2925  05.01.2020               18.0                     5.0
# ...            ...         ...                ...                     ...
# 4132          4368  27.04.2023               14.0                     3.0
# 4133          4369  28.04.2023               20.0                     3.0
# 4134          4370  29.04.2023               14.0                     3.0
# 4135          4371  30.04.2023               16.0                     3.0
# 4136          4372  01.05.2023               13.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2920                      34.0                        7.0          2921
# 2921                      30.0                       15.0          2922
# 2922                      19.0                        2.0          2923
# 2923                      17.0                        2.0          2924
# 2924                      27.0                        2.0          2925
# ...                        ...                        ...           ...
# 4132                      25.0                        4.0          4368
# 4133                      17.0                        2.0          4369
# 4134                       7.0                        2.0          4370
# 4135                      13.0                        2.0          4371
# 4136                       8.0                        2.0          4372
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
# 2921             -0.6                  98.5                        1.9
# 2922              5.9                  94.0                        3.3
# 2923              4.7                  83.8                        3.2
# 2924              4.1                  85.2                        2.0
# ...               ...                   ...                        ...
# 4132              7.6                  67.2                        1.8
# 4133              9.7                  69.3                        2.4
# 4134             10.3                  69.7                        3.5
# 4135              9.8                  54.0                        1.8
# 4136             12.8                  53.6                        1.9
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2920             200.0           1031.4
# 2921             210.0           1024.0
# 2922             231.0           1013.9
# 2923             282.0           1020.7
# 2924             222.0           1030.3
# ...                ...              ...
# 4132             278.0           1019.2
# 4133             102.0           1013.1
# 4134             322.0           1015.8
# 4135             305.0           1022.5
# 4136             229.0           1015.3
#
# [1122 rows x 12 columns]

# %%
df_train
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 0                0  02.01.2012               11.0                    11.0
# 1                1  03.01.2012               10.0                     5.0
# 2                2  04.01.2012               11.0                     9.0
# 3                3  05.01.2012               12.0                     5.0
# 4                4  06.01.2012               11.0                     3.0
# ...            ...         ...                ...                     ...
# 2915          2916  27.12.2019                7.0                     3.0
# 2916          2917  28.12.2019               11.0                     3.0
# 2917          2918  29.12.2019               10.0                     3.0
# 2918          2919  30.12.2019               12.0                    20.0
# 2919          2920  31.12.2019               23.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 0                         26.0                        5.0             0
# 1                         16.0                        4.0             1
# 2                         22.0                        5.0             2
# 3                         17.0                        5.0             3
# 4                         30.0                        7.0             4
# ...                        ...                        ...           ...
# 2915                      27.0                        8.0          2916
# 2916                      32.0                       23.0          2917
# 2917                      22.0                        2.0          2918
# 2918                      29.0                        2.0          2919
# 2919                      29.0                        2.0          2920
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 0                 8.2                  86.4                        3.1
# 1                 5.6                  84.3                        5.2
# 2                 5.3                  79.4                        5.2
# 3                 5.8                  82.3                        5.3
# 4                 3.9                  79.0                        3.3
# ...               ...                   ...                        ...
# 2915              2.3                  87.3                        1.8
# 2916             -0.8                  91.1                        1.1
# 2917             -0.1                  80.0                        1.8
# 2918              7.4                  29.7                        2.5
# 2919              6.0                  83.9                        2.5
#
#       Windrichtung (°)  Luftdruck (hPa)
# 0                243.0           1003.5
# 1                211.0           1002.5
# 2                243.0           1001.0
# 3                272.0            980.3
# 4                301.0           1006.5
# ...                ...              ...
# 2915              41.0           1030.3
# 2916             148.0           1040.8
# 2917             181.0           1035.6
# 2918             236.0           1025.0
# 2919             288.0           1028.2
#
# [2729 rows x 12 columns]

# %%
x_train = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_train = df_train['Schwefeldioxid (µg/m3)']
x_test = df_test.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_test = df_test['Schwefeldioxid (µg/m3)']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf_regressor.predict(x_test)

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 1.8220059071931416

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('y-test')
plt.ylabel('y-pred')
ax=plt.gca()
ax.set_aspect("equal")

# %%
plt.plot(df_test['Messzeit'], y_test, label='test')
plt.plot(df_test['Messzeit'], y_pred, label='pred')
plt.xlabel('Messzeit')
plt.ylabel('Werte')
plt.legend()

# %%
plt.plot(df_test['Messzeit'], y_pred-y_test)
plt.xlabel('Messzeit')
plt.ylabel('Differenz')
# Out:
# Text(0, 0.5, 'Differenz')

# %%
df_train.corr()
# Out:
# C:\Users\Praktikant\AppData\Local\Temp\ipykernel_16956\299540020.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_train.corr()
#                            Unnamed: 0_x  Feinstaub (µg/m3)  \
# Unnamed: 0_x                   1.000000          -0.046738
# Feinstaub (µg/m3)             -0.046738           1.000000
# Schwefeldioxid (µg/m3)        -0.023380          -0.070085
# Stickstoffdioxid (µg/m3)      -0.108970           0.289336
# Stickstoffmonoxid (µg/m3)     -0.083358           0.269112
# Unnamed: 0_y                   1.000000          -0.046738
# Temperatur (°C)                0.099698          -0.058310
# rel. Luftfeuchte (%)          -0.017380          -0.016331
# Windgeschwindigkeit (m/s)     -0.010647          -0.230327
# Windrichtung (°)               0.026875          -0.184500
# Luftdruck (hPa)                0.004549           0.175175
#
#                            Schwefeldioxid (µg/m3)  Stickstoffdioxid (µg/m3)  \
# Unnamed: 0_x                            -0.023380                 -0.108970
# Feinstaub (µg/m3)                       -0.070085                  0.289336
# Schwefeldioxid (µg/m3)                   1.000000                  0.160367
# Stickstoffdioxid (µg/m3)                 0.160367                  1.000000
# Stickstoffmonoxid (µg/m3)                0.036296                  0.663529
# Unnamed: 0_y                            -0.023380                 -0.108970
# Temperatur (°C)                         -0.109027                 -0.328988
# rel. Luftfeuchte (%)                     0.113244                  0.259113
# Windgeschwindigkeit (m/s)                0.181092                 -0.430288
# Windrichtung (°)                         0.217802                  0.125581
# Luftdruck (hPa)                         -0.093780                  0.154334
#
#                            Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# Unnamed: 0_x                               -0.083358      1.000000
# Feinstaub (µg/m3)                           0.269112     -0.046738
# Schwefeldioxid (µg/m3)                      0.036296     -0.023380
# Stickstoffdioxid (µg/m3)                    0.663529     -0.108970
# Stickstoffmonoxid (µg/m3)                   1.000000     -0.083358
# Unnamed: 0_y                               -0.083358      1.000000
# Temperatur (°C)                            -0.222197      0.099698
# rel. Luftfeuchte (%)                        0.177838     -0.017380
# Windgeschwindigkeit (m/s)                  -0.369227     -0.010647
# Windrichtung (°)                            0.006682      0.026875
# Luftdruck (hPa)                             0.172436      0.004549
#
#                            Temperatur (°C)  rel. Luftfeuchte (%)  \
# Unnamed: 0_x                      0.099698             -0.017380
# Feinstaub (µg/m3)                -0.058310             -0.016331
# Schwefeldioxid (µg/m3)           -0.109027              0.113244
# Stickstoffdioxid (µg/m3)         -0.328988              0.259113
# Stickstoffmonoxid (µg/m3)        -0.222197              0.177838
# Unnamed: 0_y                      0.099698             -0.017380
# Temperatur (°C)                   1.000000             -0.495292
# rel. Luftfeuchte (%)             -0.495292              1.000000
# Windgeschwindigkeit (m/s)        -0.226695             -0.044075
# Windrichtung (°)                  0.061739              0.057166
# Luftdruck (hPa)                   0.009405             -0.206299
#
#                            Windgeschwindigkeit (m/s)  Windrichtung (°)  \
# Unnamed: 0_x                               -0.010647          0.026875
# Feinstaub (µg/m3)                          -0.230327         -0.184500
# Schwefeldioxid (µg/m3)                      0.181092          0.217802
# Stickstoffdioxid (µg/m3)                   -0.430288          0.125581
# Stickstoffmonoxid (µg/m3)                  -0.369227          0.006682
# Unnamed: 0_y                               -0.010647          0.026875
# Temperatur (°C)                            -0.226695          0.061739
# rel. Luftfeuchte (%)                       -0.044075          0.057166
# Windgeschwindigkeit (m/s)                   1.000000          0.027521
# Windrichtung (°)                            0.027521          1.000000
# Luftdruck (hPa)                            -0.209614         -0.045483
#
#                            Luftdruck (hPa)
# Unnamed: 0_x                      0.004549
# Feinstaub (µg/m3)                 0.175175
# Schwefeldioxid (µg/m3)           -0.093780
# Stickstoffdioxid (µg/m3)          0.154334
# Stickstoffmonoxid (µg/m3)         0.172436
# Unnamed: 0_y                      0.004549
# Temperatur (°C)                   0.009405
# rel. Luftfeuchte (%)             -0.206299
# Windgeschwindigkeit (m/s)        -0.209614
# Windrichtung (°)                 -0.045483
# Luftdruck (hPa)                   1.000000
