# %%
import pandas as pd 
df1=pd.read_csv("billwerder_schadstoffe_2012-2023.csv")
df2=pd.read_csv("billwerder_wetter_2012-2023.csv")
df=pd.merge(df1, df2, on="Messzeit")
rolling_mean = df['Feinstaub (µg/m3)'].rolling(window=7, min_periods=1).mean()
df['Feinstaub Mittelwert'] = rolling_mean
df.loc[df['Messzeit'] == "01.01.2019"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
#
#       Windrichtung (°)  Luftdruck (hPa)  Feinstaub Mittelwert
# 2555             292.0           1018.3                  19.0

# %%
df.loc[df['Messzeit'] == "01.01.2020"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2920          2921  01.01.2020               57.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2920                      34.0                        7.0          2921
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
#
#       Windrichtung (°)  Luftdruck (hPa)  Feinstaub Mittelwert
# 2920             200.0           1031.4             18.428571

# %%
df_train = df.iloc[:2555,:]
df_val = df.iloc[2555:2920,:]
df_test = df.iloc[2920:,:]

# %%
df_val
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
# 2556          2557  02.01.2019               11.0                     3.0
# 2557          2558  03.01.2019               17.0                     4.0
# 2558          2559  04.01.2019               10.0                     3.0
# 2559          2560  05.01.2019               13.0                     3.0
# ...            ...         ...                ...                     ...
# 2915          2916  27.12.2019                7.0                     3.0
# 2916          2917  28.12.2019               11.0                     3.0
# 2917          2918  29.12.2019               10.0                     3.0
# 2918          2919  30.12.2019               12.0                    20.0
# 2919          2920  31.12.2019               23.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
# 2556                      18.0                        2.0          2557
# 2557                      56.0                       42.0          2558
# 2558                      34.0                        5.0          2559
# 2559                      19.0                        2.0          2560
# ...                        ...                        ...           ...
# 2915                      27.0                        8.0          2916
# 2916                      32.0                       23.0          2917
# 2917                      22.0                        2.0          2918
# 2918                      29.0                        2.0          2919
# 2919                      29.0                        2.0          2920
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
# 2556              3.4                  55.8                        4.6
# 2557              0.7                  78.9                        1.7
# 2558              4.3                  94.9                        3.1
# 2559              7.3                  95.5                        3.2
# ...               ...                   ...                        ...
# 2915              2.3                  87.3                        1.8
# 2916             -0.8                  91.1                        1.1
# 2917             -0.1                  80.0                        1.8
# 2918              7.4                  29.7                        2.5
# 2919              6.0                  83.9                        2.5
#
#       Windrichtung (°)  Luftdruck (hPa)  Feinstaub Mittelwert
# 2555             292.0           1018.3             19.000000
# 2556             324.0           1028.5             18.285714
# 2557             304.0           1034.7             17.142857
# 2558             294.0           1028.3             15.571429
# 2559             313.0           1022.1             14.428571
# ...                ...              ...                   ...
# 2915              41.0           1030.3              9.571429
# 2916             148.0           1040.8             10.000000
# 2917             181.0           1035.6              9.714286
# 2918             236.0           1025.0             10.000000
# 2919             288.0           1028.2             11.571429
#
# [365 rows x 13 columns]

# %%
df_train = df_train.dropna()
df_val = df_val.dropna()
df_test = df_test.dropna()

# %%
x_train = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_train = df_train['Feinstaub (µg/m3)']
x_val = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_val = df_train['Feinstaub (µg/m3)']
x_test = df_test.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_test = df_test['Feinstaub (µg/m3)']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_history(metrics):
    history_df = pd.DataFrame.from_dict(history.history)
    sns.lineplot(data=history_df[metrics])
    plt.xlabel("epochs")
    plt.ylabel("RMSE")

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlystopper = EarlyStopping(
    monitor='val_loss',
    patience=10
    )

# %%
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization

def create_nn():
    inputs = keras.layers.Input(shape=(x_train.shape[1],), name='input')

    layers_dense = keras.layers.BatchNormalization()(inputs)
    layers_dense = keras.layers.Dense(100, 'relu')(layers_dense)
    layers_dense = keras.layers.Dense(50, 'relu')(layers_dense)

    outputs = keras.layers.Dense(1)(layers_dense)

    return keras.Model(inputs=inputs, outputs=outputs, name="model_batchnorm")

model = create_nn()

# %%
def compile_model(model):
    model.compile(optimizer='adam',
                  loss='mse',
                  metrics=[keras.metrics.RootMeanSquaredError()])
compile_model(model)

# %%
compile_model(model)
model.summary()
# Out:
# Model: "model_batchnorm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 6)]               0
#
#  batch_normalization (BatchN  (None, 6)                24
#  ormalization)
#
#  dense (Dense)               (None, 100)               700
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 5,825
# Trainable params: 5,813
# Non-trainable params: 12
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,
                    batch_size = 32,
                    epochs = 1000,
                    validation_data=(x_val, y_val),
                    callbacks=[earlystopper],
                    verbose = 2)
# Out:
# Epoch 1/1000
# 75/75 - 2s - loss: 322.7697 - root_mean_squared_error: 17.9658 - val_loss: 105851.3906 - val_root_mean_squared_error: 325.3481 - 2s/epoch - 25ms/step
# Epoch 2/1000
# 75/75 - 0s - loss: 91.2843 - root_mean_squared_error: 9.5543 - val_loss: 23518.7344 - val_root_mean_squared_error: 153.3582 - 276ms/epoch - 4ms/step
# Epoch 3/1000
# 75/75 - 0s - loss: 78.8365 - root_mean_squared_error: 8.8790 - val_loss: 3130.1250 - val_root_mean_squared_error: 55.9475 - 299ms/epoch - 4ms/step
# Epoch 4/1000
# 75/75 - 0s - loss: 76.0851 - root_mean_squared_error: 8.7227 - val_loss: 507.5266 - val_root_mean_squared_error: 22.5284 - 232ms/epoch - 3ms/step
# Epoch 5/1000
# 75/75 - 0s - loss: 75.5225 - root_mean_squared_error: 8.6904 - val_loss: 112.1117 - val_root_mean_squared_error: 10.5883 - 209ms/epoch - 3ms/step
# Epoch 6/1000
# 75/75 - 0s - loss: 73.9387 - root_mean_squared_error: 8.5988 - val_loss: 76.0044 - val_root_mean_squared_error: 8.7181 - 253ms/epoch - 3ms/step
# Epoch 7/1000
# 75/75 - 0s - loss: 75.7667 - root_mean_squared_error: 8.7044 - val_loss: 70.6557 - val_root_mean_squared_error: 8.4057 - 203ms/epoch - 3ms/step
# Epoch 8/1000
# 75/75 - 0s - loss: 74.6768 - root_mean_squared_error: 8.6416 - val_loss: 69.3089 - val_root_mean_squared_error: 8.3252 - 208ms/epoch - 3ms/step
# Epoch 9/1000
# 75/75 - 0s - loss: 72.0562 - root_mean_squared_error: 8.4886 - val_loss: 69.0884 - val_root_mean_squared_error: 8.3119 - 248ms/epoch - 3ms/step
# Epoch 10/1000
# 75/75 - 0s - loss: 73.5474 - root_mean_squared_error: 8.5760 - val_loss: 68.2063 - val_root_mean_squared_error: 8.2587 - 218ms/epoch - 3ms/step
# Epoch 11/1000
# 75/75 - 0s - loss: 71.4322 - root_mean_squared_error: 8.4518 - val_loss: 67.8867 - val_root_mean_squared_error: 8.2393 - 218ms/epoch - 3ms/step
# Epoch 12/1000
# 75/75 - 0s - loss: 69.6062 - root_mean_squared_error: 8.3430 - val_loss: 67.3419 - val_root_mean_squared_error: 8.2062 - 293ms/epoch - 4ms/step
# Epoch 13/1000
# 75/75 - 0s - loss: 69.2098 - root_mean_squared_error: 8.3192 - val_loss: 66.9892 - val_root_mean_squared_error: 8.1847 - 195ms/epoch - 3ms/step
# Epoch 14/1000
# 75/75 - 0s - loss: 70.2864 - root_mean_squared_error: 8.3837 - val_loss: 67.0197 - val_root_mean_squared_error: 8.1866 - 236ms/epoch - 3ms/step
# Epoch 15/1000
# 75/75 - 0s - loss: 68.5035 - root_mean_squared_error: 8.2767 - val_loss: 66.8489 - val_root_mean_squared_error: 8.1761 - 194ms/epoch - 3ms/step
# Epoch 16/1000
# 75/75 - 0s - loss: 68.9126 - root_mean_squared_error: 8.3014 - val_loss: 66.3736 - val_root_mean_squared_error: 8.1470 - 200ms/epoch - 3ms/step
# Epoch 17/1000
# 75/75 - 0s - loss: 69.6418 - root_mean_squared_error: 8.3452 - val_loss: 65.5333 - val_root_mean_squared_error: 8.0953 - 187ms/epoch - 2ms/step
# Epoch 18/1000
# 75/75 - 0s - loss: 67.5253 - root_mean_squared_error: 8.2174 - val_loss: 65.0711 - val_root_mean_squared_error: 8.0667 - 197ms/epoch - 3ms/step
# Epoch 19/1000
# 75/75 - 0s - loss: 66.8353 - root_mean_squared_error: 8.1753 - val_loss: 66.1157 - val_root_mean_squared_error: 8.1312 - 200ms/epoch - 3ms/step
# Epoch 20/1000
# 75/75 - 0s - loss: 68.0695 - root_mean_squared_error: 8.2504 - val_loss: 64.4155 - val_root_mean_squared_error: 8.0259 - 183ms/epoch - 2ms/step
# Epoch 21/1000
# 75/75 - 0s - loss: 68.0727 - root_mean_squared_error: 8.2506 - val_loss: 64.2234 - val_root_mean_squared_error: 8.0140 - 227ms/epoch - 3ms/step
# Epoch 22/1000
# 75/75 - 0s - loss: 68.2927 - root_mean_squared_error: 8.2639 - val_loss: 63.9535 - val_root_mean_squared_error: 7.9971 - 210ms/epoch - 3ms/step
# Epoch 23/1000
# 75/75 - 0s - loss: 67.0553 - root_mean_squared_error: 8.1887 - val_loss: 63.0525 - val_root_mean_squared_error: 7.9406 - 194ms/epoch - 3ms/step
# Epoch 24/1000
# 75/75 - 0s - loss: 66.0137 - root_mean_squared_error: 8.1249 - val_loss: 62.5059 - val_root_mean_squared_error: 7.9061 - 207ms/epoch - 3ms/step
# Epoch 25/1000
# 75/75 - 0s - loss: 67.4798 - root_mean_squared_error: 8.2146 - val_loss: 62.8543 - val_root_mean_squared_error: 7.9281 - 245ms/epoch - 3ms/step
# Epoch 26/1000
# 75/75 - 0s - loss: 66.6760 - root_mean_squared_error: 8.1655 - val_loss: 62.3605 - val_root_mean_squared_error: 7.8969 - 206ms/epoch - 3ms/step
# Epoch 27/1000
# 75/75 - 0s - loss: 65.5140 - root_mean_squared_error: 8.0941 - val_loss: 62.2833 - val_root_mean_squared_error: 7.8920 - 219ms/epoch - 3ms/step
# Epoch 28/1000
# 75/75 - 0s - loss: 66.4379 - root_mean_squared_error: 8.1509 - val_loss: 61.3780 - val_root_mean_squared_error: 7.8344 - 214ms/epoch - 3ms/step
# Epoch 29/1000
# 75/75 - 0s - loss: 64.8219 - root_mean_squared_error: 8.0512 - val_loss: 61.3766 - val_root_mean_squared_error: 7.8343 - 245ms/epoch - 3ms/step
# Epoch 30/1000
# 75/75 - 0s - loss: 66.1420 - root_mean_squared_error: 8.1328 - val_loss: 61.0012 - val_root_mean_squared_error: 7.8103 - 224ms/epoch - 3ms/step
# Epoch 31/1000
# 75/75 - 0s - loss: 64.2476 - root_mean_squared_error: 8.0155 - val_loss: 60.7525 - val_root_mean_squared_error: 7.7944 - 212ms/epoch - 3ms/step
# Epoch 32/1000
# 75/75 - 0s - loss: 63.8638 - root_mean_squared_error: 7.9915 - val_loss: 61.0799 - val_root_mean_squared_error: 7.8154 - 286ms/epoch - 4ms/step
# Epoch 33/1000
# 75/75 - 0s - loss: 65.7936 - root_mean_squared_error: 8.1113 - val_loss: 60.4099 - val_root_mean_squared_error: 7.7724 - 282ms/epoch - 4ms/step
# Epoch 34/1000
# 75/75 - 0s - loss: 65.4940 - root_mean_squared_error: 8.0928 - val_loss: 60.2940 - val_root_mean_squared_error: 7.7649 - 246ms/epoch - 3ms/step
# Epoch 35/1000
# 75/75 - 0s - loss: 64.1176 - root_mean_squared_error: 8.0073 - val_loss: 61.2575 - val_root_mean_squared_error: 7.8267 - 260ms/epoch - 3ms/step
# Epoch 36/1000
# 75/75 - 0s - loss: 63.9599 - root_mean_squared_error: 7.9975 - val_loss: 61.2003 - val_root_mean_squared_error: 7.8231 - 208ms/epoch - 3ms/step
# Epoch 37/1000
# 75/75 - 0s - loss: 64.0772 - root_mean_squared_error: 8.0048 - val_loss: 59.7879 - val_root_mean_squared_error: 7.7323 - 216ms/epoch - 3ms/step
# Epoch 38/1000
# 75/75 - 0s - loss: 64.9786 - root_mean_squared_error: 8.0609 - val_loss: 59.6681 - val_root_mean_squared_error: 7.7245 - 215ms/epoch - 3ms/step
# Epoch 39/1000
# 75/75 - 0s - loss: 63.6874 - root_mean_squared_error: 7.9804 - val_loss: 59.6081 - val_root_mean_squared_error: 7.7206 - 254ms/epoch - 3ms/step
# Epoch 40/1000
# 75/75 - 0s - loss: 63.9171 - root_mean_squared_error: 7.9948 - val_loss: 60.4225 - val_root_mean_squared_error: 7.7732 - 243ms/epoch - 3ms/step
# Epoch 41/1000
# 75/75 - 0s - loss: 64.7586 - root_mean_squared_error: 8.0473 - val_loss: 59.3720 - val_root_mean_squared_error: 7.7053 - 214ms/epoch - 3ms/step
# Epoch 42/1000
# 75/75 - 0s - loss: 64.7727 - root_mean_squared_error: 8.0481 - val_loss: 59.2870 - val_root_mean_squared_error: 7.6998 - 214ms/epoch - 3ms/step
# Epoch 43/1000
# 75/75 - 0s - loss: 63.4565 - root_mean_squared_error: 7.9660 - val_loss: 60.5256 - val_root_mean_squared_error: 7.7798 - 210ms/epoch - 3ms/step
# Epoch 44/1000
# 75/75 - 0s - loss: 65.1978 - root_mean_squared_error: 8.0745 - val_loss: 59.2381 - val_root_mean_squared_error: 7.6966 - 209ms/epoch - 3ms/step
# Epoch 45/1000
# 75/75 - 0s - loss: 62.3182 - root_mean_squared_error: 7.8942 - val_loss: 58.9950 - val_root_mean_squared_error: 7.6808 - 216ms/epoch - 3ms/step
# Epoch 46/1000
# 75/75 - 0s - loss: 62.9478 - root_mean_squared_error: 7.9340 - val_loss: 58.6209 - val_root_mean_squared_error: 7.6564 - 213ms/epoch - 3ms/step
# Epoch 47/1000
# 75/75 - 0s - loss: 63.6435 - root_mean_squared_error: 7.9777 - val_loss: 59.0858 - val_root_mean_squared_error: 7.6867 - 202ms/epoch - 3ms/step
# Epoch 48/1000
# 75/75 - 0s - loss: 63.5155 - root_mean_squared_error: 7.9697 - val_loss: 58.3797 - val_root_mean_squared_error: 7.6407 - 221ms/epoch - 3ms/step
# Epoch 49/1000
# 75/75 - 0s - loss: 62.4850 - root_mean_squared_error: 7.9047 - val_loss: 59.2762 - val_root_mean_squared_error: 7.6991 - 210ms/epoch - 3ms/step
# Epoch 50/1000
# 75/75 - 0s - loss: 63.4293 - root_mean_squared_error: 7.9643 - val_loss: 59.0940 - val_root_mean_squared_error: 7.6873 - 222ms/epoch - 3ms/step
# Epoch 51/1000
# 75/75 - 0s - loss: 63.3158 - root_mean_squared_error: 7.9571 - val_loss: 58.4354 - val_root_mean_squared_error: 7.6443 - 213ms/epoch - 3ms/step
# Epoch 52/1000
# 75/75 - 0s - loss: 61.8045 - root_mean_squared_error: 7.8616 - val_loss: 58.7691 - val_root_mean_squared_error: 7.6661 - 238ms/epoch - 3ms/step
# Epoch 53/1000
# 75/75 - 0s - loss: 62.2412 - root_mean_squared_error: 7.8893 - val_loss: 58.0792 - val_root_mean_squared_error: 7.6210 - 329ms/epoch - 4ms/step
# Epoch 54/1000
# 75/75 - 0s - loss: 62.5776 - root_mean_squared_error: 7.9106 - val_loss: 57.9123 - val_root_mean_squared_error: 7.6100 - 214ms/epoch - 3ms/step
# Epoch 55/1000
# 75/75 - 0s - loss: 63.1349 - root_mean_squared_error: 7.9457 - val_loss: 58.8166 - val_root_mean_squared_error: 7.6692 - 193ms/epoch - 3ms/step
# Epoch 56/1000
# 75/75 - 0s - loss: 63.0699 - root_mean_squared_error: 7.9417 - val_loss: 57.4765 - val_root_mean_squared_error: 7.5813 - 216ms/epoch - 3ms/step
# Epoch 57/1000
# 75/75 - 0s - loss: 63.6685 - root_mean_squared_error: 7.9793 - val_loss: 58.1563 - val_root_mean_squared_error: 7.6260 - 243ms/epoch - 3ms/step
# Epoch 58/1000
# 75/75 - 0s - loss: 62.1589 - root_mean_squared_error: 7.8841 - val_loss: 57.7500 - val_root_mean_squared_error: 7.5993 - 225ms/epoch - 3ms/step
# Epoch 59/1000
# 75/75 - 0s - loss: 62.6191 - root_mean_squared_error: 7.9132 - val_loss: 57.4934 - val_root_mean_squared_error: 7.5824 - 215ms/epoch - 3ms/step
# Epoch 60/1000
# 75/75 - 0s - loss: 63.2523 - root_mean_squared_error: 7.9531 - val_loss: 57.5388 - val_root_mean_squared_error: 7.5854 - 195ms/epoch - 3ms/step
# Epoch 61/1000
# 75/75 - 0s - loss: 59.9106 - root_mean_squared_error: 7.7402 - val_loss: 56.8450 - val_root_mean_squared_error: 7.5396 - 194ms/epoch - 3ms/step
# Epoch 62/1000
# 75/75 - 0s - loss: 61.3484 - root_mean_squared_error: 7.8325 - val_loss: 56.9132 - val_root_mean_squared_error: 7.5441 - 207ms/epoch - 3ms/step
# Epoch 63/1000
# 75/75 - 0s - loss: 61.2935 - root_mean_squared_error: 7.8290 - val_loss: 56.9002 - val_root_mean_squared_error: 7.5432 - 220ms/epoch - 3ms/step
# Epoch 64/1000
# 75/75 - 0s - loss: 62.0137 - root_mean_squared_error: 7.8749 - val_loss: 59.5744 - val_root_mean_squared_error: 7.7184 - 202ms/epoch - 3ms/step
# Epoch 65/1000
# 75/75 - 0s - loss: 61.3439 - root_mean_squared_error: 7.8322 - val_loss: 57.1239 - val_root_mean_squared_error: 7.5580 - 224ms/epoch - 3ms/step
# Epoch 66/1000
# 75/75 - 0s - loss: 64.1507 - root_mean_squared_error: 8.0094 - val_loss: 56.4388 - val_root_mean_squared_error: 7.5126 - 229ms/epoch - 3ms/step
# Epoch 67/1000
# 75/75 - 0s - loss: 62.2221 - root_mean_squared_error: 7.8881 - val_loss: 57.7504 - val_root_mean_squared_error: 7.5994 - 196ms/epoch - 3ms/step
# Epoch 68/1000
# 75/75 - 0s - loss: 64.5933 - root_mean_squared_error: 8.0370 - val_loss: 56.2952 - val_root_mean_squared_error: 7.5030 - 202ms/epoch - 3ms/step
# Epoch 69/1000
# 75/75 - 0s - loss: 61.4491 - root_mean_squared_error: 7.8389 - val_loss: 56.3615 - val_root_mean_squared_error: 7.5074 - 217ms/epoch - 3ms/step
# Epoch 70/1000
# 75/75 - 0s - loss: 63.9934 - root_mean_squared_error: 7.9996 - val_loss: 56.8599 - val_root_mean_squared_error: 7.5406 - 199ms/epoch - 3ms/step
# Epoch 71/1000
# 75/75 - 0s - loss: 61.1694 - root_mean_squared_error: 7.8211 - val_loss: 56.0039 - val_root_mean_squared_error: 7.4836 - 228ms/epoch - 3ms/step
# Epoch 72/1000
# 75/75 - 0s - loss: 60.5574 - root_mean_squared_error: 7.7819 - val_loss: 56.2813 - val_root_mean_squared_error: 7.5021 - 251ms/epoch - 3ms/step
# Epoch 73/1000
# 75/75 - 0s - loss: 63.6799 - root_mean_squared_error: 7.9800 - val_loss: 55.4398 - val_root_mean_squared_error: 7.4458 - 223ms/epoch - 3ms/step
# Epoch 74/1000
# 75/75 - 0s - loss: 60.3168 - root_mean_squared_error: 7.7664 - val_loss: 55.8814 - val_root_mean_squared_error: 7.4754 - 206ms/epoch - 3ms/step
# Epoch 75/1000
# 75/75 - 0s - loss: 60.6403 - root_mean_squared_error: 7.7872 - val_loss: 56.0504 - val_root_mean_squared_error: 7.4867 - 211ms/epoch - 3ms/step
# Epoch 76/1000
# 75/75 - 0s - loss: 61.3190 - root_mean_squared_error: 7.8306 - val_loss: 55.5258 - val_root_mean_squared_error: 7.4516 - 215ms/epoch - 3ms/step
# Epoch 77/1000
# 75/75 - 0s - loss: 60.7790 - root_mean_squared_error: 7.7961 - val_loss: 55.6466 - val_root_mean_squared_error: 7.4597 - 242ms/epoch - 3ms/step
# Epoch 78/1000
# 75/75 - 0s - loss: 60.3641 - root_mean_squared_error: 7.7694 - val_loss: 55.0395 - val_root_mean_squared_error: 7.4189 - 246ms/epoch - 3ms/step
# Epoch 79/1000
# 75/75 - 0s - loss: 61.6062 - root_mean_squared_error: 7.8490 - val_loss: 55.2100 - val_root_mean_squared_error: 7.4303 - 199ms/epoch - 3ms/step
# Epoch 80/1000
# 75/75 - 0s - loss: 60.2338 - root_mean_squared_error: 7.7610 - val_loss: 55.3001 - val_root_mean_squared_error: 7.4364 - 213ms/epoch - 3ms/step
# Epoch 81/1000
# 75/75 - 0s - loss: 61.3272 - root_mean_squared_error: 7.8312 - val_loss: 54.6198 - val_root_mean_squared_error: 7.3905 - 213ms/epoch - 3ms/step
# Epoch 82/1000
# 75/75 - 0s - loss: 60.0579 - root_mean_squared_error: 7.7497 - val_loss: 54.4241 - val_root_mean_squared_error: 7.3773 - 207ms/epoch - 3ms/step
# Epoch 83/1000
# 75/75 - 0s - loss: 60.7334 - root_mean_squared_error: 7.7932 - val_loss: 54.8502 - val_root_mean_squared_error: 7.4061 - 194ms/epoch - 3ms/step
# Epoch 84/1000
# 75/75 - 0s - loss: 59.6009 - root_mean_squared_error: 7.7202 - val_loss: 54.2846 - val_root_mean_squared_error: 7.3678 - 205ms/epoch - 3ms/step
# Epoch 85/1000
# 75/75 - 0s - loss: 61.2581 - root_mean_squared_error: 7.8268 - val_loss: 54.7113 - val_root_mean_squared_error: 7.3967 - 274ms/epoch - 4ms/step
# Epoch 86/1000
# 75/75 - 0s - loss: 61.7800 - root_mean_squared_error: 7.8600 - val_loss: 55.1025 - val_root_mean_squared_error: 7.4231 - 205ms/epoch - 3ms/step
# Epoch 87/1000
# 75/75 - 0s - loss: 58.3704 - root_mean_squared_error: 7.6401 - val_loss: 54.5335 - val_root_mean_squared_error: 7.3847 - 221ms/epoch - 3ms/step
# Epoch 88/1000
# 75/75 - 0s - loss: 59.1790 - root_mean_squared_error: 7.6928 - val_loss: 54.4160 - val_root_mean_squared_error: 7.3767 - 269ms/epoch - 4ms/step
# Epoch 89/1000
# 75/75 - 0s - loss: 61.3061 - root_mean_squared_error: 7.8298 - val_loss: 55.4716 - val_root_mean_squared_error: 7.4479 - 209ms/epoch - 3ms/step
# Epoch 90/1000
# 75/75 - 0s - loss: 58.4896 - root_mean_squared_error: 7.6478 - val_loss: 53.9310 - val_root_mean_squared_error: 7.3438 - 217ms/epoch - 3ms/step
# Epoch 91/1000
# 75/75 - 0s - loss: 60.6107 - root_mean_squared_error: 7.7853 - val_loss: 54.5470 - val_root_mean_squared_error: 7.3856 - 199ms/epoch - 3ms/step
# Epoch 92/1000
# 75/75 - 0s - loss: 61.0795 - root_mean_squared_error: 7.8153 - val_loss: 56.8958 - val_root_mean_squared_error: 7.5429 - 217ms/epoch - 3ms/step
# Epoch 93/1000
# 75/75 - 0s - loss: 60.1799 - root_mean_squared_error: 7.7576 - val_loss: 53.3338 - val_root_mean_squared_error: 7.3030 - 244ms/epoch - 3ms/step
# Epoch 94/1000
# 75/75 - 0s - loss: 58.6369 - root_mean_squared_error: 7.6575 - val_loss: 54.5304 - val_root_mean_squared_error: 7.3845 - 244ms/epoch - 3ms/step
# Epoch 95/1000
# 75/75 - 0s - loss: 58.6787 - root_mean_squared_error: 7.6602 - val_loss: 53.6277 - val_root_mean_squared_error: 7.3231 - 211ms/epoch - 3ms/step
# Epoch 96/1000
# 75/75 - 0s - loss: 59.3091 - root_mean_squared_error: 7.7012 - val_loss: 53.3602 - val_root_mean_squared_error: 7.3048 - 200ms/epoch - 3ms/step
# Epoch 97/1000
# 75/75 - 0s - loss: 60.0157 - root_mean_squared_error: 7.7470 - val_loss: 53.5770 - val_root_mean_squared_error: 7.3196 - 224ms/epoch - 3ms/step
# Epoch 98/1000
# 75/75 - 0s - loss: 60.0765 - root_mean_squared_error: 7.7509 - val_loss: 53.9908 - val_root_mean_squared_error: 7.3478 - 207ms/epoch - 3ms/step
# Epoch 99/1000
# 75/75 - 0s - loss: 60.3267 - root_mean_squared_error: 7.7670 - val_loss: 52.8239 - val_root_mean_squared_error: 7.2680 - 218ms/epoch - 3ms/step
# Epoch 100/1000
# 75/75 - 0s - loss: 59.9602 - root_mean_squared_error: 7.7434 - val_loss: 53.1073 - val_root_mean_squared_error: 7.2875 - 209ms/epoch - 3ms/step
# Epoch 101/1000
# 75/75 - 0s - loss: 59.5137 - root_mean_squared_error: 7.7145 - val_loss: 52.8286 - val_root_mean_squared_error: 7.2683 - 223ms/epoch - 3ms/step
# Epoch 102/1000
# 75/75 - 0s - loss: 57.0011 - root_mean_squared_error: 7.5499 - val_loss: 52.6457 - val_root_mean_squared_error: 7.2557 - 213ms/epoch - 3ms/step
# Epoch 103/1000
# 75/75 - 0s - loss: 57.0842 - root_mean_squared_error: 7.5554 - val_loss: 52.7280 - val_root_mean_squared_error: 7.2614 - 234ms/epoch - 3ms/step
# Epoch 104/1000
# 75/75 - 0s - loss: 58.6384 - root_mean_squared_error: 7.6576 - val_loss: 53.0052 - val_root_mean_squared_error: 7.2805 - 211ms/epoch - 3ms/step
# Epoch 105/1000
# 75/75 - 0s - loss: 58.4914 - root_mean_squared_error: 7.6480 - val_loss: 52.7100 - val_root_mean_squared_error: 7.2602 - 248ms/epoch - 3ms/step
# Epoch 106/1000
# 75/75 - 0s - loss: 57.4213 - root_mean_squared_error: 7.5777 - val_loss: 52.5970 - val_root_mean_squared_error: 7.2524 - 238ms/epoch - 3ms/step
# Epoch 107/1000
# 75/75 - 0s - loss: 57.5455 - root_mean_squared_error: 7.5859 - val_loss: 52.0290 - val_root_mean_squared_error: 7.2131 - 198ms/epoch - 3ms/step
# Epoch 108/1000
# 75/75 - 0s - loss: 61.5308 - root_mean_squared_error: 7.8442 - val_loss: 52.0550 - val_root_mean_squared_error: 7.2149 - 200ms/epoch - 3ms/step
# Epoch 109/1000
# 75/75 - 0s - loss: 58.9595 - root_mean_squared_error: 7.6785 - val_loss: 51.8336 - val_root_mean_squared_error: 7.1996 - 216ms/epoch - 3ms/step
# Epoch 110/1000
# 75/75 - 0s - loss: 59.5860 - root_mean_squared_error: 7.7192 - val_loss: 52.0319 - val_root_mean_squared_error: 7.2133 - 217ms/epoch - 3ms/step
# Epoch 111/1000
# 75/75 - 0s - loss: 57.9712 - root_mean_squared_error: 7.6139 - val_loss: 52.4605 - val_root_mean_squared_error: 7.2430 - 219ms/epoch - 3ms/step
# Epoch 112/1000
# 75/75 - 0s - loss: 57.6100 - root_mean_squared_error: 7.5901 - val_loss: 51.5415 - val_root_mean_squared_error: 7.1792 - 214ms/epoch - 3ms/step
# Epoch 113/1000
# 75/75 - 0s - loss: 56.7475 - root_mean_squared_error: 7.5331 - val_loss: 52.0103 - val_root_mean_squared_error: 7.2118 - 260ms/epoch - 3ms/step
# Epoch 114/1000
# 75/75 - 0s - loss: 56.6457 - root_mean_squared_error: 7.5263 - val_loss: 51.9606 - val_root_mean_squared_error: 7.2084 - 207ms/epoch - 3ms/step
# Epoch 115/1000
# 75/75 - 0s - loss: 57.0568 - root_mean_squared_error: 7.5536 - val_loss: 51.2285 - val_root_mean_squared_error: 7.1574 - 224ms/epoch - 3ms/step
# Epoch 116/1000
# 75/75 - 0s - loss: 58.0093 - root_mean_squared_error: 7.6164 - val_loss: 53.1454 - val_root_mean_squared_error: 7.2901 - 208ms/epoch - 3ms/step
# Epoch 117/1000
# 75/75 - 0s - loss: 57.4023 - root_mean_squared_error: 7.5764 - val_loss: 51.2128 - val_root_mean_squared_error: 7.1563 - 208ms/epoch - 3ms/step
# Epoch 118/1000
# 75/75 - 0s - loss: 57.7262 - root_mean_squared_error: 7.5978 - val_loss: 51.2338 - val_root_mean_squared_error: 7.1578 - 201ms/epoch - 3ms/step
# Epoch 119/1000
# 75/75 - 0s - loss: 57.6649 - root_mean_squared_error: 7.5937 - val_loss: 51.1435 - val_root_mean_squared_error: 7.1515 - 201ms/epoch - 3ms/step
# Epoch 120/1000
# 75/75 - 0s - loss: 56.0018 - root_mean_squared_error: 7.4834 - val_loss: 50.9251 - val_root_mean_squared_error: 7.1362 - 220ms/epoch - 3ms/step
# Epoch 121/1000
# 75/75 - 0s - loss: 57.5137 - root_mean_squared_error: 7.5838 - val_loss: 51.2704 - val_root_mean_squared_error: 7.1603 - 211ms/epoch - 3ms/step
# Epoch 122/1000
# 75/75 - 0s - loss: 56.8822 - root_mean_squared_error: 7.5420 - val_loss: 51.0599 - val_root_mean_squared_error: 7.1456 - 217ms/epoch - 3ms/step
# Epoch 123/1000
# 75/75 - 0s - loss: 57.1668 - root_mean_squared_error: 7.5609 - val_loss: 50.9865 - val_root_mean_squared_error: 7.1405 - 234ms/epoch - 3ms/step
# Epoch 124/1000
# 75/75 - 0s - loss: 57.2378 - root_mean_squared_error: 7.5656 - val_loss: 50.7794 - val_root_mean_squared_error: 7.1260 - 258ms/epoch - 3ms/step
# Epoch 125/1000
# 75/75 - 0s - loss: 58.6086 - root_mean_squared_error: 7.6556 - val_loss: 51.0001 - val_root_mean_squared_error: 7.1414 - 205ms/epoch - 3ms/step
# Epoch 126/1000
# 75/75 - 0s - loss: 56.6584 - root_mean_squared_error: 7.5272 - val_loss: 50.8353 - val_root_mean_squared_error: 7.1299 - 216ms/epoch - 3ms/step
# Epoch 127/1000
# 75/75 - 0s - loss: 58.2159 - root_mean_squared_error: 7.6299 - val_loss: 50.8604 - val_root_mean_squared_error: 7.1316 - 200ms/epoch - 3ms/step
# Epoch 128/1000
# 75/75 - 0s - loss: 58.5076 - root_mean_squared_error: 7.6490 - val_loss: 50.6227 - val_root_mean_squared_error: 7.1150 - 215ms/epoch - 3ms/step
# Epoch 129/1000
# 75/75 - 0s - loss: 56.2832 - root_mean_squared_error: 7.5022 - val_loss: 53.4794 - val_root_mean_squared_error: 7.3130 - 255ms/epoch - 3ms/step
# Epoch 130/1000
# 75/75 - 0s - loss: 56.7685 - root_mean_squared_error: 7.5345 - val_loss: 50.5520 - val_root_mean_squared_error: 7.1100 - 215ms/epoch - 3ms/step
# Epoch 131/1000
# 75/75 - 0s - loss: 55.7664 - root_mean_squared_error: 7.4677 - val_loss: 50.2757 - val_root_mean_squared_error: 7.0905 - 201ms/epoch - 3ms/step
# Epoch 132/1000
# 75/75 - 0s - loss: 58.0262 - root_mean_squared_error: 7.6175 - val_loss: 50.5163 - val_root_mean_squared_error: 7.1075 - 219ms/epoch - 3ms/step
# Epoch 133/1000
# 75/75 - 0s - loss: 56.6405 - root_mean_squared_error: 7.5260 - val_loss: 50.0644 - val_root_mean_squared_error: 7.0756 - 212ms/epoch - 3ms/step
# Epoch 134/1000
# 75/75 - 0s - loss: 57.4402 - root_mean_squared_error: 7.5789 - val_loss: 50.3196 - val_root_mean_squared_error: 7.0936 - 232ms/epoch - 3ms/step
# Epoch 135/1000
# 75/75 - 0s - loss: 57.7862 - root_mean_squared_error: 7.6017 - val_loss: 50.2997 - val_root_mean_squared_error: 7.0922 - 203ms/epoch - 3ms/step
# Epoch 136/1000
# 75/75 - 0s - loss: 57.2196 - root_mean_squared_error: 7.5644 - val_loss: 49.7034 - val_root_mean_squared_error: 7.0501 - 200ms/epoch - 3ms/step
# Epoch 137/1000
# 75/75 - 0s - loss: 55.9734 - root_mean_squared_error: 7.4815 - val_loss: 49.8874 - val_root_mean_squared_error: 7.0631 - 216ms/epoch - 3ms/step
# Epoch 138/1000
# 75/75 - 0s - loss: 54.9319 - root_mean_squared_error: 7.4116 - val_loss: 50.2630 - val_root_mean_squared_error: 7.0896 - 215ms/epoch - 3ms/step
# Epoch 139/1000
# 75/75 - 0s - loss: 54.8460 - root_mean_squared_error: 7.4058 - val_loss: 49.5796 - val_root_mean_squared_error: 7.0413 - 211ms/epoch - 3ms/step
# Epoch 140/1000
# 75/75 - 0s - loss: 55.2232 - root_mean_squared_error: 7.4312 - val_loss: 50.4184 - val_root_mean_squared_error: 7.1006 - 201ms/epoch - 3ms/step
# Epoch 141/1000
# 75/75 - 0s - loss: 56.1572 - root_mean_squared_error: 7.4938 - val_loss: 50.1197 - val_root_mean_squared_error: 7.0795 - 201ms/epoch - 3ms/step
# Epoch 142/1000
# 75/75 - 0s - loss: 58.1518 - root_mean_squared_error: 7.6257 - val_loss: 50.1399 - val_root_mean_squared_error: 7.0810 - 266ms/epoch - 4ms/step
# Epoch 143/1000
# 75/75 - 0s - loss: 55.7948 - root_mean_squared_error: 7.4696 - val_loss: 49.5583 - val_root_mean_squared_error: 7.0398 - 213ms/epoch - 3ms/step
# Epoch 144/1000
# 75/75 - 0s - loss: 53.4992 - root_mean_squared_error: 7.3143 - val_loss: 49.1204 - val_root_mean_squared_error: 7.0086 - 208ms/epoch - 3ms/step
# Epoch 145/1000
# 75/75 - 0s - loss: 56.3347 - root_mean_squared_error: 7.5056 - val_loss: 49.5476 - val_root_mean_squared_error: 7.0390 - 210ms/epoch - 3ms/step
# Epoch 146/1000
# 75/75 - 0s - loss: 57.7551 - root_mean_squared_error: 7.5997 - val_loss: 49.0520 - val_root_mean_squared_error: 7.0037 - 244ms/epoch - 3ms/step
# Epoch 147/1000
# 75/75 - 0s - loss: 55.7481 - root_mean_squared_error: 7.4665 - val_loss: 49.1901 - val_root_mean_squared_error: 7.0136 - 244ms/epoch - 3ms/step
# Epoch 148/1000
# 75/75 - 0s - loss: 56.5452 - root_mean_squared_error: 7.5197 - val_loss: 48.9219 - val_root_mean_squared_error: 6.9944 - 239ms/epoch - 3ms/step
# Epoch 149/1000
# 75/75 - 0s - loss: 56.1859 - root_mean_squared_error: 7.4957 - val_loss: 49.3471 - val_root_mean_squared_error: 7.0247 - 233ms/epoch - 3ms/step
# Epoch 150/1000
# 75/75 - 0s - loss: 57.2433 - root_mean_squared_error: 7.5659 - val_loss: 48.8504 - val_root_mean_squared_error: 6.9893 - 226ms/epoch - 3ms/step
# Epoch 151/1000
# 75/75 - 0s - loss: 56.4393 - root_mean_squared_error: 7.5126 - val_loss: 48.6987 - val_root_mean_squared_error: 6.9784 - 219ms/epoch - 3ms/step
# Epoch 152/1000
# 75/75 - 0s - loss: 55.4953 - root_mean_squared_error: 7.4495 - val_loss: 49.8301 - val_root_mean_squared_error: 7.0590 - 193ms/epoch - 3ms/step
# Epoch 153/1000
# 75/75 - 0s - loss: 58.8443 - root_mean_squared_error: 7.6710 - val_loss: 49.3321 - val_root_mean_squared_error: 7.0237 - 217ms/epoch - 3ms/step
# Epoch 154/1000
# 75/75 - 0s - loss: 55.8774 - root_mean_squared_error: 7.4751 - val_loss: 50.0688 - val_root_mean_squared_error: 7.0759 - 217ms/epoch - 3ms/step
# Epoch 155/1000
# 75/75 - 0s - loss: 56.0631 - root_mean_squared_error: 7.4875 - val_loss: 48.3089 - val_root_mean_squared_error: 6.9505 - 217ms/epoch - 3ms/step
# Epoch 156/1000
# 75/75 - 0s - loss: 55.7401 - root_mean_squared_error: 7.4659 - val_loss: 48.6079 - val_root_mean_squared_error: 6.9719 - 221ms/epoch - 3ms/step
# Epoch 157/1000
# 75/75 - 0s - loss: 56.5114 - root_mean_squared_error: 7.5174 - val_loss: 48.3961 - val_root_mean_squared_error: 6.9567 - 217ms/epoch - 3ms/step
# Epoch 158/1000
# 75/75 - 0s - loss: 55.8105 - root_mean_squared_error: 7.4706 - val_loss: 48.2292 - val_root_mean_squared_error: 6.9447 - 213ms/epoch - 3ms/step
# Epoch 159/1000
# 75/75 - 0s - loss: 54.2341 - root_mean_squared_error: 7.3644 - val_loss: 48.3341 - val_root_mean_squared_error: 6.9523 - 218ms/epoch - 3ms/step
# Epoch 160/1000
# 75/75 - 0s - loss: 55.2341 - root_mean_squared_error: 7.4320 - val_loss: 48.3089 - val_root_mean_squared_error: 6.9505 - 226ms/epoch - 3ms/step
# Epoch 161/1000
# 75/75 - 0s - loss: 54.0200 - root_mean_squared_error: 7.3498 - val_loss: 48.3125 - val_root_mean_squared_error: 6.9507 - 219ms/epoch - 3ms/step
# Epoch 162/1000
# 75/75 - 0s - loss: 58.2268 - root_mean_squared_error: 7.6307 - val_loss: 48.2790 - val_root_mean_squared_error: 6.9483 - 221ms/epoch - 3ms/step
# Epoch 163/1000
# 75/75 - 0s - loss: 56.3164 - root_mean_squared_error: 7.5044 - val_loss: 47.9804 - val_root_mean_squared_error: 6.9268 - 197ms/epoch - 3ms/step
# Epoch 164/1000
# 75/75 - 0s - loss: 54.2862 - root_mean_squared_error: 7.3679 - val_loss: 48.5532 - val_root_mean_squared_error: 6.9680 - 252ms/epoch - 3ms/step
# Epoch 165/1000
# 75/75 - 0s - loss: 54.3199 - root_mean_squared_error: 7.3702 - val_loss: 49.2254 - val_root_mean_squared_error: 7.0161 - 203ms/epoch - 3ms/step
# Epoch 166/1000
# 75/75 - 0s - loss: 57.0219 - root_mean_squared_error: 7.5513 - val_loss: 47.8867 - val_root_mean_squared_error: 6.9200 - 277ms/epoch - 4ms/step
# Epoch 167/1000
# 75/75 - 0s - loss: 55.1474 - root_mean_squared_error: 7.4261 - val_loss: 48.1596 - val_root_mean_squared_error: 6.9397 - 202ms/epoch - 3ms/step
# Epoch 168/1000
# 75/75 - 0s - loss: 56.3254 - root_mean_squared_error: 7.5050 - val_loss: 48.0282 - val_root_mean_squared_error: 6.9302 - 234ms/epoch - 3ms/step
# Epoch 169/1000
# 75/75 - 0s - loss: 53.6982 - root_mean_squared_error: 7.3279 - val_loss: 48.1204 - val_root_mean_squared_error: 6.9369 - 218ms/epoch - 3ms/step
# Epoch 170/1000
# 75/75 - 0s - loss: 53.3800 - root_mean_squared_error: 7.3062 - val_loss: 47.8108 - val_root_mean_squared_error: 6.9145 - 212ms/epoch - 3ms/step
# Epoch 171/1000
# 75/75 - 0s - loss: 54.4938 - root_mean_squared_error: 7.3820 - val_loss: 48.9138 - val_root_mean_squared_error: 6.9938 - 202ms/epoch - 3ms/step
# Epoch 172/1000
# 75/75 - 0s - loss: 55.3551 - root_mean_squared_error: 7.4401 - val_loss: 47.6350 - val_root_mean_squared_error: 6.9018 - 200ms/epoch - 3ms/step
# Epoch 173/1000
# 75/75 - 0s - loss: 56.3391 - root_mean_squared_error: 7.5059 - val_loss: 47.4920 - val_root_mean_squared_error: 6.8914 - 245ms/epoch - 3ms/step
# Epoch 174/1000
# 75/75 - 0s - loss: 54.2865 - root_mean_squared_error: 7.3679 - val_loss: 47.6821 - val_root_mean_squared_error: 6.9052 - 222ms/epoch - 3ms/step
# Epoch 175/1000
# 75/75 - 0s - loss: 54.3791 - root_mean_squared_error: 7.3742 - val_loss: 47.8145 - val_root_mean_squared_error: 6.9148 - 236ms/epoch - 3ms/step
# Epoch 176/1000
# 75/75 - 0s - loss: 55.4990 - root_mean_squared_error: 7.4498 - val_loss: 47.0975 - val_root_mean_squared_error: 6.8628 - 214ms/epoch - 3ms/step
# Epoch 177/1000
# 75/75 - 0s - loss: 57.5749 - root_mean_squared_error: 7.5878 - val_loss: 46.9303 - val_root_mean_squared_error: 6.8506 - 232ms/epoch - 3ms/step
# Epoch 178/1000
# 75/75 - 0s - loss: 55.2161 - root_mean_squared_error: 7.4308 - val_loss: 50.3069 - val_root_mean_squared_error: 7.0927 - 208ms/epoch - 3ms/step
# Epoch 179/1000
# 75/75 - 0s - loss: 57.5769 - root_mean_squared_error: 7.5879 - val_loss: 47.1254 - val_root_mean_squared_error: 6.8648 - 210ms/epoch - 3ms/step
# Epoch 180/1000
# 75/75 - 0s - loss: 57.2112 - root_mean_squared_error: 7.5638 - val_loss: 47.8608 - val_root_mean_squared_error: 6.9181 - 209ms/epoch - 3ms/step
# Epoch 181/1000
# 75/75 - 0s - loss: 55.5020 - root_mean_squared_error: 7.4500 - val_loss: 47.4032 - val_root_mean_squared_error: 6.8850 - 247ms/epoch - 3ms/step
# Epoch 182/1000
# 75/75 - 0s - loss: 54.6779 - root_mean_squared_error: 7.3944 - val_loss: 47.3357 - val_root_mean_squared_error: 6.8801 - 211ms/epoch - 3ms/step
# Epoch 183/1000
# 75/75 - 0s - loss: 54.2237 - root_mean_squared_error: 7.3637 - val_loss: 46.9934 - val_root_mean_squared_error: 6.8552 - 234ms/epoch - 3ms/step
# Epoch 184/1000
# 75/75 - 0s - loss: 53.7150 - root_mean_squared_error: 7.3291 - val_loss: 47.0399 - val_root_mean_squared_error: 6.8586 - 204ms/epoch - 3ms/step
# Epoch 185/1000
# 75/75 - 0s - loss: 53.2977 - root_mean_squared_error: 7.3005 - val_loss: 47.1432 - val_root_mean_squared_error: 6.8661 - 212ms/epoch - 3ms/step
# Epoch 186/1000
# 75/75 - 0s - loss: 53.4887 - root_mean_squared_error: 7.3136 - val_loss: 46.7149 - val_root_mean_squared_error: 6.8348 - 217ms/epoch - 3ms/step
# Epoch 187/1000
# 75/75 - 0s - loss: 55.6267 - root_mean_squared_error: 7.4583 - val_loss: 47.0210 - val_root_mean_squared_error: 6.8572 - 262ms/epoch - 3ms/step
# Epoch 188/1000
# 75/75 - 0s - loss: 54.9141 - root_mean_squared_error: 7.4104 - val_loss: 46.9117 - val_root_mean_squared_error: 6.8492 - 223ms/epoch - 3ms/step
# Epoch 189/1000
# 75/75 - 0s - loss: 56.4232 - root_mean_squared_error: 7.5115 - val_loss: 46.9265 - val_root_mean_squared_error: 6.8503 - 234ms/epoch - 3ms/step
# Epoch 190/1000
# 75/75 - 0s - loss: 56.2866 - root_mean_squared_error: 7.5024 - val_loss: 48.4868 - val_root_mean_squared_error: 6.9632 - 226ms/epoch - 3ms/step
# Epoch 191/1000
# 75/75 - 0s - loss: 53.1407 - root_mean_squared_error: 7.2898 - val_loss: 46.4022 - val_root_mean_squared_error: 6.8119 - 222ms/epoch - 3ms/step
# Epoch 192/1000
# 75/75 - 0s - loss: 52.8139 - root_mean_squared_error: 7.2673 - val_loss: 46.6828 - val_root_mean_squared_error: 6.8325 - 212ms/epoch - 3ms/step
# Epoch 193/1000
# 75/75 - 0s - loss: 54.8660 - root_mean_squared_error: 7.4072 - val_loss: 46.7907 - val_root_mean_squared_error: 6.8404 - 234ms/epoch - 3ms/step
# Epoch 194/1000
# 75/75 - 0s - loss: 54.7142 - root_mean_squared_error: 7.3969 - val_loss: 47.2761 - val_root_mean_squared_error: 6.8758 - 222ms/epoch - 3ms/step
# Epoch 195/1000
# 75/75 - 0s - loss: 56.4974 - root_mean_squared_error: 7.5165 - val_loss: 46.1324 - val_root_mean_squared_error: 6.7921 - 210ms/epoch - 3ms/step
# Epoch 196/1000
# 75/75 - 0s - loss: 53.2441 - root_mean_squared_error: 7.2969 - val_loss: 46.1500 - val_root_mean_squared_error: 6.7934 - 217ms/epoch - 3ms/step
# Epoch 197/1000
# 75/75 - 0s - loss: 57.1095 - root_mean_squared_error: 7.5571 - val_loss: 46.0800 - val_root_mean_squared_error: 6.7882 - 209ms/epoch - 3ms/step
# Epoch 198/1000
# 75/75 - 0s - loss: 56.5155 - root_mean_squared_error: 7.5177 - val_loss: 46.0785 - val_root_mean_squared_error: 6.7881 - 200ms/epoch - 3ms/step
# Epoch 199/1000
# 75/75 - 0s - loss: 54.5138 - root_mean_squared_error: 7.3833 - val_loss: 45.8726 - val_root_mean_squared_error: 6.7729 - 223ms/epoch - 3ms/step
# Epoch 200/1000
# 75/75 - 0s - loss: 56.7457 - root_mean_squared_error: 7.5330 - val_loss: 50.2312 - val_root_mean_squared_error: 7.0874 - 208ms/epoch - 3ms/step
# Epoch 201/1000
# 75/75 - 0s - loss: 57.0643 - root_mean_squared_error: 7.5541 - val_loss: 46.3674 - val_root_mean_squared_error: 6.8094 - 262ms/epoch - 3ms/step
# Epoch 202/1000
# 75/75 - 0s - loss: 53.3736 - root_mean_squared_error: 7.3057 - val_loss: 46.4729 - val_root_mean_squared_error: 6.8171 - 221ms/epoch - 3ms/step
# Epoch 203/1000
# 75/75 - 0s - loss: 52.9308 - root_mean_squared_error: 7.2754 - val_loss: 47.0941 - val_root_mean_squared_error: 6.8625 - 205ms/epoch - 3ms/step
# Epoch 204/1000
# 75/75 - 0s - loss: 53.5241 - root_mean_squared_error: 7.3160 - val_loss: 45.8422 - val_root_mean_squared_error: 6.7707 - 213ms/epoch - 3ms/step
# Epoch 205/1000
# 75/75 - 0s - loss: 53.7086 - root_mean_squared_error: 7.3286 - val_loss: 47.3542 - val_root_mean_squared_error: 6.8814 - 223ms/epoch - 3ms/step
# Epoch 206/1000
# 75/75 - 0s - loss: 53.5316 - root_mean_squared_error: 7.3165 - val_loss: 45.6080 - val_root_mean_squared_error: 6.7534 - 210ms/epoch - 3ms/step
# Epoch 207/1000
# 75/75 - 0s - loss: 52.4520 - root_mean_squared_error: 7.2424 - val_loss: 45.5082 - val_root_mean_squared_error: 6.7460 - 201ms/epoch - 3ms/step
# Epoch 208/1000
# 75/75 - 0s - loss: 53.0725 - root_mean_squared_error: 7.2851 - val_loss: 45.5552 - val_root_mean_squared_error: 6.7495 - 217ms/epoch - 3ms/step
# Epoch 209/1000
# 75/75 - 0s - loss: 53.3816 - root_mean_squared_error: 7.3063 - val_loss: 45.5126 - val_root_mean_squared_error: 6.7463 - 201ms/epoch - 3ms/step
# Epoch 210/1000
# 75/75 - 0s - loss: 53.2713 - root_mean_squared_error: 7.2987 - val_loss: 45.4861 - val_root_mean_squared_error: 6.7443 - 329ms/epoch - 4ms/step
# Epoch 211/1000
# 75/75 - 0s - loss: 55.6974 - root_mean_squared_error: 7.4631 - val_loss: 46.5461 - val_root_mean_squared_error: 6.8225 - 200ms/epoch - 3ms/step
# Epoch 212/1000
# 75/75 - 0s - loss: 54.5379 - root_mean_squared_error: 7.3850 - val_loss: 45.5596 - val_root_mean_squared_error: 6.7498 - 221ms/epoch - 3ms/step
# Epoch 213/1000
# 75/75 - 0s - loss: 55.2925 - root_mean_squared_error: 7.4359 - val_loss: 45.7114 - val_root_mean_squared_error: 6.7610 - 232ms/epoch - 3ms/step
# Epoch 214/1000
# 75/75 - 0s - loss: 53.8265 - root_mean_squared_error: 7.3367 - val_loss: 46.0277 - val_root_mean_squared_error: 6.7844 - 219ms/epoch - 3ms/step
# Epoch 215/1000
# 75/75 - 0s - loss: 52.2985 - root_mean_squared_error: 7.2318 - val_loss: 45.5597 - val_root_mean_squared_error: 6.7498 - 213ms/epoch - 3ms/step
# Epoch 216/1000
# 75/75 - 0s - loss: 51.9832 - root_mean_squared_error: 7.2099 - val_loss: 45.4370 - val_root_mean_squared_error: 6.7407 - 216ms/epoch - 3ms/step
# Epoch 217/1000
# 75/75 - 0s - loss: 52.0885 - root_mean_squared_error: 7.2172 - val_loss: 46.1300 - val_root_mean_squared_error: 6.7919 - 221ms/epoch - 3ms/step
# Epoch 218/1000
# 75/75 - 0s - loss: 52.8716 - root_mean_squared_error: 7.2713 - val_loss: 45.6023 - val_root_mean_squared_error: 6.7529 - 225ms/epoch - 3ms/step
# Epoch 219/1000
# 75/75 - 0s - loss: 53.6949 - root_mean_squared_error: 7.3277 - val_loss: 45.3318 - val_root_mean_squared_error: 6.7329 - 268ms/epoch - 4ms/step
# Epoch 220/1000
# 75/75 - 0s - loss: 55.3237 - root_mean_squared_error: 7.4380 - val_loss: 45.1788 - val_root_mean_squared_error: 6.7215 - 211ms/epoch - 3ms/step
# Epoch 221/1000
# 75/75 - 0s - loss: 56.9993 - root_mean_squared_error: 7.5498 - val_loss: 45.7472 - val_root_mean_squared_error: 6.7637 - 226ms/epoch - 3ms/step
# Epoch 222/1000
# 75/75 - 0s - loss: 53.6960 - root_mean_squared_error: 7.3278 - val_loss: 48.1432 - val_root_mean_squared_error: 6.9385 - 201ms/epoch - 3ms/step
# Epoch 223/1000
# 75/75 - 0s - loss: 52.1746 - root_mean_squared_error: 7.2232 - val_loss: 45.2947 - val_root_mean_squared_error: 6.7301 - 219ms/epoch - 3ms/step
# Epoch 224/1000
# 75/75 - 0s - loss: 54.5618 - root_mean_squared_error: 7.3866 - val_loss: 46.2617 - val_root_mean_squared_error: 6.8016 - 215ms/epoch - 3ms/step
# Epoch 225/1000
# 75/75 - 0s - loss: 52.1205 - root_mean_squared_error: 7.2195 - val_loss: 44.7751 - val_root_mean_squared_error: 6.6914 - 202ms/epoch - 3ms/step
# Epoch 226/1000
# 75/75 - 0s - loss: 55.1176 - root_mean_squared_error: 7.4241 - val_loss: 46.4191 - val_root_mean_squared_error: 6.8132 - 200ms/epoch - 3ms/step
# Epoch 227/1000
# 75/75 - 0s - loss: 53.7425 - root_mean_squared_error: 7.3309 - val_loss: 45.4698 - val_root_mean_squared_error: 6.7431 - 215ms/epoch - 3ms/step
# Epoch 228/1000
# 75/75 - 0s - loss: 55.1666 - root_mean_squared_error: 7.4274 - val_loss: 45.1693 - val_root_mean_squared_error: 6.7208 - 218ms/epoch - 3ms/step
# Epoch 229/1000
# 75/75 - 0s - loss: 55.8091 - root_mean_squared_error: 7.4706 - val_loss: 45.5077 - val_root_mean_squared_error: 6.7459 - 201ms/epoch - 3ms/step
# Epoch 230/1000
# 75/75 - 0s - loss: 53.5644 - root_mean_squared_error: 7.3188 - val_loss: 44.8569 - val_root_mean_squared_error: 6.6975 - 217ms/epoch - 3ms/step
# Epoch 231/1000
# 75/75 - 0s - loss: 52.4118 - root_mean_squared_error: 7.2396 - val_loss: 44.6305 - val_root_mean_squared_error: 6.6806 - 215ms/epoch - 3ms/step
# Epoch 232/1000
# 75/75 - 0s - loss: 53.1221 - root_mean_squared_error: 7.2885 - val_loss: 44.5912 - val_root_mean_squared_error: 6.6777 - 222ms/epoch - 3ms/step
# Epoch 233/1000
# 75/75 - 0s - loss: 54.1834 - root_mean_squared_error: 7.3609 - val_loss: 44.4404 - val_root_mean_squared_error: 6.6664 - 212ms/epoch - 3ms/step
# Epoch 234/1000
# 75/75 - 0s - loss: 53.7545 - root_mean_squared_error: 7.3317 - val_loss: 44.8056 - val_root_mean_squared_error: 6.6937 - 201ms/epoch - 3ms/step
# Epoch 235/1000
# 75/75 - 0s - loss: 53.2155 - root_mean_squared_error: 7.2949 - val_loss: 45.5003 - val_root_mean_squared_error: 6.7454 - 201ms/epoch - 3ms/step
# Epoch 236/1000
# 75/75 - 0s - loss: 53.5460 - root_mean_squared_error: 7.3175 - val_loss: 44.5453 - val_root_mean_squared_error: 6.6742 - 215ms/epoch - 3ms/step
# Epoch 237/1000
# 75/75 - 0s - loss: 55.8028 - root_mean_squared_error: 7.4701 - val_loss: 44.2389 - val_root_mean_squared_error: 6.6512 - 219ms/epoch - 3ms/step
# Epoch 238/1000
# 75/75 - 0s - loss: 52.8672 - root_mean_squared_error: 7.2710 - val_loss: 44.6234 - val_root_mean_squared_error: 6.6801 - 260ms/epoch - 3ms/step
# Epoch 239/1000
# 75/75 - 0s - loss: 55.4204 - root_mean_squared_error: 7.4445 - val_loss: 45.1270 - val_root_mean_squared_error: 6.7177 - 224ms/epoch - 3ms/step
# Epoch 240/1000
# 75/75 - 0s - loss: 53.2861 - root_mean_squared_error: 7.2997 - val_loss: 44.8300 - val_root_mean_squared_error: 6.6955 - 221ms/epoch - 3ms/step
# Epoch 241/1000
# 75/75 - 0s - loss: 51.2001 - root_mean_squared_error: 7.1554 - val_loss: 45.1605 - val_root_mean_squared_error: 6.7202 - 200ms/epoch - 3ms/step
# Epoch 242/1000
# 75/75 - 0s - loss: 52.6732 - root_mean_squared_error: 7.2576 - val_loss: 44.6846 - val_root_mean_squared_error: 6.6847 - 226ms/epoch - 3ms/step
# Epoch 243/1000
# 75/75 - 0s - loss: 52.7971 - root_mean_squared_error: 7.2662 - val_loss: 44.4144 - val_root_mean_squared_error: 6.6644 - 219ms/epoch - 3ms/step
# Epoch 244/1000
# 75/75 - 0s - loss: 52.6262 - root_mean_squared_error: 7.2544 - val_loss: 44.7586 - val_root_mean_squared_error: 6.6902 - 216ms/epoch - 3ms/step
# Epoch 245/1000
# 75/75 - 0s - loss: 52.9863 - root_mean_squared_error: 7.2792 - val_loss: 45.2563 - val_root_mean_squared_error: 6.7273 - 217ms/epoch - 3ms/step
# Epoch 246/1000
# 75/75 - 0s - loss: 55.1840 - root_mean_squared_error: 7.4286 - val_loss: 44.8145 - val_root_mean_squared_error: 6.6944 - 204ms/epoch - 3ms/step
# Epoch 247/1000
# 75/75 - 0s - loss: 53.5490 - root_mean_squared_error: 7.3177 - val_loss: 45.0592 - val_root_mean_squared_error: 6.7126 - 213ms/epoch - 3ms/step

# %%
plot_history('root_mean_squared_error')

# %%
y_train_predicted = model.predict(x_train)
y_test_predicted = model.predict(x_test)
# Out:
# 75/75 [==============================] - 0s 1ms/step
# 36/36 [==============================] - 0s 1ms/step

# %%
def plot_predictions(y_pred, y_true, title):
    plt.style.use('ggplot') 
    plt.scatter(y_pred, y_true, s=10, alpha=0.5)
    plt.xlabel("predicted")
    plt.ylabel("true")
    plt.title(title)
   

plot_predictions(y_train_predicted, y_train, title='Predictions on the training set')

# %%
plot_predictions(y_test_predicted, y_test, title='Predictions on the test set')

# %%
train_metrics = model.evaluate(x_train, y_train, return_dict=True)
test_metrics = model.evaluate(x_test, y_test, return_dict=True)
print('Train RMSE: {:.2f}, Test RMSE: {:.2f}'.format(train_metrics['root_mean_squared_error'], test_metrics['root_mean_squared_error']))
# Out:
# 75/75 [==============================] - 0s 1ms/step - loss: 45.0592 - root_mean_squared_error: 6.7126
# 36/36 [==============================] - 0s 1ms/step - loss: 33.3081 - root_mean_squared_error: 5.7713
# Train RMSE: 6.71, Test RMSE: 5.77

# %%
x_test
# Out:
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
# 2921             -0.6                  98.5                        1.9
# 2922              5.9                  94.0                        3.3
# 2923              4.7                  83.8                        3.2
# 2924              4.1                  85.2                        2.0
# ...               ...                   ...                        ...
# 4132              7.6                  67.2                        1.8
# 4133              9.7                  69.3                        2.4
# 4134             10.3                  69.7                        3.5
# 4135              9.8                  54.0                        1.8
# 4136             12.8                  53.6                        1.9
#
#       Windrichtung (°)  Luftdruck (hPa)  Feinstaub Mittelwert
# 2920             200.0           1031.4             18.428571
# 2921             210.0           1024.0             21.000000
# 2922             231.0           1013.9             21.428571
# 2923             282.0           1020.7             22.000000
# 2924             222.0           1030.3             23.142857
# ...                ...              ...                   ...
# 4132             278.0           1019.2             14.000000
# 4133             102.0           1013.1             13.571429
# 4134             322.0           1015.8             13.142857
# 4135             305.0           1022.5             13.714286
# 4136             229.0           1015.3             14.428571
#
# [1122 rows x 6 columns]

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_test_predicted, squared=False)
# Out:
# 5.771318587416572

# %%
plot_history(['root_mean_squared_error', 'val_root_mean_squared_error'])
