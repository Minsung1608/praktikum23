# %%
import pandas as pd 
df1=pd.read_csv("billwerder_schadstoffe_2012-2023.csv")
df2=pd.read_csv("billwerder_wetter_2012-2023.csv")
df=pd.merge(df1, df2, on="Messzeit")
rolling_mean = df['Feinstaub (µg/m3)'].rolling(window=7, min_periods=1).mean()
df['Feinstaub Mittelwert'] = rolling_mean
df.loc[df['Messzeit'] == "01.01.2019"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
#
#       Windrichtung (°)  Luftdruck (hPa)  Feinstaub Mittelwert
# 2555             292.0           1018.3                  19.0

# %%
df.loc[df['Messzeit'] == "01.01.2020"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2920          2921  01.01.2020               57.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2920                      34.0                        7.0          2921
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
#
#       Windrichtung (°)  Luftdruck (hPa)  Feinstaub Mittelwert
# 2920             200.0           1031.4             18.428571

# %%
df_train = df.iloc[:2555,:]
df_val = df.iloc[2555:2920,:]
df_test = df.iloc[2920:,:]

# %%
df_val
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
# 2556          2557  02.01.2019               11.0                     3.0
# 2557          2558  03.01.2019               17.0                     4.0
# 2558          2559  04.01.2019               10.0                     3.0
# 2559          2560  05.01.2019               13.0                     3.0
# ...            ...         ...                ...                     ...
# 2915          2916  27.12.2019                7.0                     3.0
# 2916          2917  28.12.2019               11.0                     3.0
# 2917          2918  29.12.2019               10.0                     3.0
# 2918          2919  30.12.2019               12.0                    20.0
# 2919          2920  31.12.2019               23.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
# 2556                      18.0                        2.0          2557
# 2557                      56.0                       42.0          2558
# 2558                      34.0                        5.0          2559
# 2559                      19.0                        2.0          2560
# ...                        ...                        ...           ...
# 2915                      27.0                        8.0          2916
# 2916                      32.0                       23.0          2917
# 2917                      22.0                        2.0          2918
# 2918                      29.0                        2.0          2919
# 2919                      29.0                        2.0          2920
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
# 2556              3.4                  55.8                        4.6
# 2557              0.7                  78.9                        1.7
# 2558              4.3                  94.9                        3.1
# 2559              7.3                  95.5                        3.2
# ...               ...                   ...                        ...
# 2915              2.3                  87.3                        1.8
# 2916             -0.8                  91.1                        1.1
# 2917             -0.1                  80.0                        1.8
# 2918              7.4                  29.7                        2.5
# 2919              6.0                  83.9                        2.5
#
#       Windrichtung (°)  Luftdruck (hPa)  Feinstaub Mittelwert
# 2555             292.0           1018.3             19.000000
# 2556             324.0           1028.5             18.285714
# 2557             304.0           1034.7             17.142857
# 2558             294.0           1028.3             15.571429
# 2559             313.0           1022.1             14.428571
# ...                ...              ...                   ...
# 2915              41.0           1030.3              9.571429
# 2916             148.0           1040.8             10.000000
# 2917             181.0           1035.6              9.714286
# 2918             236.0           1025.0             10.000000
# 2919             288.0           1028.2             11.571429
#
# [365 rows x 13 columns]

# %%
df_train = df_train.dropna()
df_val = df_val.dropna()
df_test = df_test.dropna()

# %%
x_train = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_train = df_train['Feinstaub (µg/m3)']
x_val = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_val = df_train['Feinstaub (µg/m3)']
x_test = df_test.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_test = df_test['Feinstaub (µg/m3)']

# %%
from sklearn import preprocessing
x_train = preprocessing.normalize(x_train, norm='max')

x_val = preprocessing.normalize(x_val, norm='max')

x_test = preprocessing.normalize(x_test, norm='max')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_history(metrics):
    history_df = pd.DataFrame.from_dict(history.history)
    sns.lineplot(data=history_df[metrics])
    plt.xlabel("epochs")
    plt.ylabel("RMSE")

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlystopper = EarlyStopping(
    monitor='val_loss',
    patience=10
    )
# Out:
# 2023-07-06 14:01:57.346920: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization

def create_nn():
    inputs = keras.layers.Input(shape=(x_train.shape[1],), name='input')

    layers_dense = keras.layers.BatchNormalization()(inputs)
    layers_dense = keras.layers.Dense(100, 'relu')(layers_dense)
    layers_dense = keras.layers.Dense(50, 'relu')(layers_dense)

    outputs = keras.layers.Dense(1)(layers_dense)

    return keras.Model(inputs=inputs, outputs=outputs, name="model_batchnorm")

model = create_nn()
# Out:
# 2023-07-06 14:01:59.374945: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-07-06 14:01:59.374974: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-07-06 14:01:59.374989: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (l40052.lvt.dkrz.de): /proc/driver/nvidia/version does not exist
# 2023-07-06 14:01:59.375137: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def compile_model(model):
    model.compile(optimizer='adam',
                  loss='mse',
                  metrics=[keras.metrics.RootMeanSquaredError()])
compile_model(model)

# %%
compile_model(model)
model.summary()
# Out:
# Model: "model_batchnorm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 6)]               0
#
#  batch_normalization (BatchN  (None, 6)                24
#  ormalization)
#
#  dense (Dense)               (None, 100)               700
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 5,825
# Trainable params: 5,813
# Non-trainable params: 12
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,
                    batch_size = 32,
                    epochs = 1000,
                    validation_data=(x_val, y_val),
                    callbacks=[earlystopper],
                    verbose = 2)
# Out:
# Epoch 1/1000
# 75/75 - 0s - loss: 383.5990 - root_mean_squared_error: 19.5857 - val_loss: 340.1628 - val_root_mean_squared_error: 18.4435 - 480ms/epoch - 6ms/step
# Epoch 2/1000
# 75/75 - 0s - loss: 122.3592 - root_mean_squared_error: 11.0616 - val_loss: 164.2305 - val_root_mean_squared_error: 12.8152 - 92ms/epoch - 1ms/step
# Epoch 3/1000
# 75/75 - 0s - loss: 87.1556 - root_mean_squared_error: 9.3357 - val_loss: 135.7104 - val_root_mean_squared_error: 11.6495 - 90ms/epoch - 1ms/step
# Epoch 4/1000
# 75/75 - 0s - loss: 78.1749 - root_mean_squared_error: 8.8417 - val_loss: 118.2399 - val_root_mean_squared_error: 10.8738 - 90ms/epoch - 1ms/step
# Epoch 5/1000
# 75/75 - 0s - loss: 77.4050 - root_mean_squared_error: 8.7980 - val_loss: 107.8973 - val_root_mean_squared_error: 10.3874 - 89ms/epoch - 1ms/step
# Epoch 6/1000
# 75/75 - 0s - loss: 75.9815 - root_mean_squared_error: 8.7167 - val_loss: 96.7487 - val_root_mean_squared_error: 9.8361 - 90ms/epoch - 1ms/step
# Epoch 7/1000
# 75/75 - 0s - loss: 75.2547 - root_mean_squared_error: 8.6749 - val_loss: 88.8292 - val_root_mean_squared_error: 9.4249 - 89ms/epoch - 1ms/step
# Epoch 8/1000
# 75/75 - 0s - loss: 74.7844 - root_mean_squared_error: 8.6478 - val_loss: 80.8121 - val_root_mean_squared_error: 8.9896 - 88ms/epoch - 1ms/step
# Epoch 9/1000
# 75/75 - 0s - loss: 73.9742 - root_mean_squared_error: 8.6008 - val_loss: 76.3795 - val_root_mean_squared_error: 8.7395 - 88ms/epoch - 1ms/step
# Epoch 10/1000
# 75/75 - 0s - loss: 75.2263 - root_mean_squared_error: 8.6733 - val_loss: 74.7558 - val_root_mean_squared_error: 8.6461 - 88ms/epoch - 1ms/step
# Epoch 11/1000
# 75/75 - 0s - loss: 74.3663 - root_mean_squared_error: 8.6236 - val_loss: 73.0094 - val_root_mean_squared_error: 8.5446 - 89ms/epoch - 1ms/step
# Epoch 12/1000
# 75/75 - 0s - loss: 74.0431 - root_mean_squared_error: 8.6048 - val_loss: 73.2861 - val_root_mean_squared_error: 8.5607 - 90ms/epoch - 1ms/step
# Epoch 13/1000
# 75/75 - 0s - loss: 75.0370 - root_mean_squared_error: 8.6624 - val_loss: 72.1345 - val_root_mean_squared_error: 8.4932 - 88ms/epoch - 1ms/step
# Epoch 14/1000
# 75/75 - 0s - loss: 74.0575 - root_mean_squared_error: 8.6057 - val_loss: 71.8101 - val_root_mean_squared_error: 8.4741 - 91ms/epoch - 1ms/step
# Epoch 15/1000
# 75/75 - 0s - loss: 74.7592 - root_mean_squared_error: 8.6463 - val_loss: 71.5584 - val_root_mean_squared_error: 8.4592 - 90ms/epoch - 1ms/step
# Epoch 16/1000
# 75/75 - 0s - loss: 73.4085 - root_mean_squared_error: 8.5679 - val_loss: 71.3496 - val_root_mean_squared_error: 8.4469 - 89ms/epoch - 1ms/step
# Epoch 17/1000
# 75/75 - 0s - loss: 72.9667 - root_mean_squared_error: 8.5421 - val_loss: 70.8685 - val_root_mean_squared_error: 8.4183 - 91ms/epoch - 1ms/step
# Epoch 18/1000
# 75/75 - 0s - loss: 72.7770 - root_mean_squared_error: 8.5309 - val_loss: 70.5242 - val_root_mean_squared_error: 8.3979 - 96ms/epoch - 1ms/step
# Epoch 19/1000
# 75/75 - 0s - loss: 72.4921 - root_mean_squared_error: 8.5142 - val_loss: 70.7432 - val_root_mean_squared_error: 8.4109 - 92ms/epoch - 1ms/step
# Epoch 20/1000
# 75/75 - 0s - loss: 72.9825 - root_mean_squared_error: 8.5430 - val_loss: 69.8020 - val_root_mean_squared_error: 8.3548 - 90ms/epoch - 1ms/step
# Epoch 21/1000
# 75/75 - 0s - loss: 71.8458 - root_mean_squared_error: 8.4762 - val_loss: 69.5324 - val_root_mean_squared_error: 8.3386 - 91ms/epoch - 1ms/step
# Epoch 22/1000
# 75/75 - 0s - loss: 71.6604 - root_mean_squared_error: 8.4652 - val_loss: 69.4498 - val_root_mean_squared_error: 8.3337 - 89ms/epoch - 1ms/step
# Epoch 23/1000
# 75/75 - 0s - loss: 70.7036 - root_mean_squared_error: 8.4085 - val_loss: 69.5272 - val_root_mean_squared_error: 8.3383 - 90ms/epoch - 1ms/step
# Epoch 24/1000
# 75/75 - 0s - loss: 70.6279 - root_mean_squared_error: 8.4040 - val_loss: 69.2034 - val_root_mean_squared_error: 8.3189 - 91ms/epoch - 1ms/step
# Epoch 25/1000
# 75/75 - 0s - loss: 70.5853 - root_mean_squared_error: 8.4015 - val_loss: 68.7465 - val_root_mean_squared_error: 8.2914 - 91ms/epoch - 1ms/step
# Epoch 26/1000
# 75/75 - 0s - loss: 70.8345 - root_mean_squared_error: 8.4163 - val_loss: 67.8547 - val_root_mean_squared_error: 8.2374 - 92ms/epoch - 1ms/step
# Epoch 27/1000
# 75/75 - 0s - loss: 69.8180 - root_mean_squared_error: 8.3557 - val_loss: 67.6595 - val_root_mean_squared_error: 8.2255 - 93ms/epoch - 1ms/step
# Epoch 28/1000
# 75/75 - 0s - loss: 70.9891 - root_mean_squared_error: 8.4255 - val_loss: 68.0223 - val_root_mean_squared_error: 8.2476 - 92ms/epoch - 1ms/step
# Epoch 29/1000
# 75/75 - 0s - loss: 69.6795 - root_mean_squared_error: 8.3474 - val_loss: 66.9578 - val_root_mean_squared_error: 8.1828 - 93ms/epoch - 1ms/step
# Epoch 30/1000
# 75/75 - 0s - loss: 69.0212 - root_mean_squared_error: 8.3079 - val_loss: 66.5826 - val_root_mean_squared_error: 8.1598 - 93ms/epoch - 1ms/step
# Epoch 31/1000
# 75/75 - 0s - loss: 68.3373 - root_mean_squared_error: 8.2666 - val_loss: 66.8438 - val_root_mean_squared_error: 8.1758 - 91ms/epoch - 1ms/step
# Epoch 32/1000
# 75/75 - 0s - loss: 68.2900 - root_mean_squared_error: 8.2638 - val_loss: 65.8869 - val_root_mean_squared_error: 8.1171 - 91ms/epoch - 1ms/step
# Epoch 33/1000
# 75/75 - 0s - loss: 69.0435 - root_mean_squared_error: 8.3092 - val_loss: 66.9651 - val_root_mean_squared_error: 8.1832 - 93ms/epoch - 1ms/step
# Epoch 34/1000
# 75/75 - 0s - loss: 68.3361 - root_mean_squared_error: 8.2666 - val_loss: 65.3942 - val_root_mean_squared_error: 8.0867 - 91ms/epoch - 1ms/step
# Epoch 35/1000
# 75/75 - 0s - loss: 67.8073 - root_mean_squared_error: 8.2345 - val_loss: 65.2976 - val_root_mean_squared_error: 8.0807 - 89ms/epoch - 1ms/step
# Epoch 36/1000
# 75/75 - 0s - loss: 68.3472 - root_mean_squared_error: 8.2672 - val_loss: 66.1507 - val_root_mean_squared_error: 8.1333 - 92ms/epoch - 1ms/step
# Epoch 37/1000
# 75/75 - 0s - loss: 67.5779 - root_mean_squared_error: 8.2206 - val_loss: 64.8497 - val_root_mean_squared_error: 8.0529 - 94ms/epoch - 1ms/step
# Epoch 38/1000
# 75/75 - 0s - loss: 68.2379 - root_mean_squared_error: 8.2606 - val_loss: 65.4829 - val_root_mean_squared_error: 8.0922 - 94ms/epoch - 1ms/step
# Epoch 39/1000
# 75/75 - 0s - loss: 67.2971 - root_mean_squared_error: 8.2035 - val_loss: 64.2511 - val_root_mean_squared_error: 8.0157 - 94ms/epoch - 1ms/step
# Epoch 40/1000
# 75/75 - 0s - loss: 66.4353 - root_mean_squared_error: 8.1508 - val_loss: 64.0590 - val_root_mean_squared_error: 8.0037 - 95ms/epoch - 1ms/step
# Epoch 41/1000
# 75/75 - 0s - loss: 66.5908 - root_mean_squared_error: 8.1603 - val_loss: 65.0464 - val_root_mean_squared_error: 8.0651 - 93ms/epoch - 1ms/step
# Epoch 42/1000
# 75/75 - 0s - loss: 66.3742 - root_mean_squared_error: 8.1470 - val_loss: 63.6803 - val_root_mean_squared_error: 7.9800 - 92ms/epoch - 1ms/step
# Epoch 43/1000
# 75/75 - 0s - loss: 65.9402 - root_mean_squared_error: 8.1204 - val_loss: 64.0073 - val_root_mean_squared_error: 8.0005 - 93ms/epoch - 1ms/step
# Epoch 44/1000
# 75/75 - 0s - loss: 65.7485 - root_mean_squared_error: 8.1085 - val_loss: 63.4908 - val_root_mean_squared_error: 7.9681 - 92ms/epoch - 1ms/step
# Epoch 45/1000
# 75/75 - 0s - loss: 66.0124 - root_mean_squared_error: 8.1248 - val_loss: 63.7382 - val_root_mean_squared_error: 7.9836 - 92ms/epoch - 1ms/step
# Epoch 46/1000
# 75/75 - 0s - loss: 66.6956 - root_mean_squared_error: 8.1667 - val_loss: 64.5435 - val_root_mean_squared_error: 8.0339 - 93ms/epoch - 1ms/step
# Epoch 47/1000
# 75/75 - 0s - loss: 66.8619 - root_mean_squared_error: 8.1769 - val_loss: 64.7715 - val_root_mean_squared_error: 8.0481 - 91ms/epoch - 1ms/step
# Epoch 48/1000
# 75/75 - 0s - loss: 66.6288 - root_mean_squared_error: 8.1626 - val_loss: 63.4059 - val_root_mean_squared_error: 7.9628 - 91ms/epoch - 1ms/step
# Epoch 49/1000
# 75/75 - 0s - loss: 66.2464 - root_mean_squared_error: 8.1392 - val_loss: 63.2131 - val_root_mean_squared_error: 7.9507 - 90ms/epoch - 1ms/step
# Epoch 50/1000
# 75/75 - 0s - loss: 66.1276 - root_mean_squared_error: 8.1319 - val_loss: 63.0370 - val_root_mean_squared_error: 7.9396 - 95ms/epoch - 1ms/step
# Epoch 51/1000
# 75/75 - 0s - loss: 66.4002 - root_mean_squared_error: 8.1486 - val_loss: 63.3646 - val_root_mean_squared_error: 7.9602 - 94ms/epoch - 1ms/step
# Epoch 52/1000
# 75/75 - 0s - loss: 66.6531 - root_mean_squared_error: 8.1641 - val_loss: 63.2263 - val_root_mean_squared_error: 7.9515 - 93ms/epoch - 1ms/step
# Epoch 53/1000
# 75/75 - 0s - loss: 65.6680 - root_mean_squared_error: 8.1036 - val_loss: 62.9327 - val_root_mean_squared_error: 7.9330 - 92ms/epoch - 1ms/step
# Epoch 54/1000
# 75/75 - 0s - loss: 65.6650 - root_mean_squared_error: 8.1034 - val_loss: 62.8761 - val_root_mean_squared_error: 7.9294 - 92ms/epoch - 1ms/step
# Epoch 55/1000
# 75/75 - 0s - loss: 66.3253 - root_mean_squared_error: 8.1440 - val_loss: 63.0180 - val_root_mean_squared_error: 7.9384 - 92ms/epoch - 1ms/step
# Epoch 56/1000
# 75/75 - 0s - loss: 64.9225 - root_mean_squared_error: 8.0574 - val_loss: 62.7344 - val_root_mean_squared_error: 7.9205 - 94ms/epoch - 1ms/step
# Epoch 57/1000
# 75/75 - 0s - loss: 65.5266 - root_mean_squared_error: 8.0948 - val_loss: 62.7924 - val_root_mean_squared_error: 7.9242 - 91ms/epoch - 1ms/step
# Epoch 58/1000
# 75/75 - 0s - loss: 65.5337 - root_mean_squared_error: 8.0953 - val_loss: 62.9266 - val_root_mean_squared_error: 7.9326 - 89ms/epoch - 1ms/step
# Epoch 59/1000
# 75/75 - 0s - loss: 65.5733 - root_mean_squared_error: 8.0977 - val_loss: 62.6768 - val_root_mean_squared_error: 7.9169 - 90ms/epoch - 1ms/step
# Epoch 60/1000
# 75/75 - 0s - loss: 65.2153 - root_mean_squared_error: 8.0756 - val_loss: 62.6982 - val_root_mean_squared_error: 7.9182 - 92ms/epoch - 1ms/step
# Epoch 61/1000
# 75/75 - 0s - loss: 65.8816 - root_mean_squared_error: 8.1167 - val_loss: 63.2053 - val_root_mean_squared_error: 7.9502 - 91ms/epoch - 1ms/step
# Epoch 62/1000
# 75/75 - 0s - loss: 65.2399 - root_mean_squared_error: 8.0771 - val_loss: 62.3148 - val_root_mean_squared_error: 7.8940 - 90ms/epoch - 1ms/step
# Epoch 63/1000
# 75/75 - 0s - loss: 64.9685 - root_mean_squared_error: 8.0603 - val_loss: 62.4873 - val_root_mean_squared_error: 7.9049 - 91ms/epoch - 1ms/step
# Epoch 64/1000
# 75/75 - 0s - loss: 65.1989 - root_mean_squared_error: 8.0746 - val_loss: 62.4016 - val_root_mean_squared_error: 7.8995 - 92ms/epoch - 1ms/step
# Epoch 65/1000
# 75/75 - 0s - loss: 64.9264 - root_mean_squared_error: 8.0577 - val_loss: 62.4054 - val_root_mean_squared_error: 7.8997 - 92ms/epoch - 1ms/step
# Epoch 66/1000
# 75/75 - 0s - loss: 65.7213 - root_mean_squared_error: 8.1069 - val_loss: 62.1369 - val_root_mean_squared_error: 7.8827 - 92ms/epoch - 1ms/step
# Epoch 67/1000
# 75/75 - 0s - loss: 64.5726 - root_mean_squared_error: 8.0357 - val_loss: 62.0654 - val_root_mean_squared_error: 7.8782 - 92ms/epoch - 1ms/step
# Epoch 68/1000
# 75/75 - 0s - loss: 65.0740 - root_mean_squared_error: 8.0668 - val_loss: 62.1797 - val_root_mean_squared_error: 7.8854 - 93ms/epoch - 1ms/step
# Epoch 69/1000
# 75/75 - 0s - loss: 64.7587 - root_mean_squared_error: 8.0473 - val_loss: 62.3810 - val_root_mean_squared_error: 7.8982 - 92ms/epoch - 1ms/step
# Epoch 70/1000
# 75/75 - 0s - loss: 65.1474 - root_mean_squared_error: 8.0714 - val_loss: 62.2851 - val_root_mean_squared_error: 7.8921 - 91ms/epoch - 1ms/step
# Epoch 71/1000
# 75/75 - 0s - loss: 65.8556 - root_mean_squared_error: 8.1151 - val_loss: 63.0351 - val_root_mean_squared_error: 7.9395 - 92ms/epoch - 1ms/step
# Epoch 72/1000
# 75/75 - 0s - loss: 63.9037 - root_mean_squared_error: 7.9940 - val_loss: 62.2820 - val_root_mean_squared_error: 7.8919 - 92ms/epoch - 1ms/step
# Epoch 73/1000
# 75/75 - 0s - loss: 65.0685 - root_mean_squared_error: 8.0665 - val_loss: 61.8821 - val_root_mean_squared_error: 7.8665 - 91ms/epoch - 1ms/step
# Epoch 74/1000
# 75/75 - 0s - loss: 64.9882 - root_mean_squared_error: 8.0615 - val_loss: 62.6689 - val_root_mean_squared_error: 7.9164 - 91ms/epoch - 1ms/step
# Epoch 75/1000
# 75/75 - 0s - loss: 63.8741 - root_mean_squared_error: 7.9921 - val_loss: 61.7117 - val_root_mean_squared_error: 7.8557 - 92ms/epoch - 1ms/step
# Epoch 76/1000
# 75/75 - 0s - loss: 64.0969 - root_mean_squared_error: 8.0061 - val_loss: 62.7539 - val_root_mean_squared_error: 7.9217 - 92ms/epoch - 1ms/step
# Epoch 77/1000
# 75/75 - 0s - loss: 65.0329 - root_mean_squared_error: 8.0643 - val_loss: 61.9663 - val_root_mean_squared_error: 7.8719 - 94ms/epoch - 1ms/step
# Epoch 78/1000
# 75/75 - 0s - loss: 65.3069 - root_mean_squared_error: 8.0813 - val_loss: 62.1716 - val_root_mean_squared_error: 7.8849 - 92ms/epoch - 1ms/step
# Epoch 79/1000
# 75/75 - 0s - loss: 65.6916 - root_mean_squared_error: 8.1050 - val_loss: 61.8453 - val_root_mean_squared_error: 7.8642 - 91ms/epoch - 1ms/step
# Epoch 80/1000
# 75/75 - 0s - loss: 64.2528 - root_mean_squared_error: 8.0158 - val_loss: 61.7569 - val_root_mean_squared_error: 7.8586 - 92ms/epoch - 1ms/step
# Epoch 81/1000
# 75/75 - 0s - loss: 64.4963 - root_mean_squared_error: 8.0310 - val_loss: 61.8101 - val_root_mean_squared_error: 7.8619 - 92ms/epoch - 1ms/step
# Epoch 82/1000
# 75/75 - 0s - loss: 64.9798 - root_mean_squared_error: 8.0610 - val_loss: 61.9492 - val_root_mean_squared_error: 7.8708 - 92ms/epoch - 1ms/step
# Epoch 83/1000
# 75/75 - 0s - loss: 65.2436 - root_mean_squared_error: 8.0774 - val_loss: 61.6052 - val_root_mean_squared_error: 7.8489 - 94ms/epoch - 1ms/step
# Epoch 84/1000
# 75/75 - 0s - loss: 63.7415 - root_mean_squared_error: 7.9838 - val_loss: 61.4593 - val_root_mean_squared_error: 7.8396 - 93ms/epoch - 1ms/step
# Epoch 85/1000
# 75/75 - 0s - loss: 62.8403 - root_mean_squared_error: 7.9272 - val_loss: 61.2969 - val_root_mean_squared_error: 7.8292 - 92ms/epoch - 1ms/step
# Epoch 86/1000
# 75/75 - 0s - loss: 64.2295 - root_mean_squared_error: 8.0143 - val_loss: 61.5551 - val_root_mean_squared_error: 7.8457 - 94ms/epoch - 1ms/step
# Epoch 87/1000
# 75/75 - 0s - loss: 63.9397 - root_mean_squared_error: 7.9962 - val_loss: 61.3427 - val_root_mean_squared_error: 7.8322 - 94ms/epoch - 1ms/step
# Epoch 88/1000
# 75/75 - 0s - loss: 64.1243 - root_mean_squared_error: 8.0078 - val_loss: 61.8679 - val_root_mean_squared_error: 7.8656 - 93ms/epoch - 1ms/step
# Epoch 89/1000
# 75/75 - 0s - loss: 64.3223 - root_mean_squared_error: 8.0201 - val_loss: 61.2552 - val_root_mean_squared_error: 7.8266 - 93ms/epoch - 1ms/step
# Epoch 90/1000
# 75/75 - 0s - loss: 65.4078 - root_mean_squared_error: 8.0875 - val_loss: 61.2057 - val_root_mean_squared_error: 7.8234 - 93ms/epoch - 1ms/step
# Epoch 91/1000
# 75/75 - 0s - loss: 63.6922 - root_mean_squared_error: 7.9807 - val_loss: 61.6624 - val_root_mean_squared_error: 7.8525 - 93ms/epoch - 1ms/step
# Epoch 92/1000
# 75/75 - 0s - loss: 64.9425 - root_mean_squared_error: 8.0587 - val_loss: 61.4214 - val_root_mean_squared_error: 7.8372 - 93ms/epoch - 1ms/step
# Epoch 93/1000
# 75/75 - 0s - loss: 63.2215 - root_mean_squared_error: 7.9512 - val_loss: 61.1981 - val_root_mean_squared_error: 7.8229 - 93ms/epoch - 1ms/step
# Epoch 94/1000
# 75/75 - 0s - loss: 63.4095 - root_mean_squared_error: 7.9630 - val_loss: 61.3484 - val_root_mean_squared_error: 7.8325 - 93ms/epoch - 1ms/step
# Epoch 95/1000
# 75/75 - 0s - loss: 64.5886 - root_mean_squared_error: 8.0367 - val_loss: 60.9588 - val_root_mean_squared_error: 7.8076 - 91ms/epoch - 1ms/step
# Epoch 96/1000
# 75/75 - 0s - loss: 65.4997 - root_mean_squared_error: 8.0932 - val_loss: 60.9406 - val_root_mean_squared_error: 7.8064 - 91ms/epoch - 1ms/step
# Epoch 97/1000
# 75/75 - 0s - loss: 64.2630 - root_mean_squared_error: 8.0164 - val_loss: 60.9086 - val_root_mean_squared_error: 7.8044 - 92ms/epoch - 1ms/step
# Epoch 98/1000
# 75/75 - 0s - loss: 63.9244 - root_mean_squared_error: 7.9953 - val_loss: 60.7873 - val_root_mean_squared_error: 7.7966 - 92ms/epoch - 1ms/step
# Epoch 99/1000
# 75/75 - 0s - loss: 64.1770 - root_mean_squared_error: 8.0111 - val_loss: 61.4107 - val_root_mean_squared_error: 7.8365 - 94ms/epoch - 1ms/step
# Epoch 100/1000
# 75/75 - 0s - loss: 65.0981 - root_mean_squared_error: 8.0683 - val_loss: 60.7722 - val_root_mean_squared_error: 7.7957 - 92ms/epoch - 1ms/step
# Epoch 101/1000
# 75/75 - 0s - loss: 64.1836 - root_mean_squared_error: 8.0115 - val_loss: 60.8795 - val_root_mean_squared_error: 7.8025 - 95ms/epoch - 1ms/step
# Epoch 102/1000
# 75/75 - 0s - loss: 63.7891 - root_mean_squared_error: 7.9868 - val_loss: 60.6492 - val_root_mean_squared_error: 7.7878 - 93ms/epoch - 1ms/step
# Epoch 103/1000
# 75/75 - 0s - loss: 63.3238 - root_mean_squared_error: 7.9576 - val_loss: 60.7371 - val_root_mean_squared_error: 7.7934 - 93ms/epoch - 1ms/step
# Epoch 104/1000
# 75/75 - 0s - loss: 63.7101 - root_mean_squared_error: 7.9819 - val_loss: 61.2933 - val_root_mean_squared_error: 7.8290 - 93ms/epoch - 1ms/step
# Epoch 105/1000
# 75/75 - 0s - loss: 64.5570 - root_mean_squared_error: 8.0347 - val_loss: 60.9446 - val_root_mean_squared_error: 7.8067 - 93ms/epoch - 1ms/step
# Epoch 106/1000
# 75/75 - 0s - loss: 64.2539 - root_mean_squared_error: 8.0159 - val_loss: 60.5362 - val_root_mean_squared_error: 7.7805 - 93ms/epoch - 1ms/step
# Epoch 107/1000
# 75/75 - 0s - loss: 64.4807 - root_mean_squared_error: 8.0300 - val_loss: 60.5425 - val_root_mean_squared_error: 7.7809 - 92ms/epoch - 1ms/step
# Epoch 108/1000
# 75/75 - 0s - loss: 63.4694 - root_mean_squared_error: 7.9668 - val_loss: 60.4977 - val_root_mean_squared_error: 7.7780 - 95ms/epoch - 1ms/step
# Epoch 109/1000
# 75/75 - 0s - loss: 64.1172 - root_mean_squared_error: 8.0073 - val_loss: 60.7767 - val_root_mean_squared_error: 7.7959 - 89ms/epoch - 1ms/step
# Epoch 110/1000
# 75/75 - 0s - loss: 65.9877 - root_mean_squared_error: 8.1233 - val_loss: 60.6659 - val_root_mean_squared_error: 7.7888 - 92ms/epoch - 1ms/step
# Epoch 111/1000
# 75/75 - 0s - loss: 63.6381 - root_mean_squared_error: 7.9773 - val_loss: 60.3257 - val_root_mean_squared_error: 7.7670 - 94ms/epoch - 1ms/step
# Epoch 112/1000
# 75/75 - 0s - loss: 65.4622 - root_mean_squared_error: 8.0909 - val_loss: 61.1915 - val_root_mean_squared_error: 7.8225 - 94ms/epoch - 1ms/step
# Epoch 113/1000
# 75/75 - 0s - loss: 63.0186 - root_mean_squared_error: 7.9384 - val_loss: 60.7005 - val_root_mean_squared_error: 7.7911 - 94ms/epoch - 1ms/step
# Epoch 114/1000
# 75/75 - 0s - loss: 63.3307 - root_mean_squared_error: 7.9581 - val_loss: 60.4563 - val_root_mean_squared_error: 7.7754 - 90ms/epoch - 1ms/step
# Epoch 115/1000
# 75/75 - 0s - loss: 62.9191 - root_mean_squared_error: 7.9322 - val_loss: 60.6221 - val_root_mean_squared_error: 7.7860 - 92ms/epoch - 1ms/step
# Epoch 116/1000
# 75/75 - 0s - loss: 63.3998 - root_mean_squared_error: 7.9624 - val_loss: 60.4407 - val_root_mean_squared_error: 7.7744 - 90ms/epoch - 1ms/step
# Epoch 117/1000
# 75/75 - 0s - loss: 63.9152 - root_mean_squared_error: 7.9947 - val_loss: 60.4691 - val_root_mean_squared_error: 7.7762 - 89ms/epoch - 1ms/step
# Epoch 118/1000
# 75/75 - 0s - loss: 61.7615 - root_mean_squared_error: 7.8588 - val_loss: 61.7412 - val_root_mean_squared_error: 7.8576 - 91ms/epoch - 1ms/step
# Epoch 119/1000
# 75/75 - 0s - loss: 63.8715 - root_mean_squared_error: 7.9920 - val_loss: 61.0091 - val_root_mean_squared_error: 7.8108 - 92ms/epoch - 1ms/step
# Epoch 120/1000
# 75/75 - 0s - loss: 63.0999 - root_mean_squared_error: 7.9435 - val_loss: 60.6414 - val_root_mean_squared_error: 7.7873 - 90ms/epoch - 1ms/step
# Epoch 121/1000
# 75/75 - 0s - loss: 64.0090 - root_mean_squared_error: 8.0006 - val_loss: 60.0673 - val_root_mean_squared_error: 7.7503 - 92ms/epoch - 1ms/step
# Epoch 122/1000
# 75/75 - 0s - loss: 63.5521 - root_mean_squared_error: 7.9720 - val_loss: 60.2795 - val_root_mean_squared_error: 7.7640 - 93ms/epoch - 1ms/step
# Epoch 123/1000
# 75/75 - 0s - loss: 63.3548 - root_mean_squared_error: 7.9596 - val_loss: 61.7578 - val_root_mean_squared_error: 7.8586 - 95ms/epoch - 1ms/step
# Epoch 124/1000
# 75/75 - 0s - loss: 62.8650 - root_mean_squared_error: 7.9287 - val_loss: 60.3536 - val_root_mean_squared_error: 7.7688 - 93ms/epoch - 1ms/step
# Epoch 125/1000
# 75/75 - 0s - loss: 63.6999 - root_mean_squared_error: 7.9812 - val_loss: 60.0864 - val_root_mean_squared_error: 7.7515 - 94ms/epoch - 1ms/step
# Epoch 126/1000
# 75/75 - 0s - loss: 63.3441 - root_mean_squared_error: 7.9589 - val_loss: 60.4456 - val_root_mean_squared_error: 7.7747 - 94ms/epoch - 1ms/step
# Epoch 127/1000
# 75/75 - 0s - loss: 64.6043 - root_mean_squared_error: 8.0377 - val_loss: 59.9549 - val_root_mean_squared_error: 7.7431 - 94ms/epoch - 1ms/step
# Epoch 128/1000
# 75/75 - 0s - loss: 63.5814 - root_mean_squared_error: 7.9738 - val_loss: 60.0717 - val_root_mean_squared_error: 7.7506 - 92ms/epoch - 1ms/step
# Epoch 129/1000
# 75/75 - 0s - loss: 63.3225 - root_mean_squared_error: 7.9575 - val_loss: 59.8635 - val_root_mean_squared_error: 7.7371 - 92ms/epoch - 1ms/step
# Epoch 130/1000
# 75/75 - 0s - loss: 63.7319 - root_mean_squared_error: 7.9832 - val_loss: 60.1500 - val_root_mean_squared_error: 7.7556 - 91ms/epoch - 1ms/step
# Epoch 131/1000
# 75/75 - 0s - loss: 62.3964 - root_mean_squared_error: 7.8991 - val_loss: 60.0053 - val_root_mean_squared_error: 7.7463 - 93ms/epoch - 1ms/step
# Epoch 132/1000
# 75/75 - 0s - loss: 63.8110 - root_mean_squared_error: 7.9882 - val_loss: 61.0109 - val_root_mean_squared_error: 7.8109 - 92ms/epoch - 1ms/step
# Epoch 133/1000
# 75/75 - 0s - loss: 62.9375 - root_mean_squared_error: 7.9333 - val_loss: 60.1618 - val_root_mean_squared_error: 7.7564 - 93ms/epoch - 1ms/step
# Epoch 134/1000
# 75/75 - 0s - loss: 63.7046 - root_mean_squared_error: 7.9815 - val_loss: 59.7460 - val_root_mean_squared_error: 7.7296 - 93ms/epoch - 1ms/step
# Epoch 135/1000
# 75/75 - 0s - loss: 63.2220 - root_mean_squared_error: 7.9512 - val_loss: 59.7987 - val_root_mean_squared_error: 7.7330 - 93ms/epoch - 1ms/step
# Epoch 136/1000
# 75/75 - 0s - loss: 63.9418 - root_mean_squared_error: 7.9964 - val_loss: 59.7887 - val_root_mean_squared_error: 7.7323 - 93ms/epoch - 1ms/step
# Epoch 137/1000
# 75/75 - 0s - loss: 62.9529 - root_mean_squared_error: 7.9343 - val_loss: 59.8604 - val_root_mean_squared_error: 7.7370 - 92ms/epoch - 1ms/step
# Epoch 138/1000
# 75/75 - 0s - loss: 63.5341 - root_mean_squared_error: 7.9708 - val_loss: 60.0652 - val_root_mean_squared_error: 7.7502 - 92ms/epoch - 1ms/step
# Epoch 139/1000
# 75/75 - 0s - loss: 63.6843 - root_mean_squared_error: 7.9802 - val_loss: 60.1194 - val_root_mean_squared_error: 7.7537 - 93ms/epoch - 1ms/step
# Epoch 140/1000
# 75/75 - 0s - loss: 63.3781 - root_mean_squared_error: 7.9610 - val_loss: 60.2021 - val_root_mean_squared_error: 7.7590 - 91ms/epoch - 1ms/step
# Epoch 141/1000
# 75/75 - 0s - loss: 62.3120 - root_mean_squared_error: 7.8938 - val_loss: 59.5470 - val_root_mean_squared_error: 7.7167 - 93ms/epoch - 1ms/step
# Epoch 142/1000
# 75/75 - 0s - loss: 63.8713 - root_mean_squared_error: 7.9920 - val_loss: 59.5589 - val_root_mean_squared_error: 7.7174 - 93ms/epoch - 1ms/step
# Epoch 143/1000
# 75/75 - 0s - loss: 63.1728 - root_mean_squared_error: 7.9481 - val_loss: 59.5808 - val_root_mean_squared_error: 7.7189 - 92ms/epoch - 1ms/step
# Epoch 144/1000
# 75/75 - 0s - loss: 63.3368 - root_mean_squared_error: 7.9584 - val_loss: 61.6116 - val_root_mean_squared_error: 7.8493 - 93ms/epoch - 1ms/step
# Epoch 145/1000
# 75/75 - 0s - loss: 63.2044 - root_mean_squared_error: 7.9501 - val_loss: 59.4000 - val_root_mean_squared_error: 7.7071 - 92ms/epoch - 1ms/step
# Epoch 146/1000
# 75/75 - 0s - loss: 62.4656 - root_mean_squared_error: 7.9035 - val_loss: 59.4911 - val_root_mean_squared_error: 7.7130 - 91ms/epoch - 1ms/step
# Epoch 147/1000
# 75/75 - 0s - loss: 62.3392 - root_mean_squared_error: 7.8955 - val_loss: 59.8883 - val_root_mean_squared_error: 7.7388 - 92ms/epoch - 1ms/step
# Epoch 148/1000
# 75/75 - 0s - loss: 62.7679 - root_mean_squared_error: 7.9226 - val_loss: 59.3996 - val_root_mean_squared_error: 7.7071 - 92ms/epoch - 1ms/step
# Epoch 149/1000
# 75/75 - 0s - loss: 63.4043 - root_mean_squared_error: 7.9627 - val_loss: 64.2034 - val_root_mean_squared_error: 8.0127 - 92ms/epoch - 1ms/step
# Epoch 150/1000
# 75/75 - 0s - loss: 62.3721 - root_mean_squared_error: 7.8976 - val_loss: 59.3095 - val_root_mean_squared_error: 7.7013 - 91ms/epoch - 1ms/step
# Epoch 151/1000
# 75/75 - 0s - loss: 63.2290 - root_mean_squared_error: 7.9517 - val_loss: 60.4444 - val_root_mean_squared_error: 7.7746 - 92ms/epoch - 1ms/step
# Epoch 152/1000
# 75/75 - 0s - loss: 62.9513 - root_mean_squared_error: 7.9342 - val_loss: 59.3108 - val_root_mean_squared_error: 7.7014 - 93ms/epoch - 1ms/step
# Epoch 153/1000
# 75/75 - 0s - loss: 63.1734 - root_mean_squared_error: 7.9482 - val_loss: 59.5300 - val_root_mean_squared_error: 7.7156 - 92ms/epoch - 1ms/step
# Epoch 154/1000
# 75/75 - 0s - loss: 63.9453 - root_mean_squared_error: 7.9966 - val_loss: 60.3494 - val_root_mean_squared_error: 7.7685 - 92ms/epoch - 1ms/step
# Epoch 155/1000
# 75/75 - 0s - loss: 62.6055 - root_mean_squared_error: 7.9124 - val_loss: 59.5363 - val_root_mean_squared_error: 7.7160 - 92ms/epoch - 1ms/step
# Epoch 156/1000
# 75/75 - 0s - loss: 63.2175 - root_mean_squared_error: 7.9509 - val_loss: 59.3002 - val_root_mean_squared_error: 7.7007 - 92ms/epoch - 1ms/step
# Epoch 157/1000
# 75/75 - 0s - loss: 63.6078 - root_mean_squared_error: 7.9754 - val_loss: 59.4719 - val_root_mean_squared_error: 7.7118 - 92ms/epoch - 1ms/step
# Epoch 158/1000
# 75/75 - 0s - loss: 63.9142 - root_mean_squared_error: 7.9946 - val_loss: 59.4333 - val_root_mean_squared_error: 7.7093 - 93ms/epoch - 1ms/step
# Epoch 159/1000
# 75/75 - 0s - loss: 63.7838 - root_mean_squared_error: 7.9865 - val_loss: 59.3138 - val_root_mean_squared_error: 7.7015 - 93ms/epoch - 1ms/step
# Epoch 160/1000
# 75/75 - 0s - loss: 63.6560 - root_mean_squared_error: 7.9785 - val_loss: 59.3905 - val_root_mean_squared_error: 7.7065 - 93ms/epoch - 1ms/step
# Epoch 161/1000
# 75/75 - 0s - loss: 61.6375 - root_mean_squared_error: 7.8510 - val_loss: 59.6121 - val_root_mean_squared_error: 7.7209 - 95ms/epoch - 1ms/step
# Epoch 162/1000
# 75/75 - 0s - loss: 62.7063 - root_mean_squared_error: 7.9187 - val_loss: 59.3184 - val_root_mean_squared_error: 7.7018 - 91ms/epoch - 1ms/step
# Epoch 163/1000
# 75/75 - 0s - loss: 62.0652 - root_mean_squared_error: 7.8781 - val_loss: 59.1338 - val_root_mean_squared_error: 7.6899 - 93ms/epoch - 1ms/step
# Epoch 164/1000
# 75/75 - 0s - loss: 62.6999 - root_mean_squared_error: 7.9183 - val_loss: 60.4779 - val_root_mean_squared_error: 7.7768 - 94ms/epoch - 1ms/step
# Epoch 165/1000
# 75/75 - 0s - loss: 62.0721 - root_mean_squared_error: 7.8786 - val_loss: 59.1532 - val_root_mean_squared_error: 7.6911 - 93ms/epoch - 1ms/step
# Epoch 166/1000
# 75/75 - 0s - loss: 62.0847 - root_mean_squared_error: 7.8794 - val_loss: 59.2134 - val_root_mean_squared_error: 7.6950 - 94ms/epoch - 1ms/step
# Epoch 167/1000
# 75/75 - 0s - loss: 63.4459 - root_mean_squared_error: 7.9653 - val_loss: 59.5825 - val_root_mean_squared_error: 7.7190 - 93ms/epoch - 1ms/step
# Epoch 168/1000
# 75/75 - 0s - loss: 61.2145 - root_mean_squared_error: 7.8240 - val_loss: 58.8893 - val_root_mean_squared_error: 7.6739 - 93ms/epoch - 1ms/step
# Epoch 169/1000
# 75/75 - 0s - loss: 65.5678 - root_mean_squared_error: 8.0974 - val_loss: 59.0862 - val_root_mean_squared_error: 7.6868 - 91ms/epoch - 1ms/step
# Epoch 170/1000
# 75/75 - 0s - loss: 62.8969 - root_mean_squared_error: 7.9308 - val_loss: 59.3916 - val_root_mean_squared_error: 7.7066 - 92ms/epoch - 1ms/step
# Epoch 171/1000
# 75/75 - 0s - loss: 63.6084 - root_mean_squared_error: 7.9755 - val_loss: 58.9859 - val_root_mean_squared_error: 7.6802 - 92ms/epoch - 1ms/step
# Epoch 172/1000
# 75/75 - 0s - loss: 61.2143 - root_mean_squared_error: 7.8240 - val_loss: 59.0162 - val_root_mean_squared_error: 7.6822 - 92ms/epoch - 1ms/step
# Epoch 173/1000
# 75/75 - 0s - loss: 61.2279 - root_mean_squared_error: 7.8248 - val_loss: 58.8722 - val_root_mean_squared_error: 7.6728 - 92ms/epoch - 1ms/step
# Epoch 174/1000
# 75/75 - 0s - loss: 62.5054 - root_mean_squared_error: 7.9060 - val_loss: 60.4172 - val_root_mean_squared_error: 7.7729 - 93ms/epoch - 1ms/step
# Epoch 175/1000
# 75/75 - 0s - loss: 61.9979 - root_mean_squared_error: 7.8739 - val_loss: 58.7333 - val_root_mean_squared_error: 7.6638 - 92ms/epoch - 1ms/step
# Epoch 176/1000
# 75/75 - 0s - loss: 62.4126 - root_mean_squared_error: 7.9002 - val_loss: 59.2625 - val_root_mean_squared_error: 7.6982 - 95ms/epoch - 1ms/step
# Epoch 177/1000
# 75/75 - 0s - loss: 62.1710 - root_mean_squared_error: 7.8849 - val_loss: 58.8438 - val_root_mean_squared_error: 7.6710 - 92ms/epoch - 1ms/step
# Epoch 178/1000
# 75/75 - 0s - loss: 64.2759 - root_mean_squared_error: 8.0172 - val_loss: 58.6464 - val_root_mean_squared_error: 7.6581 - 91ms/epoch - 1ms/step
# Epoch 179/1000
# 75/75 - 0s - loss: 62.6596 - root_mean_squared_error: 7.9158 - val_loss: 60.0123 - val_root_mean_squared_error: 7.7468 - 92ms/epoch - 1ms/step
# Epoch 180/1000
# 75/75 - 0s - loss: 64.0226 - root_mean_squared_error: 8.0014 - val_loss: 59.1994 - val_root_mean_squared_error: 7.6941 - 92ms/epoch - 1ms/step
# Epoch 181/1000
# 75/75 - 0s - loss: 65.2180 - root_mean_squared_error: 8.0758 - val_loss: 58.5755 - val_root_mean_squared_error: 7.6535 - 92ms/epoch - 1ms/step
# Epoch 182/1000
# 75/75 - 0s - loss: 62.6245 - root_mean_squared_error: 7.9136 - val_loss: 58.7011 - val_root_mean_squared_error: 7.6617 - 92ms/epoch - 1ms/step
# Epoch 183/1000
# 75/75 - 0s - loss: 62.4164 - root_mean_squared_error: 7.9004 - val_loss: 58.6375 - val_root_mean_squared_error: 7.6575 - 91ms/epoch - 1ms/step
# Epoch 184/1000
# 75/75 - 0s - loss: 61.1012 - root_mean_squared_error: 7.8167 - val_loss: 58.7939 - val_root_mean_squared_error: 7.6677 - 94ms/epoch - 1ms/step
# Epoch 185/1000
# 75/75 - 0s - loss: 60.7580 - root_mean_squared_error: 7.7947 - val_loss: 58.8195 - val_root_mean_squared_error: 7.6694 - 94ms/epoch - 1ms/step
# Epoch 186/1000
# 75/75 - 0s - loss: 62.7698 - root_mean_squared_error: 7.9227 - val_loss: 58.9679 - val_root_mean_squared_error: 7.6791 - 93ms/epoch - 1ms/step
# Epoch 187/1000
# 75/75 - 0s - loss: 62.5550 - root_mean_squared_error: 7.9092 - val_loss: 58.4641 - val_root_mean_squared_error: 7.6462 - 94ms/epoch - 1ms/step
# Epoch 188/1000
# 75/75 - 0s - loss: 61.7601 - root_mean_squared_error: 7.8588 - val_loss: 59.1479 - val_root_mean_squared_error: 7.6908 - 92ms/epoch - 1ms/step
# Epoch 189/1000
# 75/75 - 0s - loss: 61.8824 - root_mean_squared_error: 7.8665 - val_loss: 58.4804 - val_root_mean_squared_error: 7.6472 - 96ms/epoch - 1ms/step
# Epoch 190/1000
# 75/75 - 0s - loss: 62.0649 - root_mean_squared_error: 7.8781 - val_loss: 59.4293 - val_root_mean_squared_error: 7.7090 - 93ms/epoch - 1ms/step
# Epoch 191/1000
# 75/75 - 0s - loss: 63.0463 - root_mean_squared_error: 7.9402 - val_loss: 59.3453 - val_root_mean_squared_error: 7.7036 - 91ms/epoch - 1ms/step
# Epoch 192/1000
# 75/75 - 0s - loss: 63.8646 - root_mean_squared_error: 7.9915 - val_loss: 58.2697 - val_root_mean_squared_error: 7.6335 - 95ms/epoch - 1ms/step
# Epoch 193/1000
# 75/75 - 0s - loss: 62.0891 - root_mean_squared_error: 7.8797 - val_loss: 58.5120 - val_root_mean_squared_error: 7.6493 - 92ms/epoch - 1ms/step
# Epoch 194/1000
# 75/75 - 0s - loss: 61.8957 - root_mean_squared_error: 7.8674 - val_loss: 59.6836 - val_root_mean_squared_error: 7.7255 - 92ms/epoch - 1ms/step
# Epoch 195/1000
# 75/75 - 0s - loss: 61.8580 - root_mean_squared_error: 7.8650 - val_loss: 58.1542 - val_root_mean_squared_error: 7.6259 - 91ms/epoch - 1ms/step
# Epoch 196/1000
# 75/75 - 0s - loss: 63.8768 - root_mean_squared_error: 7.9923 - val_loss: 59.2765 - val_root_mean_squared_error: 7.6991 - 91ms/epoch - 1ms/step
# Epoch 197/1000
# 75/75 - 0s - loss: 62.9852 - root_mean_squared_error: 7.9363 - val_loss: 58.9121 - val_root_mean_squared_error: 7.6754 - 91ms/epoch - 1ms/step
# Epoch 198/1000
# 75/75 - 0s - loss: 61.3305 - root_mean_squared_error: 7.8314 - val_loss: 58.1370 - val_root_mean_squared_error: 7.6248 - 91ms/epoch - 1ms/step
# Epoch 199/1000
# 75/75 - 0s - loss: 63.0303 - root_mean_squared_error: 7.9392 - val_loss: 58.1031 - val_root_mean_squared_error: 7.6225 - 93ms/epoch - 1ms/step
# Epoch 200/1000
# 75/75 - 0s - loss: 61.5516 - root_mean_squared_error: 7.8455 - val_loss: 58.8759 - val_root_mean_squared_error: 7.6731 - 93ms/epoch - 1ms/step
# Epoch 201/1000
# 75/75 - 0s - loss: 63.0166 - root_mean_squared_error: 7.9383 - val_loss: 60.0975 - val_root_mean_squared_error: 7.7523 - 91ms/epoch - 1ms/step
# Epoch 202/1000
# 75/75 - 0s - loss: 62.8579 - root_mean_squared_error: 7.9283 - val_loss: 58.0558 - val_root_mean_squared_error: 7.6194 - 92ms/epoch - 1ms/step
# Epoch 203/1000
# 75/75 - 0s - loss: 63.8495 - root_mean_squared_error: 7.9906 - val_loss: 58.8674 - val_root_mean_squared_error: 7.6725 - 91ms/epoch - 1ms/step
# Epoch 204/1000
# 75/75 - 0s - loss: 61.5925 - root_mean_squared_error: 7.8481 - val_loss: 58.3787 - val_root_mean_squared_error: 7.6406 - 93ms/epoch - 1ms/step
# Epoch 205/1000
# 75/75 - 0s - loss: 62.2916 - root_mean_squared_error: 7.8925 - val_loss: 58.1126 - val_root_mean_squared_error: 7.6232 - 92ms/epoch - 1ms/step
# Epoch 206/1000
# 75/75 - 0s - loss: 62.1207 - root_mean_squared_error: 7.8817 - val_loss: 58.2940 - val_root_mean_squared_error: 7.6351 - 92ms/epoch - 1ms/step
# Epoch 207/1000
# 75/75 - 0s - loss: 60.9334 - root_mean_squared_error: 7.8060 - val_loss: 58.7082 - val_root_mean_squared_error: 7.6621 - 91ms/epoch - 1ms/step
# Epoch 208/1000
# 75/75 - 0s - loss: 61.3529 - root_mean_squared_error: 7.8328 - val_loss: 57.9046 - val_root_mean_squared_error: 7.6095 - 92ms/epoch - 1ms/step
# Epoch 209/1000
# 75/75 - 0s - loss: 62.0750 - root_mean_squared_error: 7.8788 - val_loss: 58.0674 - val_root_mean_squared_error: 7.6202 - 92ms/epoch - 1ms/step
# Epoch 210/1000
# 75/75 - 0s - loss: 62.1677 - root_mean_squared_error: 7.8846 - val_loss: 58.0290 - val_root_mean_squared_error: 7.6177 - 93ms/epoch - 1ms/step
# Epoch 211/1000
# 75/75 - 0s - loss: 61.9663 - root_mean_squared_error: 7.8719 - val_loss: 60.1647 - val_root_mean_squared_error: 7.7566 - 92ms/epoch - 1ms/step
# Epoch 212/1000
# 75/75 - 0s - loss: 62.7355 - root_mean_squared_error: 7.9206 - val_loss: 57.8892 - val_root_mean_squared_error: 7.6085 - 91ms/epoch - 1ms/step
# Epoch 213/1000
# 75/75 - 0s - loss: 62.2306 - root_mean_squared_error: 7.8886 - val_loss: 58.6689 - val_root_mean_squared_error: 7.6596 - 93ms/epoch - 1ms/step
# Epoch 214/1000
# 75/75 - 0s - loss: 62.0363 - root_mean_squared_error: 7.8763 - val_loss: 58.0921 - val_root_mean_squared_error: 7.6218 - 96ms/epoch - 1ms/step
# Epoch 215/1000
# 75/75 - 0s - loss: 60.7805 - root_mean_squared_error: 7.7962 - val_loss: 57.6129 - val_root_mean_squared_error: 7.5903 - 93ms/epoch - 1ms/step
# Epoch 216/1000
# 75/75 - 0s - loss: 60.0487 - root_mean_squared_error: 7.7491 - val_loss: 59.4241 - val_root_mean_squared_error: 7.7087 - 91ms/epoch - 1ms/step
# Epoch 217/1000
# 75/75 - 0s - loss: 60.2337 - root_mean_squared_error: 7.7610 - val_loss: 57.6149 - val_root_mean_squared_error: 7.5904 - 96ms/epoch - 1ms/step
# Epoch 218/1000
# 75/75 - 0s - loss: 61.8313 - root_mean_squared_error: 7.8633 - val_loss: 58.2306 - val_root_mean_squared_error: 7.6309 - 91ms/epoch - 1ms/step
# Epoch 219/1000
# 75/75 - 0s - loss: 61.1517 - root_mean_squared_error: 7.8200 - val_loss: 58.2153 - val_root_mean_squared_error: 7.6299 - 94ms/epoch - 1ms/step
# Epoch 220/1000
# 75/75 - 0s - loss: 60.6777 - root_mean_squared_error: 7.7896 - val_loss: 57.4275 - val_root_mean_squared_error: 7.5781 - 93ms/epoch - 1ms/step
# Epoch 221/1000
# 75/75 - 0s - loss: 62.5651 - root_mean_squared_error: 7.9098 - val_loss: 57.3940 - val_root_mean_squared_error: 7.5759 - 93ms/epoch - 1ms/step
# Epoch 222/1000
# 75/75 - 0s - loss: 63.5484 - root_mean_squared_error: 7.9717 - val_loss: 57.5718 - val_root_mean_squared_error: 7.5876 - 93ms/epoch - 1ms/step
# Epoch 223/1000
# 75/75 - 0s - loss: 60.8531 - root_mean_squared_error: 7.8008 - val_loss: 57.6043 - val_root_mean_squared_error: 7.5898 - 91ms/epoch - 1ms/step
# Epoch 224/1000
# 75/75 - 0s - loss: 59.9050 - root_mean_squared_error: 7.7398 - val_loss: 57.4083 - val_root_mean_squared_error: 7.5768 - 91ms/epoch - 1ms/step
# Epoch 225/1000
# 75/75 - 0s - loss: 62.7355 - root_mean_squared_error: 7.9206 - val_loss: 57.2856 - val_root_mean_squared_error: 7.5687 - 94ms/epoch - 1ms/step
# Epoch 226/1000
# 75/75 - 0s - loss: 61.1360 - root_mean_squared_error: 7.8190 - val_loss: 57.7794 - val_root_mean_squared_error: 7.6013 - 91ms/epoch - 1ms/step
# Epoch 227/1000
# 75/75 - 0s - loss: 60.5951 - root_mean_squared_error: 7.7843 - val_loss: 57.5765 - val_root_mean_squared_error: 7.5879 - 91ms/epoch - 1ms/step
# Epoch 228/1000
# 75/75 - 0s - loss: 61.0823 - root_mean_squared_error: 7.8155 - val_loss: 57.5624 - val_root_mean_squared_error: 7.5870 - 92ms/epoch - 1ms/step
# Epoch 229/1000
# 75/75 - 0s - loss: 60.9101 - root_mean_squared_error: 7.8045 - val_loss: 57.8940 - val_root_mean_squared_error: 7.6088 - 93ms/epoch - 1ms/step
# Epoch 230/1000
# 75/75 - 0s - loss: 61.4586 - root_mean_squared_error: 7.8396 - val_loss: 57.4660 - val_root_mean_squared_error: 7.5806 - 94ms/epoch - 1ms/step
# Epoch 231/1000
# 75/75 - 0s - loss: 61.3088 - root_mean_squared_error: 7.8300 - val_loss: 57.7792 - val_root_mean_squared_error: 7.6013 - 92ms/epoch - 1ms/step
# Epoch 232/1000
# 75/75 - 0s - loss: 62.3824 - root_mean_squared_error: 7.8983 - val_loss: 57.6677 - val_root_mean_squared_error: 7.5939 - 92ms/epoch - 1ms/step
# Epoch 233/1000
# 75/75 - 0s - loss: 61.6446 - root_mean_squared_error: 7.8514 - val_loss: 57.3352 - val_root_mean_squared_error: 7.5720 - 93ms/epoch - 1ms/step
# Epoch 234/1000
# 75/75 - 0s - loss: 60.5630 - root_mean_squared_error: 7.7822 - val_loss: 58.7204 - val_root_mean_squared_error: 7.6629 - 93ms/epoch - 1ms/step
# Epoch 235/1000
# 75/75 - 0s - loss: 60.7471 - root_mean_squared_error: 7.7940 - val_loss: 57.1413 - val_root_mean_squared_error: 7.5592 - 92ms/epoch - 1ms/step
# Epoch 236/1000
# 75/75 - 0s - loss: 60.9286 - root_mean_squared_error: 7.8057 - val_loss: 57.2220 - val_root_mean_squared_error: 7.5645 - 92ms/epoch - 1ms/step
# Epoch 237/1000
# 75/75 - 0s - loss: 60.3611 - root_mean_squared_error: 7.7692 - val_loss: 58.9987 - val_root_mean_squared_error: 7.6811 - 92ms/epoch - 1ms/step
# Epoch 238/1000
# 75/75 - 0s - loss: 63.1506 - root_mean_squared_error: 7.9467 - val_loss: 56.9409 - val_root_mean_squared_error: 7.5459 - 90ms/epoch - 1ms/step
# Epoch 239/1000
# 75/75 - 0s - loss: 63.2912 - root_mean_squared_error: 7.9556 - val_loss: 57.2994 - val_root_mean_squared_error: 7.5696 - 91ms/epoch - 1ms/step
# Epoch 240/1000
# 75/75 - 0s - loss: 62.2976 - root_mean_squared_error: 7.8929 - val_loss: 58.6682 - val_root_mean_squared_error: 7.6595 - 90ms/epoch - 1ms/step
# Epoch 241/1000
# 75/75 - 0s - loss: 61.0202 - root_mean_squared_error: 7.8115 - val_loss: 56.9383 - val_root_mean_squared_error: 7.5457 - 90ms/epoch - 1ms/step
# Epoch 242/1000
# 75/75 - 0s - loss: 60.7663 - root_mean_squared_error: 7.7953 - val_loss: 57.3111 - val_root_mean_squared_error: 7.5704 - 89ms/epoch - 1ms/step
# Epoch 243/1000
# 75/75 - 0s - loss: 59.9537 - root_mean_squared_error: 7.7430 - val_loss: 58.1105 - val_root_mean_squared_error: 7.6230 - 90ms/epoch - 1ms/step
# Epoch 244/1000
# 75/75 - 0s - loss: 62.6888 - root_mean_squared_error: 7.9176 - val_loss: 57.0382 - val_root_mean_squared_error: 7.5524 - 91ms/epoch - 1ms/step
# Epoch 245/1000
# 75/75 - 0s - loss: 61.1132 - root_mean_squared_error: 7.8175 - val_loss: 57.2832 - val_root_mean_squared_error: 7.5686 - 91ms/epoch - 1ms/step
# Epoch 246/1000
# 75/75 - 0s - loss: 61.0520 - root_mean_squared_error: 7.8136 - val_loss: 57.3387 - val_root_mean_squared_error: 7.5722 - 90ms/epoch - 1ms/step
# Epoch 247/1000
# 75/75 - 0s - loss: 62.1950 - root_mean_squared_error: 7.8864 - val_loss: 58.6190 - val_root_mean_squared_error: 7.6563 - 91ms/epoch - 1ms/step
# Epoch 248/1000
# 75/75 - 0s - loss: 60.2238 - root_mean_squared_error: 7.7604 - val_loss: 57.8882 - val_root_mean_squared_error: 7.6084 - 90ms/epoch - 1ms/step
# Epoch 249/1000
# 75/75 - 0s - loss: 62.1459 - root_mean_squared_error: 7.8833 - val_loss: 57.8220 - val_root_mean_squared_error: 7.6041 - 89ms/epoch - 1ms/step
# Epoch 250/1000
# 75/75 - 0s - loss: 59.6252 - root_mean_squared_error: 7.7217 - val_loss: 58.4572 - val_root_mean_squared_error: 7.6457 - 91ms/epoch - 1ms/step
# Epoch 251/1000
# 75/75 - 0s - loss: 61.7739 - root_mean_squared_error: 7.8596 - val_loss: 56.6400 - val_root_mean_squared_error: 7.5260 - 94ms/epoch - 1ms/step
# Epoch 252/1000
# 75/75 - 0s - loss: 60.6391 - root_mean_squared_error: 7.7871 - val_loss: 57.2903 - val_root_mean_squared_error: 7.5690 - 93ms/epoch - 1ms/step
# Epoch 253/1000
# 75/75 - 0s - loss: 62.5933 - root_mean_squared_error: 7.9116 - val_loss: 58.2913 - val_root_mean_squared_error: 7.6349 - 92ms/epoch - 1ms/step
# Epoch 254/1000
# 75/75 - 0s - loss: 60.9546 - root_mean_squared_error: 7.8073 - val_loss: 56.5842 - val_root_mean_squared_error: 7.5222 - 92ms/epoch - 1ms/step
# Epoch 255/1000
# 75/75 - 0s - loss: 59.0581 - root_mean_squared_error: 7.6849 - val_loss: 56.6348 - val_root_mean_squared_error: 7.5256 - 93ms/epoch - 1ms/step
# Epoch 256/1000
# 75/75 - 0s - loss: 60.6503 - root_mean_squared_error: 7.7878 - val_loss: 56.7321 - val_root_mean_squared_error: 7.5321 - 92ms/epoch - 1ms/step
# Epoch 257/1000
# 75/75 - 0s - loss: 61.3122 - root_mean_squared_error: 7.8302 - val_loss: 56.4092 - val_root_mean_squared_error: 7.5106 - 92ms/epoch - 1ms/step
# Epoch 258/1000
# 75/75 - 0s - loss: 59.4081 - root_mean_squared_error: 7.7077 - val_loss: 56.3991 - val_root_mean_squared_error: 7.5099 - 95ms/epoch - 1ms/step
# Epoch 259/1000
# 75/75 - 0s - loss: 60.0841 - root_mean_squared_error: 7.7514 - val_loss: 56.9677 - val_root_mean_squared_error: 7.5477 - 90ms/epoch - 1ms/step
# Epoch 260/1000
# 75/75 - 0s - loss: 60.7645 - root_mean_squared_error: 7.7952 - val_loss: 56.7701 - val_root_mean_squared_error: 7.5346 - 91ms/epoch - 1ms/step
# Epoch 261/1000
# 75/75 - 0s - loss: 62.2318 - root_mean_squared_error: 7.8887 - val_loss: 56.2428 - val_root_mean_squared_error: 7.4995 - 91ms/epoch - 1ms/step
# Epoch 262/1000
# 75/75 - 0s - loss: 59.9538 - root_mean_squared_error: 7.7430 - val_loss: 56.4767 - val_root_mean_squared_error: 7.5151 - 91ms/epoch - 1ms/step
# Epoch 263/1000
# 75/75 - 0s - loss: 59.7744 - root_mean_squared_error: 7.7314 - val_loss: 57.6533 - val_root_mean_squared_error: 7.5930 - 92ms/epoch - 1ms/step
# Epoch 264/1000
# 75/75 - 0s - loss: 59.3171 - root_mean_squared_error: 7.7018 - val_loss: 56.2457 - val_root_mean_squared_error: 7.4997 - 97ms/epoch - 1ms/step
# Epoch 265/1000
# 75/75 - 0s - loss: 59.6095 - root_mean_squared_error: 7.7207 - val_loss: 56.1278 - val_root_mean_squared_error: 7.4918 - 93ms/epoch - 1ms/step
# Epoch 266/1000
# 75/75 - 0s - loss: 60.1817 - root_mean_squared_error: 7.7577 - val_loss: 56.3075 - val_root_mean_squared_error: 7.5038 - 94ms/epoch - 1ms/step
# Epoch 267/1000
# 75/75 - 0s - loss: 60.2795 - root_mean_squared_error: 7.7640 - val_loss: 57.0534 - val_root_mean_squared_error: 7.5534 - 93ms/epoch - 1ms/step
# Epoch 268/1000
# 75/75 - 0s - loss: 62.4299 - root_mean_squared_error: 7.9013 - val_loss: 56.4638 - val_root_mean_squared_error: 7.5142 - 92ms/epoch - 1ms/step
# Epoch 269/1000
# 75/75 - 0s - loss: 59.3817 - root_mean_squared_error: 7.7059 - val_loss: 56.2055 - val_root_mean_squared_error: 7.4970 - 94ms/epoch - 1ms/step
# Epoch 270/1000
# 75/75 - 0s - loss: 58.4401 - root_mean_squared_error: 7.6446 - val_loss: 56.0084 - val_root_mean_squared_error: 7.4839 - 92ms/epoch - 1ms/step
# Epoch 271/1000
# 75/75 - 0s - loss: 60.0185 - root_mean_squared_error: 7.7472 - val_loss: 56.1212 - val_root_mean_squared_error: 7.4914 - 94ms/epoch - 1ms/step
# Epoch 272/1000
# 75/75 - 0s - loss: 59.7473 - root_mean_squared_error: 7.7296 - val_loss: 57.3706 - val_root_mean_squared_error: 7.5743 - 93ms/epoch - 1ms/step
# Epoch 273/1000
# 75/75 - 0s - loss: 60.1174 - root_mean_squared_error: 7.7535 - val_loss: 56.4606 - val_root_mean_squared_error: 7.5140 - 96ms/epoch - 1ms/step
# Epoch 274/1000
# 75/75 - 0s - loss: 61.3268 - root_mean_squared_error: 7.8311 - val_loss: 56.3649 - val_root_mean_squared_error: 7.5077 - 92ms/epoch - 1ms/step
# Epoch 275/1000
# 75/75 - 0s - loss: 60.2840 - root_mean_squared_error: 7.7643 - val_loss: 57.3278 - val_root_mean_squared_error: 7.5715 - 94ms/epoch - 1ms/step
# Epoch 276/1000
# 75/75 - 0s - loss: 60.8620 - root_mean_squared_error: 7.8014 - val_loss: 55.8592 - val_root_mean_squared_error: 7.4739 - 93ms/epoch - 1ms/step
# Epoch 277/1000
# 75/75 - 0s - loss: 59.7178 - root_mean_squared_error: 7.7277 - val_loss: 56.3414 - val_root_mean_squared_error: 7.5061 - 93ms/epoch - 1ms/step
# Epoch 278/1000
# 75/75 - 0s - loss: 61.0234 - root_mean_squared_error: 7.8117 - val_loss: 55.7296 - val_root_mean_squared_error: 7.4652 - 92ms/epoch - 1ms/step
# Epoch 279/1000
# 75/75 - 0s - loss: 60.7942 - root_mean_squared_error: 7.7971 - val_loss: 57.2359 - val_root_mean_squared_error: 7.5654 - 93ms/epoch - 1ms/step
# Epoch 280/1000
# 75/75 - 0s - loss: 60.5131 - root_mean_squared_error: 7.7790 - val_loss: 56.1282 - val_root_mean_squared_error: 7.4919 - 95ms/epoch - 1ms/step
# Epoch 281/1000
# 75/75 - 0s - loss: 59.0851 - root_mean_squared_error: 7.6867 - val_loss: 56.7811 - val_root_mean_squared_error: 7.5353 - 93ms/epoch - 1ms/step
# Epoch 282/1000
# 75/75 - 0s - loss: 60.2147 - root_mean_squared_error: 7.7598 - val_loss: 56.0095 - val_root_mean_squared_error: 7.4839 - 92ms/epoch - 1ms/step
# Epoch 283/1000
# 75/75 - 0s - loss: 59.8833 - root_mean_squared_error: 7.7384 - val_loss: 55.5544 - val_root_mean_squared_error: 7.4535 - 92ms/epoch - 1ms/step
# Epoch 284/1000
# 75/75 - 0s - loss: 61.1411 - root_mean_squared_error: 7.8193 - val_loss: 55.7234 - val_root_mean_squared_error: 7.4648 - 92ms/epoch - 1ms/step
# Epoch 285/1000
# 75/75 - 0s - loss: 59.9262 - root_mean_squared_error: 7.7412 - val_loss: 55.8087 - val_root_mean_squared_error: 7.4705 - 91ms/epoch - 1ms/step
# Epoch 286/1000
# 75/75 - 0s - loss: 58.7032 - root_mean_squared_error: 7.6618 - val_loss: 55.5131 - val_root_mean_squared_error: 7.4507 - 95ms/epoch - 1ms/step
# Epoch 287/1000
# 75/75 - 0s - loss: 58.8324 - root_mean_squared_error: 7.6702 - val_loss: 57.1480 - val_root_mean_squared_error: 7.5596 - 92ms/epoch - 1ms/step
# Epoch 288/1000
# 75/75 - 0s - loss: 59.6333 - root_mean_squared_error: 7.7223 - val_loss: 56.2323 - val_root_mean_squared_error: 7.4988 - 92ms/epoch - 1ms/step
# Epoch 289/1000
# 75/75 - 0s - loss: 59.7791 - root_mean_squared_error: 7.7317 - val_loss: 55.4165 - val_root_mean_squared_error: 7.4442 - 93ms/epoch - 1ms/step
# Epoch 290/1000
# 75/75 - 0s - loss: 59.1681 - root_mean_squared_error: 7.6921 - val_loss: 55.9220 - val_root_mean_squared_error: 7.4781 - 92ms/epoch - 1ms/step
# Epoch 291/1000
# 75/75 - 0s - loss: 60.5007 - root_mean_squared_error: 7.7782 - val_loss: 55.5176 - val_root_mean_squared_error: 7.4510 - 93ms/epoch - 1ms/step
# Epoch 292/1000
# 75/75 - 0s - loss: 59.5094 - root_mean_squared_error: 7.7142 - val_loss: 55.2638 - val_root_mean_squared_error: 7.4340 - 93ms/epoch - 1ms/step
# Epoch 293/1000
# 75/75 - 0s - loss: 59.0587 - root_mean_squared_error: 7.6850 - val_loss: 55.7999 - val_root_mean_squared_error: 7.4699 - 91ms/epoch - 1ms/step
# Epoch 294/1000
# 75/75 - 0s - loss: 60.0362 - root_mean_squared_error: 7.7483 - val_loss: 55.4181 - val_root_mean_squared_error: 7.4443 - 96ms/epoch - 1ms/step
# Epoch 295/1000
# 75/75 - 0s - loss: 59.3052 - root_mean_squared_error: 7.7010 - val_loss: 55.5815 - val_root_mean_squared_error: 7.4553 - 95ms/epoch - 1ms/step
# Epoch 296/1000
# 75/75 - 0s - loss: 61.1863 - root_mean_squared_error: 7.8222 - val_loss: 55.6163 - val_root_mean_squared_error: 7.4576 - 94ms/epoch - 1ms/step
# Epoch 297/1000
# 75/75 - 0s - loss: 60.6099 - root_mean_squared_error: 7.7852 - val_loss: 55.5576 - val_root_mean_squared_error: 7.4537 - 95ms/epoch - 1ms/step
# Epoch 298/1000
# 75/75 - 0s - loss: 59.1197 - root_mean_squared_error: 7.6889 - val_loss: 55.2697 - val_root_mean_squared_error: 7.4344 - 95ms/epoch - 1ms/step
# Epoch 299/1000
# 75/75 - 0s - loss: 59.3163 - root_mean_squared_error: 7.7017 - val_loss: 55.2133 - val_root_mean_squared_error: 7.4306 - 95ms/epoch - 1ms/step
# Epoch 300/1000
# 75/75 - 0s - loss: 59.4811 - root_mean_squared_error: 7.7124 - val_loss: 56.5298 - val_root_mean_squared_error: 7.5186 - 95ms/epoch - 1ms/step
# Epoch 301/1000
# 75/75 - 0s - loss: 59.4155 - root_mean_squared_error: 7.7081 - val_loss: 55.6369 - val_root_mean_squared_error: 7.4590 - 95ms/epoch - 1ms/step
# Epoch 302/1000
# 75/75 - 0s - loss: 60.0342 - root_mean_squared_error: 7.7482 - val_loss: 55.3469 - val_root_mean_squared_error: 7.4396 - 94ms/epoch - 1ms/step
# Epoch 303/1000
# 75/75 - 0s - loss: 59.4230 - root_mean_squared_error: 7.7086 - val_loss: 56.1309 - val_root_mean_squared_error: 7.4921 - 91ms/epoch - 1ms/step
# Epoch 304/1000
# 75/75 - 0s - loss: 60.0675 - root_mean_squared_error: 7.7503 - val_loss: 56.5535 - val_root_mean_squared_error: 7.5202 - 93ms/epoch - 1ms/step
# Epoch 305/1000
# 75/75 - 0s - loss: 59.4802 - root_mean_squared_error: 7.7123 - val_loss: 55.4127 - val_root_mean_squared_error: 7.4440 - 94ms/epoch - 1ms/step
# Epoch 306/1000
# 75/75 - 0s - loss: 58.7710 - root_mean_squared_error: 7.6662 - val_loss: 55.6140 - val_root_mean_squared_error: 7.4575 - 92ms/epoch - 1ms/step
# Epoch 307/1000
# 75/75 - 0s - loss: 58.1710 - root_mean_squared_error: 7.6270 - val_loss: 55.6674 - val_root_mean_squared_error: 7.4611 - 93ms/epoch - 1ms/step
# Epoch 308/1000
# 75/75 - 0s - loss: 59.6492 - root_mean_squared_error: 7.7233 - val_loss: 55.3150 - val_root_mean_squared_error: 7.4374 - 92ms/epoch - 1ms/step
# Epoch 309/1000
# 75/75 - 0s - loss: 62.1547 - root_mean_squared_error: 7.8838 - val_loss: 55.1358 - val_root_mean_squared_error: 7.4253 - 92ms/epoch - 1ms/step
# Epoch 310/1000
# 75/75 - 0s - loss: 59.5408 - root_mean_squared_error: 7.7163 - val_loss: 55.6582 - val_root_mean_squared_error: 7.4604 - 94ms/epoch - 1ms/step
# Epoch 311/1000
# 75/75 - 0s - loss: 58.5504 - root_mean_squared_error: 7.6518 - val_loss: 55.2703 - val_root_mean_squared_error: 7.4344 - 93ms/epoch - 1ms/step
# Epoch 312/1000
# 75/75 - 0s - loss: 60.8273 - root_mean_squared_error: 7.7992 - val_loss: 54.8291 - val_root_mean_squared_error: 7.4047 - 92ms/epoch - 1ms/step
# Epoch 313/1000
# 75/75 - 0s - loss: 58.5457 - root_mean_squared_error: 7.6515 - val_loss: 56.0525 - val_root_mean_squared_error: 7.4868 - 91ms/epoch - 1ms/step
# Epoch 314/1000
# 75/75 - 0s - loss: 58.7782 - root_mean_squared_error: 7.6667 - val_loss: 54.7629 - val_root_mean_squared_error: 7.4002 - 93ms/epoch - 1ms/step
# Epoch 315/1000
# 75/75 - 0s - loss: 59.9053 - root_mean_squared_error: 7.7399 - val_loss: 54.6990 - val_root_mean_squared_error: 7.3959 - 94ms/epoch - 1ms/step
# Epoch 316/1000
# 75/75 - 0s - loss: 60.3749 - root_mean_squared_error: 7.7701 - val_loss: 54.7971 - val_root_mean_squared_error: 7.4025 - 93ms/epoch - 1ms/step
# Epoch 317/1000
# 75/75 - 0s - loss: 59.4024 - root_mean_squared_error: 7.7073 - val_loss: 55.6047 - val_root_mean_squared_error: 7.4569 - 93ms/epoch - 1ms/step
# Epoch 318/1000
# 75/75 - 0s - loss: 59.1915 - root_mean_squared_error: 7.6936 - val_loss: 55.1211 - val_root_mean_squared_error: 7.4244 - 93ms/epoch - 1ms/step
# Epoch 319/1000
# 75/75 - 0s - loss: 58.3271 - root_mean_squared_error: 7.6372 - val_loss: 54.5308 - val_root_mean_squared_error: 7.3845 - 95ms/epoch - 1ms/step
# Epoch 320/1000
# 75/75 - 0s - loss: 58.8747 - root_mean_squared_error: 7.6730 - val_loss: 55.3572 - val_root_mean_squared_error: 7.4402 - 93ms/epoch - 1ms/step
# Epoch 321/1000
# 75/75 - 0s - loss: 60.1722 - root_mean_squared_error: 7.7571 - val_loss: 54.5824 - val_root_mean_squared_error: 7.3880 - 92ms/epoch - 1ms/step
# Epoch 322/1000
# 75/75 - 0s - loss: 57.3777 - root_mean_squared_error: 7.5748 - val_loss: 54.4245 - val_root_mean_squared_error: 7.3773 - 92ms/epoch - 1ms/step
# Epoch 323/1000
# 75/75 - 0s - loss: 58.1929 - root_mean_squared_error: 7.6284 - val_loss: 55.0469 - val_root_mean_squared_error: 7.4194 - 92ms/epoch - 1ms/step
# Epoch 324/1000
# 75/75 - 0s - loss: 57.8315 - root_mean_squared_error: 7.6047 - val_loss: 54.6907 - val_root_mean_squared_error: 7.3953 - 93ms/epoch - 1ms/step
# Epoch 325/1000
# 75/75 - 0s - loss: 58.4448 - root_mean_squared_error: 7.6449 - val_loss: 54.5936 - val_root_mean_squared_error: 7.3887 - 93ms/epoch - 1ms/step
# Epoch 326/1000
# 75/75 - 0s - loss: 59.3522 - root_mean_squared_error: 7.7040 - val_loss: 54.4206 - val_root_mean_squared_error: 7.3770 - 97ms/epoch - 1ms/step
# Epoch 327/1000
# 75/75 - 0s - loss: 59.1692 - root_mean_squared_error: 7.6922 - val_loss: 54.3785 - val_root_mean_squared_error: 7.3742 - 95ms/epoch - 1ms/step
# Epoch 328/1000
# 75/75 - 0s - loss: 60.0706 - root_mean_squared_error: 7.7505 - val_loss: 54.4288 - val_root_mean_squared_error: 7.3776 - 95ms/epoch - 1ms/step
# Epoch 329/1000
# 75/75 - 0s - loss: 59.4953 - root_mean_squared_error: 7.7133 - val_loss: 54.3189 - val_root_mean_squared_error: 7.3701 - 95ms/epoch - 1ms/step
# Epoch 330/1000
# 75/75 - 0s - loss: 58.9619 - root_mean_squared_error: 7.6787 - val_loss: 54.8455 - val_root_mean_squared_error: 7.4058 - 93ms/epoch - 1ms/step
# Epoch 331/1000
# 75/75 - 0s - loss: 60.1611 - root_mean_squared_error: 7.7564 - val_loss: 54.5757 - val_root_mean_squared_error: 7.3875 - 92ms/epoch - 1ms/step
# Epoch 332/1000
# 75/75 - 0s - loss: 58.9190 - root_mean_squared_error: 7.6759 - val_loss: 55.6503 - val_root_mean_squared_error: 7.4599 - 92ms/epoch - 1ms/step
# Epoch 333/1000
# 75/75 - 0s - loss: 59.0149 - root_mean_squared_error: 7.6821 - val_loss: 54.3326 - val_root_mean_squared_error: 7.3711 - 91ms/epoch - 1ms/step
# Epoch 334/1000
# 75/75 - 0s - loss: 58.9248 - root_mean_squared_error: 7.6763 - val_loss: 54.7888 - val_root_mean_squared_error: 7.4019 - 94ms/epoch - 1ms/step
# Epoch 335/1000
# 75/75 - 0s - loss: 58.0741 - root_mean_squared_error: 7.6206 - val_loss: 54.7540 - val_root_mean_squared_error: 7.3996 - 95ms/epoch - 1ms/step
# Epoch 336/1000
# 75/75 - 0s - loss: 59.7367 - root_mean_squared_error: 7.7290 - val_loss: 54.2377 - val_root_mean_squared_error: 7.3646 - 93ms/epoch - 1ms/step
# Epoch 337/1000
# 75/75 - 0s - loss: 57.5226 - root_mean_squared_error: 7.5844 - val_loss: 54.2271 - val_root_mean_squared_error: 7.3639 - 96ms/epoch - 1ms/step
# Epoch 338/1000
# 75/75 - 0s - loss: 57.8105 - root_mean_squared_error: 7.6033 - val_loss: 55.0684 - val_root_mean_squared_error: 7.4208 - 94ms/epoch - 1ms/step
# Epoch 339/1000
# 75/75 - 0s - loss: 59.9492 - root_mean_squared_error: 7.7427 - val_loss: 54.7866 - val_root_mean_squared_error: 7.4018 - 93ms/epoch - 1ms/step
# Epoch 340/1000
# 75/75 - 0s - loss: 58.8413 - root_mean_squared_error: 7.6708 - val_loss: 54.0938 - val_root_mean_squared_error: 7.3549 - 95ms/epoch - 1ms/step
# Epoch 341/1000
# 75/75 - 0s - loss: 60.0345 - root_mean_squared_error: 7.7482 - val_loss: 54.9498 - val_root_mean_squared_error: 7.4128 - 95ms/epoch - 1ms/step
# Epoch 342/1000
# 75/75 - 0s - loss: 58.8057 - root_mean_squared_error: 7.6685 - val_loss: 53.8396 - val_root_mean_squared_error: 7.3375 - 96ms/epoch - 1ms/step
# Epoch 343/1000
# 75/75 - 0s - loss: 58.6407 - root_mean_squared_error: 7.6577 - val_loss: 53.9421 - val_root_mean_squared_error: 7.3445 - 93ms/epoch - 1ms/step
# Epoch 344/1000
# 75/75 - 0s - loss: 57.9097 - root_mean_squared_error: 7.6098 - val_loss: 54.0334 - val_root_mean_squared_error: 7.3507 - 94ms/epoch - 1ms/step
# Epoch 345/1000
# 75/75 - 0s - loss: 59.8380 - root_mean_squared_error: 7.7355 - val_loss: 54.1971 - val_root_mean_squared_error: 7.3619 - 93ms/epoch - 1ms/step
# Epoch 346/1000
# 75/75 - 0s - loss: 59.4028 - root_mean_squared_error: 7.7073 - val_loss: 54.0123 - val_root_mean_squared_error: 7.3493 - 93ms/epoch - 1ms/step
# Epoch 347/1000
# 75/75 - 0s - loss: 56.7538 - root_mean_squared_error: 7.5335 - val_loss: 54.1425 - val_root_mean_squared_error: 7.3582 - 95ms/epoch - 1ms/step
# Epoch 348/1000
# 75/75 - 0s - loss: 59.1047 - root_mean_squared_error: 7.6880 - val_loss: 53.8284 - val_root_mean_squared_error: 7.3368 - 95ms/epoch - 1ms/step
# Epoch 349/1000
# 75/75 - 0s - loss: 60.1141 - root_mean_squared_error: 7.7533 - val_loss: 54.1745 - val_root_mean_squared_error: 7.3603 - 93ms/epoch - 1ms/step
# Epoch 350/1000
# 75/75 - 0s - loss: 58.0898 - root_mean_squared_error: 7.6217 - val_loss: 54.6071 - val_root_mean_squared_error: 7.3897 - 92ms/epoch - 1ms/step
# Epoch 351/1000
# 75/75 - 0s - loss: 60.6927 - root_mean_squared_error: 7.7906 - val_loss: 53.6213 - val_root_mean_squared_error: 7.3227 - 92ms/epoch - 1ms/step
# Epoch 352/1000
# 75/75 - 0s - loss: 58.8909 - root_mean_squared_error: 7.6740 - val_loss: 53.7046 - val_root_mean_squared_error: 7.3283 - 92ms/epoch - 1ms/step
# Epoch 353/1000
# 75/75 - 0s - loss: 57.9703 - root_mean_squared_error: 7.6138 - val_loss: 53.9513 - val_root_mean_squared_error: 7.3452 - 92ms/epoch - 1ms/step
# Epoch 354/1000
# 75/75 - 0s - loss: 59.3891 - root_mean_squared_error: 7.7064 - val_loss: 53.7848 - val_root_mean_squared_error: 7.3338 - 95ms/epoch - 1ms/step
# Epoch 355/1000
# 75/75 - 0s - loss: 58.3249 - root_mean_squared_error: 7.6371 - val_loss: 53.5386 - val_root_mean_squared_error: 7.3170 - 94ms/epoch - 1ms/step
# Epoch 356/1000
# 75/75 - 0s - loss: 59.5195 - root_mean_squared_error: 7.7149 - val_loss: 54.2673 - val_root_mean_squared_error: 7.3666 - 95ms/epoch - 1ms/step
# Epoch 357/1000
# 75/75 - 0s - loss: 59.7134 - root_mean_squared_error: 7.7274 - val_loss: 54.5049 - val_root_mean_squared_error: 7.3827 - 95ms/epoch - 1ms/step
# Epoch 358/1000
# 75/75 - 0s - loss: 60.3275 - root_mean_squared_error: 7.7671 - val_loss: 54.8599 - val_root_mean_squared_error: 7.4067 - 96ms/epoch - 1ms/step
# Epoch 359/1000
# 75/75 - 0s - loss: 59.2102 - root_mean_squared_error: 7.6948 - val_loss: 54.2102 - val_root_mean_squared_error: 7.3628 - 92ms/epoch - 1ms/step
# Epoch 360/1000
# 75/75 - 0s - loss: 57.6478 - root_mean_squared_error: 7.5926 - val_loss: 53.6810 - val_root_mean_squared_error: 7.3267 - 94ms/epoch - 1ms/step
# Epoch 361/1000
# 75/75 - 0s - loss: 59.3050 - root_mean_squared_error: 7.7010 - val_loss: 53.7131 - val_root_mean_squared_error: 7.3289 - 94ms/epoch - 1ms/step
# Epoch 362/1000
# 75/75 - 0s - loss: 57.5009 - root_mean_squared_error: 7.5829 - val_loss: 53.5136 - val_root_mean_squared_error: 7.3153 - 92ms/epoch - 1ms/step
# Epoch 363/1000
# 75/75 - 0s - loss: 59.0512 - root_mean_squared_error: 7.6845 - val_loss: 54.1949 - val_root_mean_squared_error: 7.3617 - 93ms/epoch - 1ms/step
# Epoch 364/1000
# 75/75 - 0s - loss: 59.1019 - root_mean_squared_error: 7.6878 - val_loss: 53.9831 - val_root_mean_squared_error: 7.3473 - 92ms/epoch - 1ms/step
# Epoch 365/1000
# 75/75 - 0s - loss: 60.0078 - root_mean_squared_error: 7.7465 - val_loss: 53.5395 - val_root_mean_squared_error: 7.3171 - 95ms/epoch - 1ms/step
# Epoch 366/1000
# 75/75 - 0s - loss: 59.4699 - root_mean_squared_error: 7.7117 - val_loss: 54.3373 - val_root_mean_squared_error: 7.3714 - 93ms/epoch - 1ms/step
# Epoch 367/1000
# 75/75 - 0s - loss: 59.0039 - root_mean_squared_error: 7.6814 - val_loss: 53.8310 - val_root_mean_squared_error: 7.3370 - 91ms/epoch - 1ms/step
# Epoch 368/1000
# 75/75 - 0s - loss: 58.2867 - root_mean_squared_error: 7.6346 - val_loss: 53.5994 - val_root_mean_squared_error: 7.3212 - 94ms/epoch - 1ms/step
# Epoch 369/1000
# 75/75 - 0s - loss: 56.8556 - root_mean_squared_error: 7.5403 - val_loss: 53.2669 - val_root_mean_squared_error: 7.2984 - 95ms/epoch - 1ms/step
# Epoch 370/1000
# 75/75 - 0s - loss: 55.8160 - root_mean_squared_error: 7.4710 - val_loss: 53.4532 - val_root_mean_squared_error: 7.3112 - 93ms/epoch - 1ms/step
# Epoch 371/1000
# 75/75 - 0s - loss: 57.2491 - root_mean_squared_error: 7.5663 - val_loss: 53.4338 - val_root_mean_squared_error: 7.3098 - 93ms/epoch - 1ms/step
# Epoch 372/1000
# 75/75 - 0s - loss: 58.7195 - root_mean_squared_error: 7.6629 - val_loss: 53.6444 - val_root_mean_squared_error: 7.3242 - 93ms/epoch - 1ms/step
# Epoch 373/1000
# 75/75 - 0s - loss: 57.6721 - root_mean_squared_error: 7.5942 - val_loss: 53.5362 - val_root_mean_squared_error: 7.3168 - 93ms/epoch - 1ms/step
# Epoch 374/1000
# 75/75 - 0s - loss: 58.3141 - root_mean_squared_error: 7.6364 - val_loss: 53.4039 - val_root_mean_squared_error: 7.3078 - 94ms/epoch - 1ms/step
# Epoch 375/1000
# 75/75 - 0s - loss: 59.1158 - root_mean_squared_error: 7.6887 - val_loss: 53.3063 - val_root_mean_squared_error: 7.3011 - 93ms/epoch - 1ms/step
# Epoch 376/1000
# 75/75 - 0s - loss: 59.4736 - root_mean_squared_error: 7.7119 - val_loss: 53.5558 - val_root_mean_squared_error: 7.3182 - 92ms/epoch - 1ms/step
# Epoch 377/1000
# 75/75 - 0s - loss: 56.3279 - root_mean_squared_error: 7.5052 - val_loss: 53.3104 - val_root_mean_squared_error: 7.3014 - 93ms/epoch - 1ms/step
# Epoch 378/1000
# 75/75 - 0s - loss: 58.8232 - root_mean_squared_error: 7.6696 - val_loss: 53.8169 - val_root_mean_squared_error: 7.3360 - 91ms/epoch - 1ms/step
# Epoch 379/1000
# 75/75 - 0s - loss: 58.3421 - root_mean_squared_error: 7.6382 - val_loss: 53.4445 - val_root_mean_squared_error: 7.3106 - 92ms/epoch - 1ms/step

# %%
plot_history('root_mean_squared_error')

# %%
y_train_predicted = model.predict(x_train)
y_test_predicted = model.predict(x_test)
# Out:
# 75/75 [==============================] - 0s 503us/step
# 36/36 [==============================] - 0s 484us/step

# %%
def plot_predictions(y_pred, y_true, title):
    plt.style.use('ggplot') 
    plt.scatter(y_pred, y_true, s=10, alpha=0.5)
    plt.xlabel("predicted")
    plt.ylabel("true")
    plt.title(title)
   

plot_predictions(y_train_predicted, y_train, title='Predictions on the training set')

# %%
plot_predictions(y_test_predicted, y_test, title='Predictions on the test set')

# %%
train_metrics = model.evaluate(x_train, y_train, return_dict=True)
test_metrics = model.evaluate(x_test, y_test, return_dict=True)
print('Train RMSE: {:.2f}, Test RMSE: {:.2f}'.format(train_metrics['root_mean_squared_error'], test_metrics['root_mean_squared_error']))
# Out:
# 75/75 [==============================] - 0s 524us/step - loss: 53.4445 - root_mean_squared_error: 7.3106
# 36/36 [==============================] - 0s 527us/step - loss: 32.9890 - root_mean_squared_error: 5.7436
# Train RMSE: 7.31, Test RMSE: 5.74

# %%
x_test
# Out:
# array([[ 5.81733566e-04,  9.27865038e-02,  1.06651154e-03,
#          1.93911189e-01,  1.00000000e+00,  1.78675310e-02],
#        [-5.85937500e-04,  9.61914062e-02,  1.85546875e-03,
#          2.05078125e-01,  1.00000000e+00,  2.05078125e-02],
#        [ 5.81911431e-03,  9.27113128e-02,  3.25475885e-03,
#          2.27833120e-01,  1.00000000e+00,  2.11347977e-02],
#        ...,
#        [ 1.01397913e-02,  6.86158693e-02,  3.44556015e-03,
#          3.16991534e-01,  1.00000000e+00,  1.29384299e-02],
#        [ 9.58435208e-03,  5.28117359e-02,  1.76039120e-03,
#          2.98288509e-01,  1.00000000e+00,  1.34125044e-02],
#        [ 1.26071112e-02,  5.27922781e-02,  1.87136807e-03,
#          2.25549099e-01,  1.00000000e+00,  1.42111410e-02]])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_test_predicted, squared=False)
# Out:
# 5.7436041285041695

# %%
plot_history(['root_mean_squared_error', 'val_root_mean_squared_error'])
