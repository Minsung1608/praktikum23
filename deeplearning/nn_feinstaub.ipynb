# %%
import pandas as pd 
df1=pd.read_csv("billwerder_schadstoffe_2012-2023.csv")
df2=pd.read_csv("billwerder_wetter_2012-2023.csv")
df=pd.merge(df1, df2, on="Messzeit")
df.loc[df['Messzeit'] == "01.01.2019"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2555             292.0           1018.3

# %%
df.loc[df['Messzeit'] == "01.01.2020"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2920          2921  01.01.2020               57.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2920                      34.0                        7.0          2921
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2920             200.0           1031.4

# %%
df_train = df.iloc[:2555,:]
df_val = df.iloc[2555:2920,:]
df_test = df.iloc[2920:,:]

# %%
df_val
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
# 2556          2557  02.01.2019               11.0                     3.0
# 2557          2558  03.01.2019               17.0                     4.0
# 2558          2559  04.01.2019               10.0                     3.0
# 2559          2560  05.01.2019               13.0                     3.0
# ...            ...         ...                ...                     ...
# 2915          2916  27.12.2019                7.0                     3.0
# 2916          2917  28.12.2019               11.0                     3.0
# 2917          2918  29.12.2019               10.0                     3.0
# 2918          2919  30.12.2019               12.0                    20.0
# 2919          2920  31.12.2019               23.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
# 2556                      18.0                        2.0          2557
# 2557                      56.0                       42.0          2558
# 2558                      34.0                        5.0          2559
# 2559                      19.0                        2.0          2560
# ...                        ...                        ...           ...
# 2915                      27.0                        8.0          2916
# 2916                      32.0                       23.0          2917
# 2917                      22.0                        2.0          2918
# 2918                      29.0                        2.0          2919
# 2919                      29.0                        2.0          2920
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
# 2556              3.4                  55.8                        4.6
# 2557              0.7                  78.9                        1.7
# 2558              4.3                  94.9                        3.1
# 2559              7.3                  95.5                        3.2
# ...               ...                   ...                        ...
# 2915              2.3                  87.3                        1.8
# 2916             -0.8                  91.1                        1.1
# 2917             -0.1                  80.0                        1.8
# 2918              7.4                  29.7                        2.5
# 2919              6.0                  83.9                        2.5
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2555             292.0           1018.3
# 2556             324.0           1028.5
# 2557             304.0           1034.7
# 2558             294.0           1028.3
# 2559             313.0           1022.1
# ...                ...              ...
# 2915              41.0           1030.3
# 2916             148.0           1040.8
# 2917             181.0           1035.6
# 2918             236.0           1025.0
# 2919             288.0           1028.2
#
# [365 rows x 12 columns]

# %%
df_train = df_train.dropna()
df_val = df_val.dropna()
df_test = df_test.dropna()

# %%
x_train = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_train = df_train['Feinstaub (µg/m3)']
x_val = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_val = df_train['Feinstaub (µg/m3)']
x_test = df_test.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_test = df_test['Feinstaub (µg/m3)']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_history(metrics):
    history_df = pd.DataFrame.from_dict(history.history)
    sns.lineplot(data=history_df[metrics])
    plt.xlabel("epochs")
    plt.ylabel("RMSE")

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlystopper = EarlyStopping(
    monitor='val_loss',
    patience=10
    )

# %%
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization

def create_nn():
    inputs = keras.layers.Input(shape=(x_train.shape[1],), name='input')

    layers_dense = keras.layers.BatchNormalization()(inputs)
    layers_dense = keras.layers.Dense(100, 'relu')(layers_dense)
    layers_dense = keras.layers.Dense(50, 'relu')(layers_dense)

    outputs = keras.layers.Dense(1)(layers_dense)

    return keras.Model(inputs=inputs, outputs=outputs, name="model_batchnorm")

model = create_nn()

# %%
def compile_model(model):
    model.compile(optimizer='adam',
                  loss='mse',
                  metrics=[keras.metrics.RootMeanSquaredError()])
compile_model(model)

# %%
compile_model(model)
model.summary()
# Out:
# Model: "model_batchnorm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 5)]               0
#
#  batch_normalization (BatchN  (None, 5)                20
#  ormalization)
#
#  dense (Dense)               (None, 100)               600
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 5,721
# Trainable params: 5,711
# Non-trainable params: 10
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,
                    batch_size = 32,
                    epochs = 1000,
                    validation_data=(x_val, y_val),
                    callbacks=[earlystopper],
                    verbose = 2)
# Out:
# Epoch 1/1000
# 75/75 - 1s - loss: 323.5663 - root_mean_squared_error: 17.9879 - val_loss: 122918.3125 - val_root_mean_squared_error: 350.5971 - 1s/epoch - 18ms/step
# Epoch 2/1000
# 75/75 - 0s - loss: 120.0559 - root_mean_squared_error: 10.9570 - val_loss: 31721.3340 - val_root_mean_squared_error: 178.1048 - 210ms/epoch - 3ms/step
# Epoch 3/1000
# 75/75 - 0s - loss: 109.3134 - root_mean_squared_error: 10.4553 - val_loss: 4736.9185 - val_root_mean_squared_error: 68.8253 - 207ms/epoch - 3ms/step
# Epoch 4/1000
# 75/75 - 0s - loss: 107.0570 - root_mean_squared_error: 10.3468 - val_loss: 795.2938 - val_root_mean_squared_error: 28.2010 - 196ms/epoch - 3ms/step
# Epoch 5/1000
# 75/75 - 0s - loss: 106.3674 - root_mean_squared_error: 10.3135 - val_loss: 167.2034 - val_root_mean_squared_error: 12.9307 - 209ms/epoch - 3ms/step
# Epoch 6/1000
# 75/75 - 0s - loss: 105.4441 - root_mean_squared_error: 10.2686 - val_loss: 109.2004 - val_root_mean_squared_error: 10.4499 - 233ms/epoch - 3ms/step
# Epoch 7/1000
# 75/75 - 0s - loss: 104.8948 - root_mean_squared_error: 10.2418 - val_loss: 101.6747 - val_root_mean_squared_error: 10.0834 - 189ms/epoch - 3ms/step
# Epoch 8/1000
# 75/75 - 0s - loss: 102.5702 - root_mean_squared_error: 10.1277 - val_loss: 100.9717 - val_root_mean_squared_error: 10.0485 - 199ms/epoch - 3ms/step
# Epoch 9/1000
# 75/75 - 0s - loss: 102.6945 - root_mean_squared_error: 10.1338 - val_loss: 100.3883 - val_root_mean_squared_error: 10.0194 - 243ms/epoch - 3ms/step
# Epoch 10/1000
# 75/75 - 0s - loss: 101.8195 - root_mean_squared_error: 10.0906 - val_loss: 100.2678 - val_root_mean_squared_error: 10.0134 - 194ms/epoch - 3ms/step
# Epoch 11/1000
# 75/75 - 0s - loss: 101.9013 - root_mean_squared_error: 10.0946 - val_loss: 99.4215 - val_root_mean_squared_error: 9.9710 - 230ms/epoch - 3ms/step
# Epoch 12/1000
# 75/75 - 0s - loss: 100.9493 - root_mean_squared_error: 10.0474 - val_loss: 99.0520 - val_root_mean_squared_error: 9.9525 - 196ms/epoch - 3ms/step
# Epoch 13/1000
# 75/75 - 0s - loss: 101.9943 - root_mean_squared_error: 10.0992 - val_loss: 98.7439 - val_root_mean_squared_error: 9.9370 - 216ms/epoch - 3ms/step
# Epoch 14/1000
# 75/75 - 0s - loss: 99.0550 - root_mean_squared_error: 9.9526 - val_loss: 98.3453 - val_root_mean_squared_error: 9.9169 - 190ms/epoch - 3ms/step
# Epoch 15/1000
# 75/75 - 0s - loss: 99.9874 - root_mean_squared_error: 9.9994 - val_loss: 97.8633 - val_root_mean_squared_error: 9.8926 - 200ms/epoch - 3ms/step
# Epoch 16/1000
# 75/75 - 0s - loss: 100.0432 - root_mean_squared_error: 10.0022 - val_loss: 98.5960 - val_root_mean_squared_error: 9.9296 - 222ms/epoch - 3ms/step
# Epoch 17/1000
# 75/75 - 0s - loss: 99.3337 - root_mean_squared_error: 9.9666 - val_loss: 97.0838 - val_root_mean_squared_error: 9.8531 - 211ms/epoch - 3ms/step
# Epoch 18/1000
# 75/75 - 0s - loss: 98.5354 - root_mean_squared_error: 9.9265 - val_loss: 97.0565 - val_root_mean_squared_error: 9.8517 - 215ms/epoch - 3ms/step
# Epoch 19/1000
# 75/75 - 0s - loss: 99.6246 - root_mean_squared_error: 9.9812 - val_loss: 96.5977 - val_root_mean_squared_error: 9.8284 - 212ms/epoch - 3ms/step
# Epoch 20/1000
# 75/75 - 0s - loss: 98.4519 - root_mean_squared_error: 9.9223 - val_loss: 95.9252 - val_root_mean_squared_error: 9.7941 - 203ms/epoch - 3ms/step
# Epoch 21/1000
# 75/75 - 0s - loss: 97.8224 - root_mean_squared_error: 9.8905 - val_loss: 95.5889 - val_root_mean_squared_error: 9.7770 - 196ms/epoch - 3ms/step
# Epoch 22/1000
# 75/75 - 0s - loss: 98.2012 - root_mean_squared_error: 9.9097 - val_loss: 95.1639 - val_root_mean_squared_error: 9.7552 - 265ms/epoch - 4ms/step
# Epoch 23/1000
# 75/75 - 0s - loss: 96.8724 - root_mean_squared_error: 9.8424 - val_loss: 95.2379 - val_root_mean_squared_error: 9.7590 - 252ms/epoch - 3ms/step
# Epoch 24/1000
# 75/75 - 0s - loss: 97.9298 - root_mean_squared_error: 9.8959 - val_loss: 94.8833 - val_root_mean_squared_error: 9.7408 - 210ms/epoch - 3ms/step
# Epoch 25/1000
# 75/75 - 0s - loss: 96.3840 - root_mean_squared_error: 9.8175 - val_loss: 93.9826 - val_root_mean_squared_error: 9.6945 - 209ms/epoch - 3ms/step
# Epoch 26/1000
# 75/75 - 0s - loss: 95.3887 - root_mean_squared_error: 9.7667 - val_loss: 93.8101 - val_root_mean_squared_error: 9.6856 - 216ms/epoch - 3ms/step
# Epoch 27/1000
# 75/75 - 0s - loss: 96.8542 - root_mean_squared_error: 9.8415 - val_loss: 93.3539 - val_root_mean_squared_error: 9.6620 - 187ms/epoch - 2ms/step
# Epoch 28/1000
# 75/75 - 0s - loss: 95.8003 - root_mean_squared_error: 9.7878 - val_loss: 93.3162 - val_root_mean_squared_error: 9.6600 - 200ms/epoch - 3ms/step
# Epoch 29/1000
# 75/75 - 0s - loss: 95.1762 - root_mean_squared_error: 9.7558 - val_loss: 93.2057 - val_root_mean_squared_error: 9.6543 - 197ms/epoch - 3ms/step
# Epoch 30/1000
# 75/75 - 0s - loss: 95.3994 - root_mean_squared_error: 9.7673 - val_loss: 93.4445 - val_root_mean_squared_error: 9.6667 - 207ms/epoch - 3ms/step
# Epoch 31/1000
# 75/75 - 0s - loss: 96.5009 - root_mean_squared_error: 9.8235 - val_loss: 92.6333 - val_root_mean_squared_error: 9.6246 - 220ms/epoch - 3ms/step
# Epoch 32/1000
# 75/75 - 0s - loss: 94.5667 - root_mean_squared_error: 9.7245 - val_loss: 92.3721 - val_root_mean_squared_error: 9.6110 - 199ms/epoch - 3ms/step
# Epoch 33/1000
# 75/75 - 0s - loss: 94.7647 - root_mean_squared_error: 9.7347 - val_loss: 91.9700 - val_root_mean_squared_error: 9.5901 - 216ms/epoch - 3ms/step
# Epoch 34/1000
# 75/75 - 0s - loss: 94.5265 - root_mean_squared_error: 9.7225 - val_loss: 91.5083 - val_root_mean_squared_error: 9.5660 - 203ms/epoch - 3ms/step
# Epoch 35/1000
# 75/75 - 0s - loss: 94.4119 - root_mean_squared_error: 9.7166 - val_loss: 91.6853 - val_root_mean_squared_error: 9.5752 - 203ms/epoch - 3ms/step
# Epoch 36/1000
# 75/75 - 0s - loss: 95.1900 - root_mean_squared_error: 9.7565 - val_loss: 91.9075 - val_root_mean_squared_error: 9.5868 - 209ms/epoch - 3ms/step
# Epoch 37/1000
# 75/75 - 0s - loss: 94.7006 - root_mean_squared_error: 9.7314 - val_loss: 91.6434 - val_root_mean_squared_error: 9.5731 - 210ms/epoch - 3ms/step
# Epoch 38/1000
# 75/75 - 0s - loss: 94.7972 - root_mean_squared_error: 9.7364 - val_loss: 91.4745 - val_root_mean_squared_error: 9.5642 - 198ms/epoch - 3ms/step
# Epoch 39/1000
# 75/75 - 0s - loss: 93.5842 - root_mean_squared_error: 9.6739 - val_loss: 90.7520 - val_root_mean_squared_error: 9.5264 - 210ms/epoch - 3ms/step
# Epoch 40/1000
# 75/75 - 0s - loss: 94.4792 - root_mean_squared_error: 9.7200 - val_loss: 91.4828 - val_root_mean_squared_error: 9.5647 - 196ms/epoch - 3ms/step
# Epoch 41/1000
# 75/75 - 0s - loss: 93.2215 - root_mean_squared_error: 9.6551 - val_loss: 90.4571 - val_root_mean_squared_error: 9.5109 - 214ms/epoch - 3ms/step
# Epoch 42/1000
# 75/75 - 0s - loss: 93.0957 - root_mean_squared_error: 9.6486 - val_loss: 90.7372 - val_root_mean_squared_error: 9.5256 - 209ms/epoch - 3ms/step
# Epoch 43/1000
# 75/75 - 0s - loss: 94.5572 - root_mean_squared_error: 9.7241 - val_loss: 90.6429 - val_root_mean_squared_error: 9.5207 - 189ms/epoch - 3ms/step
# Epoch 44/1000
# 75/75 - 0s - loss: 94.4260 - root_mean_squared_error: 9.7173 - val_loss: 90.3574 - val_root_mean_squared_error: 9.5056 - 204ms/epoch - 3ms/step
# Epoch 45/1000
# 75/75 - 0s - loss: 93.9118 - root_mean_squared_error: 9.6908 - val_loss: 90.2573 - val_root_mean_squared_error: 9.5004 - 203ms/epoch - 3ms/step
# Epoch 46/1000
# 75/75 - 0s - loss: 93.5844 - root_mean_squared_error: 9.6739 - val_loss: 90.2567 - val_root_mean_squared_error: 9.5004 - 210ms/epoch - 3ms/step
# Epoch 47/1000
# 75/75 - 0s - loss: 92.6990 - root_mean_squared_error: 9.6280 - val_loss: 90.0618 - val_root_mean_squared_error: 9.4901 - 211ms/epoch - 3ms/step
# Epoch 48/1000
# 75/75 - 0s - loss: 91.7367 - root_mean_squared_error: 9.5779 - val_loss: 89.7612 - val_root_mean_squared_error: 9.4742 - 191ms/epoch - 3ms/step
# Epoch 49/1000
# 75/75 - 0s - loss: 92.7811 - root_mean_squared_error: 9.6323 - val_loss: 90.6073 - val_root_mean_squared_error: 9.5188 - 215ms/epoch - 3ms/step
# Epoch 50/1000
# 75/75 - 0s - loss: 94.3141 - root_mean_squared_error: 9.7115 - val_loss: 89.5624 - val_root_mean_squared_error: 9.4637 - 190ms/epoch - 3ms/step
# Epoch 51/1000
# 75/75 - 0s - loss: 92.5618 - root_mean_squared_error: 9.6209 - val_loss: 89.8102 - val_root_mean_squared_error: 9.4768 - 192ms/epoch - 3ms/step
# Epoch 52/1000
# 75/75 - 0s - loss: 92.1732 - root_mean_squared_error: 9.6007 - val_loss: 90.3705 - val_root_mean_squared_error: 9.5063 - 199ms/epoch - 3ms/step
# Epoch 53/1000
# 75/75 - 0s - loss: 90.9340 - root_mean_squared_error: 9.5359 - val_loss: 89.2169 - val_root_mean_squared_error: 9.4455 - 196ms/epoch - 3ms/step
# Epoch 54/1000
# 75/75 - 0s - loss: 92.9331 - root_mean_squared_error: 9.6402 - val_loss: 89.2772 - val_root_mean_squared_error: 9.4487 - 235ms/epoch - 3ms/step
# Epoch 55/1000
# 75/75 - 0s - loss: 93.0970 - root_mean_squared_error: 9.6487 - val_loss: 89.2906 - val_root_mean_squared_error: 9.4494 - 183ms/epoch - 2ms/step
# Epoch 56/1000
# 75/75 - 0s - loss: 92.1615 - root_mean_squared_error: 9.6001 - val_loss: 89.3068 - val_root_mean_squared_error: 9.4502 - 219ms/epoch - 3ms/step
# Epoch 57/1000
# 75/75 - 0s - loss: 92.3904 - root_mean_squared_error: 9.6120 - val_loss: 89.0836 - val_root_mean_squared_error: 9.4384 - 198ms/epoch - 3ms/step
# Epoch 58/1000
# 75/75 - 0s - loss: 92.2681 - root_mean_squared_error: 9.6056 - val_loss: 88.8738 - val_root_mean_squared_error: 9.4273 - 199ms/epoch - 3ms/step
# Epoch 59/1000
# 75/75 - 0s - loss: 92.9412 - root_mean_squared_error: 9.6406 - val_loss: 88.6235 - val_root_mean_squared_error: 9.4140 - 187ms/epoch - 2ms/step
# Epoch 60/1000
# 75/75 - 0s - loss: 91.3765 - root_mean_squared_error: 9.5591 - val_loss: 89.2222 - val_root_mean_squared_error: 9.4458 - 208ms/epoch - 3ms/step
# Epoch 61/1000
# 75/75 - 0s - loss: 93.9099 - root_mean_squared_error: 9.6907 - val_loss: 88.7732 - val_root_mean_squared_error: 9.4220 - 196ms/epoch - 3ms/step
# Epoch 62/1000
# 75/75 - 0s - loss: 92.0336 - root_mean_squared_error: 9.5934 - val_loss: 88.6952 - val_root_mean_squared_error: 9.4178 - 205ms/epoch - 3ms/step
# Epoch 63/1000
# 75/75 - 0s - loss: 91.8786 - root_mean_squared_error: 9.5853 - val_loss: 88.4409 - val_root_mean_squared_error: 9.4043 - 214ms/epoch - 3ms/step
# Epoch 64/1000
# 75/75 - 0s - loss: 91.1959 - root_mean_squared_error: 9.5497 - val_loss: 88.9417 - val_root_mean_squared_error: 9.4309 - 212ms/epoch - 3ms/step
# Epoch 65/1000
# 75/75 - 0s - loss: 93.1373 - root_mean_squared_error: 9.6508 - val_loss: 88.8517 - val_root_mean_squared_error: 9.4261 - 217ms/epoch - 3ms/step
# Epoch 66/1000
# 75/75 - 0s - loss: 90.6837 - root_mean_squared_error: 9.5228 - val_loss: 88.3709 - val_root_mean_squared_error: 9.4006 - 216ms/epoch - 3ms/step
# Epoch 67/1000
# 75/75 - 0s - loss: 91.5670 - root_mean_squared_error: 9.5691 - val_loss: 88.2886 - val_root_mean_squared_error: 9.3962 - 200ms/epoch - 3ms/step
# Epoch 68/1000
# 75/75 - 0s - loss: 93.8910 - root_mean_squared_error: 9.6897 - val_loss: 88.1914 - val_root_mean_squared_error: 9.3910 - 198ms/epoch - 3ms/step
# Epoch 69/1000
# 75/75 - 0s - loss: 92.2622 - root_mean_squared_error: 9.6053 - val_loss: 88.3758 - val_root_mean_squared_error: 9.4008 - 204ms/epoch - 3ms/step
# Epoch 70/1000
# 75/75 - 0s - loss: 92.3898 - root_mean_squared_error: 9.6120 - val_loss: 87.8810 - val_root_mean_squared_error: 9.3745 - 205ms/epoch - 3ms/step
# Epoch 71/1000
# 75/75 - 0s - loss: 91.1176 - root_mean_squared_error: 9.5456 - val_loss: 88.5014 - val_root_mean_squared_error: 9.4075 - 203ms/epoch - 3ms/step
# Epoch 72/1000
# 75/75 - 0s - loss: 92.6093 - root_mean_squared_error: 9.6234 - val_loss: 88.1088 - val_root_mean_squared_error: 9.3866 - 193ms/epoch - 3ms/step
# Epoch 73/1000
# 75/75 - 0s - loss: 91.9639 - root_mean_squared_error: 9.5898 - val_loss: 89.3342 - val_root_mean_squared_error: 9.4517 - 198ms/epoch - 3ms/step
# Epoch 74/1000
# 75/75 - 0s - loss: 91.1590 - root_mean_squared_error: 9.5477 - val_loss: 87.6935 - val_root_mean_squared_error: 9.3645 - 192ms/epoch - 3ms/step
# Epoch 75/1000
# 75/75 - 0s - loss: 90.9085 - root_mean_squared_error: 9.5346 - val_loss: 87.9121 - val_root_mean_squared_error: 9.3761 - 255ms/epoch - 3ms/step
# Epoch 76/1000
# 75/75 - 0s - loss: 90.9677 - root_mean_squared_error: 9.5377 - val_loss: 87.2228 - val_root_mean_squared_error: 9.3393 - 320ms/epoch - 4ms/step
# Epoch 77/1000
# 75/75 - 0s - loss: 92.2607 - root_mean_squared_error: 9.6052 - val_loss: 87.5875 - val_root_mean_squared_error: 9.3588 - 215ms/epoch - 3ms/step
# Epoch 78/1000
# 75/75 - 0s - loss: 91.5205 - root_mean_squared_error: 9.5666 - val_loss: 87.6423 - val_root_mean_squared_error: 9.3617 - 204ms/epoch - 3ms/step
# Epoch 79/1000
# 75/75 - 0s - loss: 92.7602 - root_mean_squared_error: 9.6312 - val_loss: 87.4818 - val_root_mean_squared_error: 9.3532 - 236ms/epoch - 3ms/step
# Epoch 80/1000
# 75/75 - 0s - loss: 90.8672 - root_mean_squared_error: 9.5324 - val_loss: 87.1809 - val_root_mean_squared_error: 9.3371 - 212ms/epoch - 3ms/step
# Epoch 81/1000
# 75/75 - 0s - loss: 89.6837 - root_mean_squared_error: 9.4701 - val_loss: 87.7476 - val_root_mean_squared_error: 9.3674 - 219ms/epoch - 3ms/step
# Epoch 82/1000
# 75/75 - 0s - loss: 92.3142 - root_mean_squared_error: 9.6080 - val_loss: 87.3644 - val_root_mean_squared_error: 9.3469 - 203ms/epoch - 3ms/step
# Epoch 83/1000
# 75/75 - 0s - loss: 90.6221 - root_mean_squared_error: 9.5196 - val_loss: 87.6382 - val_root_mean_squared_error: 9.3615 - 198ms/epoch - 3ms/step
# Epoch 84/1000
# 75/75 - 0s - loss: 90.4875 - root_mean_squared_error: 9.5125 - val_loss: 87.2161 - val_root_mean_squared_error: 9.3390 - 217ms/epoch - 3ms/step
# Epoch 85/1000
# 75/75 - 0s - loss: 91.4391 - root_mean_squared_error: 9.5624 - val_loss: 86.9042 - val_root_mean_squared_error: 9.3222 - 201ms/epoch - 3ms/step
# Epoch 86/1000
# 75/75 - 0s - loss: 91.9832 - root_mean_squared_error: 9.5908 - val_loss: 86.5722 - val_root_mean_squared_error: 9.3044 - 199ms/epoch - 3ms/step
# Epoch 87/1000
# 75/75 - 0s - loss: 91.5677 - root_mean_squared_error: 9.5691 - val_loss: 87.0208 - val_root_mean_squared_error: 9.3285 - 208ms/epoch - 3ms/step
# Epoch 88/1000
# 75/75 - 0s - loss: 91.6901 - root_mean_squared_error: 9.5755 - val_loss: 86.5874 - val_root_mean_squared_error: 9.3052 - 221ms/epoch - 3ms/step
# Epoch 89/1000
# 75/75 - 0s - loss: 91.5424 - root_mean_squared_error: 9.5678 - val_loss: 87.1746 - val_root_mean_squared_error: 9.3367 - 210ms/epoch - 3ms/step
# Epoch 90/1000
# 75/75 - 0s - loss: 90.1628 - root_mean_squared_error: 9.4954 - val_loss: 86.3794 - val_root_mean_squared_error: 9.2941 - 207ms/epoch - 3ms/step
# Epoch 91/1000
# 75/75 - 0s - loss: 90.8620 - root_mean_squared_error: 9.5322 - val_loss: 87.5686 - val_root_mean_squared_error: 9.3578 - 222ms/epoch - 3ms/step
# Epoch 92/1000
# 75/75 - 0s - loss: 90.9281 - root_mean_squared_error: 9.5356 - val_loss: 86.8649 - val_root_mean_squared_error: 9.3201 - 243ms/epoch - 3ms/step
# Epoch 93/1000
# 75/75 - 0s - loss: 91.2744 - root_mean_squared_error: 9.5538 - val_loss: 86.3498 - val_root_mean_squared_error: 9.2925 - 215ms/epoch - 3ms/step
# Epoch 94/1000
# 75/75 - 0s - loss: 89.6781 - root_mean_squared_error: 9.4699 - val_loss: 86.6422 - val_root_mean_squared_error: 9.3082 - 220ms/epoch - 3ms/step
# Epoch 95/1000
# 75/75 - 0s - loss: 89.9225 - root_mean_squared_error: 9.4827 - val_loss: 87.6090 - val_root_mean_squared_error: 9.3600 - 230ms/epoch - 3ms/step
# Epoch 96/1000
# 75/75 - 0s - loss: 88.9248 - root_mean_squared_error: 9.4300 - val_loss: 86.1782 - val_root_mean_squared_error: 9.2832 - 253ms/epoch - 3ms/step
# Epoch 97/1000
# 75/75 - 0s - loss: 91.1205 - root_mean_squared_error: 9.5457 - val_loss: 87.4578 - val_root_mean_squared_error: 9.3519 - 260ms/epoch - 3ms/step
# Epoch 98/1000
# 75/75 - 0s - loss: 89.2077 - root_mean_squared_error: 9.4450 - val_loss: 85.8276 - val_root_mean_squared_error: 9.2643 - 204ms/epoch - 3ms/step
# Epoch 99/1000
# 75/75 - 0s - loss: 90.2361 - root_mean_squared_error: 9.4993 - val_loss: 86.0576 - val_root_mean_squared_error: 9.2767 - 233ms/epoch - 3ms/step
# Epoch 100/1000
# 75/75 - 0s - loss: 91.0528 - root_mean_squared_error: 9.5422 - val_loss: 85.9875 - val_root_mean_squared_error: 9.2729 - 200ms/epoch - 3ms/step
# Epoch 101/1000
# 75/75 - 0s - loss: 88.3491 - root_mean_squared_error: 9.3994 - val_loss: 85.5217 - val_root_mean_squared_error: 9.2478 - 215ms/epoch - 3ms/step
# Epoch 102/1000
# 75/75 - 0s - loss: 89.0073 - root_mean_squared_error: 9.4344 - val_loss: 85.6575 - val_root_mean_squared_error: 9.2551 - 215ms/epoch - 3ms/step
# Epoch 103/1000
# 75/75 - 0s - loss: 88.8287 - root_mean_squared_error: 9.4249 - val_loss: 85.6063 - val_root_mean_squared_error: 9.2524 - 192ms/epoch - 3ms/step
# Epoch 104/1000
# 75/75 - 0s - loss: 90.0423 - root_mean_squared_error: 9.4891 - val_loss: 87.0778 - val_root_mean_squared_error: 9.3315 - 290ms/epoch - 4ms/step
# Epoch 105/1000
# 75/75 - 0s - loss: 90.1179 - root_mean_squared_error: 9.4930 - val_loss: 86.1379 - val_root_mean_squared_error: 9.2810 - 270ms/epoch - 4ms/step
# Epoch 106/1000
# 75/75 - 0s - loss: 89.8237 - root_mean_squared_error: 9.4775 - val_loss: 85.2174 - val_root_mean_squared_error: 9.2313 - 231ms/epoch - 3ms/step
# Epoch 107/1000
# 75/75 - 0s - loss: 89.9743 - root_mean_squared_error: 9.4855 - val_loss: 86.5548 - val_root_mean_squared_error: 9.3035 - 195ms/epoch - 3ms/step
# Epoch 108/1000
# 75/75 - 0s - loss: 90.1845 - root_mean_squared_error: 9.4966 - val_loss: 85.7636 - val_root_mean_squared_error: 9.2609 - 203ms/epoch - 3ms/step
# Epoch 109/1000
# 75/75 - 0s - loss: 88.8686 - root_mean_squared_error: 9.4270 - val_loss: 85.4144 - val_root_mean_squared_error: 9.2420 - 215ms/epoch - 3ms/step
# Epoch 110/1000
# 75/75 - 0s - loss: 88.3652 - root_mean_squared_error: 9.4003 - val_loss: 85.0631 - val_root_mean_squared_error: 9.2230 - 197ms/epoch - 3ms/step
# Epoch 111/1000
# 75/75 - 0s - loss: 91.5220 - root_mean_squared_error: 9.5667 - val_loss: 85.6157 - val_root_mean_squared_error: 9.2529 - 236ms/epoch - 3ms/step
# Epoch 112/1000
# 75/75 - 0s - loss: 90.9586 - root_mean_squared_error: 9.5372 - val_loss: 85.2392 - val_root_mean_squared_error: 9.2325 - 232ms/epoch - 3ms/step
# Epoch 113/1000
# 75/75 - 0s - loss: 88.8260 - root_mean_squared_error: 9.4248 - val_loss: 85.4835 - val_root_mean_squared_error: 9.2457 - 266ms/epoch - 4ms/step
# Epoch 114/1000
# 75/75 - 0s - loss: 90.7027 - root_mean_squared_error: 9.5238 - val_loss: 85.6471 - val_root_mean_squared_error: 9.2546 - 191ms/epoch - 3ms/step
# Epoch 115/1000
# 75/75 - 0s - loss: 90.3295 - root_mean_squared_error: 9.5042 - val_loss: 85.0391 - val_root_mean_squared_error: 9.2217 - 209ms/epoch - 3ms/step
# Epoch 116/1000
# 75/75 - 0s - loss: 89.2917 - root_mean_squared_error: 9.4494 - val_loss: 85.0480 - val_root_mean_squared_error: 9.2221 - 195ms/epoch - 3ms/step
# Epoch 117/1000
# 75/75 - 0s - loss: 88.6468 - root_mean_squared_error: 9.4152 - val_loss: 84.8286 - val_root_mean_squared_error: 9.2102 - 270ms/epoch - 4ms/step
# Epoch 118/1000
# 75/75 - 0s - loss: 90.6163 - root_mean_squared_error: 9.5193 - val_loss: 87.8525 - val_root_mean_squared_error: 9.3730 - 282ms/epoch - 4ms/step
# Epoch 119/1000
# 75/75 - 0s - loss: 91.4335 - root_mean_squared_error: 9.5621 - val_loss: 85.5517 - val_root_mean_squared_error: 9.2494 - 228ms/epoch - 3ms/step
# Epoch 120/1000
# 75/75 - 0s - loss: 89.7339 - root_mean_squared_error: 9.4728 - val_loss: 84.6760 - val_root_mean_squared_error: 9.2020 - 212ms/epoch - 3ms/step
# Epoch 121/1000
# 75/75 - 0s - loss: 88.4577 - root_mean_squared_error: 9.4052 - val_loss: 85.2448 - val_root_mean_squared_error: 9.2328 - 205ms/epoch - 3ms/step
# Epoch 122/1000
# 75/75 - 0s - loss: 90.2035 - root_mean_squared_error: 9.4976 - val_loss: 86.9752 - val_root_mean_squared_error: 9.3260 - 237ms/epoch - 3ms/step
# Epoch 123/1000
# 75/75 - 0s - loss: 91.4508 - root_mean_squared_error: 9.5630 - val_loss: 84.5308 - val_root_mean_squared_error: 9.1941 - 229ms/epoch - 3ms/step
# Epoch 124/1000
# 75/75 - 0s - loss: 90.3436 - root_mean_squared_error: 9.5049 - val_loss: 84.5618 - val_root_mean_squared_error: 9.1957 - 200ms/epoch - 3ms/step
# Epoch 125/1000
# 75/75 - 0s - loss: 88.2362 - root_mean_squared_error: 9.3934 - val_loss: 84.5873 - val_root_mean_squared_error: 9.1971 - 242ms/epoch - 3ms/step
# Epoch 126/1000
# 75/75 - 0s - loss: 89.0001 - root_mean_squared_error: 9.4340 - val_loss: 84.5720 - val_root_mean_squared_error: 9.1963 - 256ms/epoch - 3ms/step
# Epoch 127/1000
# 75/75 - 0s - loss: 87.4106 - root_mean_squared_error: 9.3494 - val_loss: 84.2888 - val_root_mean_squared_error: 9.1809 - 285ms/epoch - 4ms/step
# Epoch 128/1000
# 75/75 - 0s - loss: 89.3590 - root_mean_squared_error: 9.4530 - val_loss: 84.2205 - val_root_mean_squared_error: 9.1772 - 244ms/epoch - 3ms/step
# Epoch 129/1000
# 75/75 - 0s - loss: 90.1100 - root_mean_squared_error: 9.4926 - val_loss: 84.6786 - val_root_mean_squared_error: 9.2021 - 246ms/epoch - 3ms/step
# Epoch 130/1000
# 75/75 - 0s - loss: 90.2420 - root_mean_squared_error: 9.4996 - val_loss: 84.2173 - val_root_mean_squared_error: 9.1770 - 213ms/epoch - 3ms/step
# Epoch 131/1000
# 75/75 - 0s - loss: 90.5563 - root_mean_squared_error: 9.5161 - val_loss: 84.6828 - val_root_mean_squared_error: 9.2023 - 206ms/epoch - 3ms/step
# Epoch 132/1000
# 75/75 - 0s - loss: 88.7443 - root_mean_squared_error: 9.4204 - val_loss: 83.9791 - val_root_mean_squared_error: 9.1640 - 209ms/epoch - 3ms/step
# Epoch 133/1000
# 75/75 - 0s - loss: 89.9067 - root_mean_squared_error: 9.4819 - val_loss: 84.0583 - val_root_mean_squared_error: 9.1683 - 219ms/epoch - 3ms/step
# Epoch 134/1000
# 75/75 - 0s - loss: 89.6372 - root_mean_squared_error: 9.4677 - val_loss: 85.9030 - val_root_mean_squared_error: 9.2684 - 223ms/epoch - 3ms/step
# Epoch 135/1000
# 75/75 - 0s - loss: 90.7033 - root_mean_squared_error: 9.5238 - val_loss: 83.9221 - val_root_mean_squared_error: 9.1609 - 239ms/epoch - 3ms/step
# Epoch 136/1000
# 75/75 - 0s - loss: 90.1092 - root_mean_squared_error: 9.4926 - val_loss: 85.7566 - val_root_mean_squared_error: 9.2605 - 221ms/epoch - 3ms/step
# Epoch 137/1000
# 75/75 - 0s - loss: 88.6239 - root_mean_squared_error: 9.4140 - val_loss: 84.0831 - val_root_mean_squared_error: 9.1697 - 270ms/epoch - 4ms/step
# Epoch 138/1000
# 75/75 - 0s - loss: 89.8174 - root_mean_squared_error: 9.4772 - val_loss: 85.2940 - val_root_mean_squared_error: 9.2355 - 217ms/epoch - 3ms/step
# Epoch 139/1000
# 75/75 - 0s - loss: 88.0169 - root_mean_squared_error: 9.3817 - val_loss: 84.5974 - val_root_mean_squared_error: 9.1977 - 217ms/epoch - 3ms/step
# Epoch 140/1000
# 75/75 - 0s - loss: 88.7972 - root_mean_squared_error: 9.4232 - val_loss: 84.6608 - val_root_mean_squared_error: 9.2011 - 216ms/epoch - 3ms/step
# Epoch 141/1000
# 75/75 - 0s - loss: 89.3960 - root_mean_squared_error: 9.4549 - val_loss: 83.5120 - val_root_mean_squared_error: 9.1385 - 217ms/epoch - 3ms/step
# Epoch 142/1000
# 75/75 - 0s - loss: 87.7673 - root_mean_squared_error: 9.3684 - val_loss: 83.5365 - val_root_mean_squared_error: 9.1398 - 283ms/epoch - 4ms/step
# Epoch 143/1000
# 75/75 - 0s - loss: 88.7041 - root_mean_squared_error: 9.4183 - val_loss: 83.7482 - val_root_mean_squared_error: 9.1514 - 198ms/epoch - 3ms/step
# Epoch 144/1000
# 75/75 - 0s - loss: 89.6434 - root_mean_squared_error: 9.4680 - val_loss: 84.0810 - val_root_mean_squared_error: 9.1696 - 203ms/epoch - 3ms/step
# Epoch 145/1000
# 75/75 - 0s - loss: 91.4948 - root_mean_squared_error: 9.5653 - val_loss: 84.0392 - val_root_mean_squared_error: 9.1673 - 187ms/epoch - 2ms/step
# Epoch 146/1000
# 75/75 - 0s - loss: 88.6475 - root_mean_squared_error: 9.4153 - val_loss: 83.3497 - val_root_mean_squared_error: 9.1296 - 213ms/epoch - 3ms/step
# Epoch 147/1000
# 75/75 - 0s - loss: 89.0062 - root_mean_squared_error: 9.4343 - val_loss: 83.4553 - val_root_mean_squared_error: 9.1354 - 412ms/epoch - 5ms/step
# Epoch 148/1000
# 75/75 - 0s - loss: 87.6391 - root_mean_squared_error: 9.3616 - val_loss: 83.5856 - val_root_mean_squared_error: 9.1425 - 378ms/epoch - 5ms/step
# Epoch 149/1000
# 75/75 - 0s - loss: 89.9370 - root_mean_squared_error: 9.4835 - val_loss: 84.7222 - val_root_mean_squared_error: 9.2045 - 371ms/epoch - 5ms/step
# Epoch 150/1000
# 75/75 - 0s - loss: 88.6487 - root_mean_squared_error: 9.4153 - val_loss: 83.8449 - val_root_mean_squared_error: 9.1567 - 361ms/epoch - 5ms/step
# Epoch 151/1000
# 75/75 - 0s - loss: 88.9421 - root_mean_squared_error: 9.4309 - val_loss: 83.6062 - val_root_mean_squared_error: 9.1436 - 409ms/epoch - 5ms/step
# Epoch 152/1000
# 75/75 - 0s - loss: 88.7745 - root_mean_squared_error: 9.4220 - val_loss: 83.5632 - val_root_mean_squared_error: 9.1413 - 378ms/epoch - 5ms/step
# Epoch 153/1000
# 75/75 - 0s - loss: 88.5033 - root_mean_squared_error: 9.4076 - val_loss: 83.3385 - val_root_mean_squared_error: 9.1290 - 279ms/epoch - 4ms/step
# Epoch 154/1000
# 75/75 - 0s - loss: 87.6821 - root_mean_squared_error: 9.3639 - val_loss: 83.1578 - val_root_mean_squared_error: 9.1191 - 427ms/epoch - 6ms/step
# Epoch 155/1000
# 75/75 - 0s - loss: 87.3004 - root_mean_squared_error: 9.3435 - val_loss: 83.6730 - val_root_mean_squared_error: 9.1473 - 315ms/epoch - 4ms/step
# Epoch 156/1000
# 75/75 - 0s - loss: 90.3279 - root_mean_squared_error: 9.5041 - val_loss: 83.4562 - val_root_mean_squared_error: 9.1354 - 299ms/epoch - 4ms/step
# Epoch 157/1000
# 75/75 - 0s - loss: 87.3610 - root_mean_squared_error: 9.3467 - val_loss: 83.6144 - val_root_mean_squared_error: 9.1441 - 256ms/epoch - 3ms/step
# Epoch 158/1000
# 75/75 - 0s - loss: 90.1628 - root_mean_squared_error: 9.4954 - val_loss: 83.4188 - val_root_mean_squared_error: 9.1334 - 256ms/epoch - 3ms/step
# Epoch 159/1000
# 75/75 - 0s - loss: 89.3189 - root_mean_squared_error: 9.4509 - val_loss: 83.3739 - val_root_mean_squared_error: 9.1309 - 242ms/epoch - 3ms/step
# Epoch 160/1000
# 75/75 - 0s - loss: 89.3134 - root_mean_squared_error: 9.4506 - val_loss: 83.1112 - val_root_mean_squared_error: 9.1165 - 276ms/epoch - 4ms/step
# Epoch 161/1000
# 75/75 - 0s - loss: 89.2462 - root_mean_squared_error: 9.4470 - val_loss: 83.0097 - val_root_mean_squared_error: 9.1110 - 250ms/epoch - 3ms/step
# Epoch 162/1000
# 75/75 - 0s - loss: 86.5000 - root_mean_squared_error: 9.3005 - val_loss: 82.7027 - val_root_mean_squared_error: 9.0941 - 285ms/epoch - 4ms/step
# Epoch 163/1000
# 75/75 - 0s - loss: 86.2936 - root_mean_squared_error: 9.2894 - val_loss: 83.3527 - val_root_mean_squared_error: 9.1298 - 307ms/epoch - 4ms/step
# Epoch 164/1000
# 75/75 - 0s - loss: 87.6986 - root_mean_squared_error: 9.3648 - val_loss: 83.0060 - val_root_mean_squared_error: 9.1108 - 266ms/epoch - 4ms/step
# Epoch 165/1000
# 75/75 - 0s - loss: 87.5613 - root_mean_squared_error: 9.3574 - val_loss: 82.6570 - val_root_mean_squared_error: 9.0916 - 278ms/epoch - 4ms/step
# Epoch 166/1000
# 75/75 - 0s - loss: 88.6381 - root_mean_squared_error: 9.4148 - val_loss: 82.6871 - val_root_mean_squared_error: 9.0932 - 315ms/epoch - 4ms/step
# Epoch 167/1000
# 75/75 - 0s - loss: 88.8094 - root_mean_squared_error: 9.4239 - val_loss: 82.5129 - val_root_mean_squared_error: 9.0837 - 312ms/epoch - 4ms/step
# Epoch 168/1000
# 75/75 - 0s - loss: 90.0862 - root_mean_squared_error: 9.4914 - val_loss: 82.7383 - val_root_mean_squared_error: 9.0961 - 317ms/epoch - 4ms/step
# Epoch 169/1000
# 75/75 - 0s - loss: 88.6074 - root_mean_squared_error: 9.4131 - val_loss: 82.2319 - val_root_mean_squared_error: 9.0682 - 411ms/epoch - 5ms/step
# Epoch 170/1000
# 75/75 - 0s - loss: 87.9317 - root_mean_squared_error: 9.3772 - val_loss: 82.8115 - val_root_mean_squared_error: 9.1001 - 349ms/epoch - 5ms/step
# Epoch 171/1000
# 75/75 - 0s - loss: 89.0502 - root_mean_squared_error: 9.4366 - val_loss: 82.1612 - val_root_mean_squared_error: 9.0643 - 317ms/epoch - 4ms/step
# Epoch 172/1000
# 75/75 - 0s - loss: 88.9967 - root_mean_squared_error: 9.4338 - val_loss: 82.4911 - val_root_mean_squared_error: 9.0825 - 294ms/epoch - 4ms/step
# Epoch 173/1000
# 75/75 - 0s - loss: 87.5447 - root_mean_squared_error: 9.3565 - val_loss: 82.8048 - val_root_mean_squared_error: 9.0997 - 314ms/epoch - 4ms/step
# Epoch 174/1000
# 75/75 - 0s - loss: 87.4627 - root_mean_squared_error: 9.3521 - val_loss: 82.2313 - val_root_mean_squared_error: 9.0682 - 321ms/epoch - 4ms/step
# Epoch 175/1000
# 75/75 - 0s - loss: 88.0096 - root_mean_squared_error: 9.3813 - val_loss: 82.4151 - val_root_mean_squared_error: 9.0783 - 329ms/epoch - 4ms/step
# Epoch 176/1000
# 75/75 - 0s - loss: 89.0678 - root_mean_squared_error: 9.4376 - val_loss: 83.0989 - val_root_mean_squared_error: 9.1159 - 309ms/epoch - 4ms/step
# Epoch 177/1000
# 75/75 - 0s - loss: 87.1633 - root_mean_squared_error: 9.3361 - val_loss: 82.1796 - val_root_mean_squared_error: 9.0653 - 335ms/epoch - 4ms/step
# Epoch 178/1000
# 75/75 - 0s - loss: 86.4799 - root_mean_squared_error: 9.2995 - val_loss: 82.5046 - val_root_mean_squared_error: 9.0832 - 321ms/epoch - 4ms/step
# Epoch 179/1000
# 75/75 - 0s - loss: 89.1206 - root_mean_squared_error: 9.4404 - val_loss: 83.8600 - val_root_mean_squared_error: 9.1575 - 285ms/epoch - 4ms/step
# Epoch 180/1000
# 75/75 - 0s - loss: 88.4108 - root_mean_squared_error: 9.4027 - val_loss: 82.7621 - val_root_mean_squared_error: 9.0974 - 314ms/epoch - 4ms/step
# Epoch 181/1000
# 75/75 - 0s - loss: 88.3951 - root_mean_squared_error: 9.4019 - val_loss: 82.2689 - val_root_mean_squared_error: 9.0702 - 285ms/epoch - 4ms/step

# %%
plot_history('root_mean_squared_error')

# %%
y_train_predicted = model.predict(x_train)
y_test_predicted = model.predict(x_test)
# Out:
# 75/75 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step

# %%
def plot_predictions(y_pred, y_true, title):
    plt.style.use('ggplot') 
    plt.scatter(y_pred, y_true, s=10, alpha=0.5)
    plt.xlabel("predicted")
    plt.ylabel("true")
    plt.title(title)
   

plot_predictions(y_train_predicted, y_train, title='Predictions on the training set')

# %%
plot_predictions(y_test_predicted, y_test, title='Predictions on the test set')

# %%
train_metrics = model.evaluate(x_train, y_train, return_dict=True)
test_metrics = model.evaluate(x_test, y_test, return_dict=True)
print('Train RMSE: {:.2f}, Test RMSE: {:.2f}'.format(train_metrics['root_mean_squared_error'], test_metrics['root_mean_squared_error']))
# Out:
# 75/75 [==============================] - 0s 2ms/step - loss: 82.2689 - root_mean_squared_error: 9.0702
# 36/36 [==============================] - 0s 2ms/step - loss: 58.7346 - root_mean_squared_error: 7.6638
# Train RMSE: 9.07, Test RMSE: 7.66

# %%
x_test
# Out:
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
# 2921             -0.6                  98.5                        1.9
# 2922              5.9                  94.0                        3.3
# 2923              4.7                  83.8                        3.2
# 2924              4.1                  85.2                        2.0
# ...               ...                   ...                        ...
# 4132              7.6                  67.2                        1.8
# 4133              9.7                  69.3                        2.4
# 4134             10.3                  69.7                        3.5
# 4135              9.8                  54.0                        1.8
# 4136             12.8                  53.6                        1.9
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2920             200.0           1031.4
# 2921             210.0           1024.0
# 2922             231.0           1013.9
# 2923             282.0           1020.7
# 2924             222.0           1030.3
# ...                ...              ...
# 4132             278.0           1019.2
# 4133             102.0           1013.1
# 4134             322.0           1015.8
# 4135             305.0           1022.5
# 4136             229.0           1015.3
#
# [1122 rows x 5 columns]

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_test_predicted, squared=False)
# Out:
# 7.663848349181191

# %%
plot_history(['root_mean_squared_error', 'val_root_mean_squared_error'])
