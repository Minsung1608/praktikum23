# %%
import pandas as pd 
df1=pd.read_csv("billwerder_schadstoffe_2012-2023.csv")
df2=pd.read_csv("billwerder_wetter_2012-2023.csv")
df=pd.merge(df1, df2, on="Messzeit")
df.loc[df['Messzeit'] == "01.01.2019"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2555             292.0           1018.3

# %%
df.loc[df['Messzeit'] == "01.01.2020"]
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2920          2921  01.01.2020               57.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2920                      34.0                        7.0          2921
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2920             200.0           1031.4

# %%
df_train = df.iloc[:2555,:]
df_val = df.iloc[2555:2920,:]
df_test = df.iloc[2920:,:]

# %%
df_val
# Out:
#       Unnamed: 0_x    Messzeit  Feinstaub (µg/m3)  Schwefeldioxid (µg/m3)  \
# 2555          2556  01.01.2019               20.0                     3.0
# 2556          2557  02.01.2019               11.0                     3.0
# 2557          2558  03.01.2019               17.0                     4.0
# 2558          2559  04.01.2019               10.0                     3.0
# 2559          2560  05.01.2019               13.0                     3.0
# ...            ...         ...                ...                     ...
# 2915          2916  27.12.2019                7.0                     3.0
# 2916          2917  28.12.2019               11.0                     3.0
# 2917          2918  29.12.2019               10.0                     3.0
# 2918          2919  30.12.2019               12.0                    20.0
# 2919          2920  31.12.2019               23.0                     3.0
#
#       Stickstoffdioxid (µg/m3)  Stickstoffmonoxid (µg/m3)  Unnamed: 0_y  \
# 2555                      11.0                        2.0          2556
# 2556                      18.0                        2.0          2557
# 2557                      56.0                       42.0          2558
# 2558                      34.0                        5.0          2559
# 2559                      19.0                        2.0          2560
# ...                        ...                        ...           ...
# 2915                      27.0                        8.0          2916
# 2916                      32.0                       23.0          2917
# 2917                      22.0                        2.0          2918
# 2918                      29.0                        2.0          2919
# 2919                      29.0                        2.0          2920
#
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2555              6.7                  77.3                        5.1
# 2556              3.4                  55.8                        4.6
# 2557              0.7                  78.9                        1.7
# 2558              4.3                  94.9                        3.1
# 2559              7.3                  95.5                        3.2
# ...               ...                   ...                        ...
# 2915              2.3                  87.3                        1.8
# 2916             -0.8                  91.1                        1.1
# 2917             -0.1                  80.0                        1.8
# 2918              7.4                  29.7                        2.5
# 2919              6.0                  83.9                        2.5
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2555             292.0           1018.3
# 2556             324.0           1028.5
# 2557             304.0           1034.7
# 2558             294.0           1028.3
# 2559             313.0           1022.1
# ...                ...              ...
# 2915              41.0           1030.3
# 2916             148.0           1040.8
# 2917             181.0           1035.6
# 2918             236.0           1025.0
# 2919             288.0           1028.2
#
# [365 rows x 12 columns]

# %%
df_train = df_train.dropna()
df_val = df_val.dropna()
df_test = df_test.dropna()

# %%
x_train = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_train = df_train['Schwefeldioxid (µg/m3)']
x_val = df_train.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_val = df_train['Schwefeldioxid (µg/m3)']
x_test = df_test.drop(columns=['Feinstaub (µg/m3)', 'Messzeit', 'Unnamed: 0_x', 'Stickstoffdioxid (µg/m3)', 'Stickstoffmonoxid (µg/m3)', 'Schwefeldioxid (µg/m3)', 'Unnamed: 0_y'])
y_test = df_test['Schwefeldioxid (µg/m3)']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_history(metrics):
    history_df = pd.DataFrame.from_dict(history.history)
    sns.lineplot(data=history_df[metrics])
    plt.xlabel("epochs")
    plt.ylabel("RMSE")

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlystopper = EarlyStopping(
    monitor='val_loss',
    patience=10
    )

# %%
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization

def create_nn():
    inputs = keras.layers.Input(shape=(x_train.shape[1],), name='input')

    layers_dense = keras.layers.BatchNormalization()(inputs)
    layers_dense = keras.layers.Dense(100, 'relu')(layers_dense)
    layers_dense = keras.layers.Dense(50, 'relu')(layers_dense)

    outputs = keras.layers.Dense(1)(layers_dense)

    return keras.Model(inputs=inputs, outputs=outputs, name="model_batchnorm")

model = create_nn()

# %%
def compile_model(model):
    model.compile(optimizer='adam',
                  loss='mse',
                  metrics=[keras.metrics.RootMeanSquaredError()])
compile_model(model)

# %%
compile_model(model)
model.summary()
# Out:
# Model: "model_batchnorm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 5)]               0
#
#  batch_normalization (BatchN  (None, 5)                20
#  ormalization)
#
#  dense (Dense)               (None, 100)               600
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 5,721
# Trainable params: 5,711
# Non-trainable params: 10
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,
                    batch_size = 32,
                    epochs = 1000,
                    validation_data=(x_val, y_val),
                    callbacks=[earlystopper],
                    verbose = 2)
# Out:
# Epoch 1/1000
# 75/75 - 1s - loss: 11.4688 - root_mean_squared_error: 3.3866 - val_loss: 13150.7549 - val_root_mean_squared_error: 114.6767 - 1s/epoch - 17ms/step
# Epoch 2/1000
# 75/75 - 0s - loss: 6.9578 - root_mean_squared_error: 2.6378 - val_loss: 1457.0609 - val_root_mean_squared_error: 38.1715 - 216ms/epoch - 3ms/step
# Epoch 3/1000
# 75/75 - 0s - loss: 6.5913 - root_mean_squared_error: 2.5673 - val_loss: 222.2481 - val_root_mean_squared_error: 14.9080 - 202ms/epoch - 3ms/step
# Epoch 4/1000
# 75/75 - 0s - loss: 6.3276 - root_mean_squared_error: 2.5155 - val_loss: 33.2880 - val_root_mean_squared_error: 5.7696 - 232ms/epoch - 3ms/step
# Epoch 5/1000
# 75/75 - 0s - loss: 6.0161 - root_mean_squared_error: 2.4528 - val_loss: 7.0940 - val_root_mean_squared_error: 2.6635 - 232ms/epoch - 3ms/step
# Epoch 6/1000
# 75/75 - 0s - loss: 5.6313 - root_mean_squared_error: 2.3730 - val_loss: 5.7745 - val_root_mean_squared_error: 2.4030 - 251ms/epoch - 3ms/step
# Epoch 7/1000
# 75/75 - 0s - loss: 5.4037 - root_mean_squared_error: 2.3246 - val_loss: 5.1411 - val_root_mean_squared_error: 2.2674 - 231ms/epoch - 3ms/step
# Epoch 8/1000
# 75/75 - 0s - loss: 5.1154 - root_mean_squared_error: 2.2617 - val_loss: 4.9345 - val_root_mean_squared_error: 2.2214 - 253ms/epoch - 3ms/step
# Epoch 9/1000
# 75/75 - 0s - loss: 4.9727 - root_mean_squared_error: 2.2300 - val_loss: 4.7829 - val_root_mean_squared_error: 2.1870 - 351ms/epoch - 5ms/step
# Epoch 10/1000
# 75/75 - 0s - loss: 4.9032 - root_mean_squared_error: 2.2143 - val_loss: 4.5134 - val_root_mean_squared_error: 2.1245 - 290ms/epoch - 4ms/step
# Epoch 11/1000
# 75/75 - 0s - loss: 4.7567 - root_mean_squared_error: 2.1810 - val_loss: 4.5280 - val_root_mean_squared_error: 2.1279 - 207ms/epoch - 3ms/step
# Epoch 12/1000
# 75/75 - 0s - loss: 4.6490 - root_mean_squared_error: 2.1562 - val_loss: 4.3024 - val_root_mean_squared_error: 2.0742 - 221ms/epoch - 3ms/step
# Epoch 13/1000
# 75/75 - 0s - loss: 4.4807 - root_mean_squared_error: 2.1168 - val_loss: 4.2209 - val_root_mean_squared_error: 2.0545 - 218ms/epoch - 3ms/step
# Epoch 14/1000
# 75/75 - 0s - loss: 4.5788 - root_mean_squared_error: 2.1398 - val_loss: 4.1527 - val_root_mean_squared_error: 2.0378 - 196ms/epoch - 3ms/step
# Epoch 15/1000
# 75/75 - 0s - loss: 4.5962 - root_mean_squared_error: 2.1439 - val_loss: 4.2218 - val_root_mean_squared_error: 2.0547 - 207ms/epoch - 3ms/step
# Epoch 16/1000
# 75/75 - 0s - loss: 4.3694 - root_mean_squared_error: 2.0903 - val_loss: 4.0567 - val_root_mean_squared_error: 2.0141 - 204ms/epoch - 3ms/step
# Epoch 17/1000
# 75/75 - 0s - loss: 4.4870 - root_mean_squared_error: 2.1183 - val_loss: 4.0086 - val_root_mean_squared_error: 2.0021 - 219ms/epoch - 3ms/step
# Epoch 18/1000
# 75/75 - 0s - loss: 4.4702 - root_mean_squared_error: 2.1143 - val_loss: 3.9661 - val_root_mean_squared_error: 1.9915 - 251ms/epoch - 3ms/step
# Epoch 19/1000
# 75/75 - 0s - loss: 4.3682 - root_mean_squared_error: 2.0900 - val_loss: 4.1165 - val_root_mean_squared_error: 2.0289 - 230ms/epoch - 3ms/step
# Epoch 20/1000
# 75/75 - 0s - loss: 4.3624 - root_mean_squared_error: 2.0886 - val_loss: 3.9860 - val_root_mean_squared_error: 1.9965 - 207ms/epoch - 3ms/step
# Epoch 21/1000
# 75/75 - 0s - loss: 4.2792 - root_mean_squared_error: 2.0686 - val_loss: 3.8757 - val_root_mean_squared_error: 1.9687 - 238ms/epoch - 3ms/step
# Epoch 22/1000
# 75/75 - 0s - loss: 4.4249 - root_mean_squared_error: 2.1035 - val_loss: 3.8760 - val_root_mean_squared_error: 1.9688 - 205ms/epoch - 3ms/step
# Epoch 23/1000
# 75/75 - 0s - loss: 4.5496 - root_mean_squared_error: 2.1330 - val_loss: 3.9123 - val_root_mean_squared_error: 1.9779 - 203ms/epoch - 3ms/step
# Epoch 24/1000
# 75/75 - 0s - loss: 4.3699 - root_mean_squared_error: 2.0904 - val_loss: 3.9333 - val_root_mean_squared_error: 1.9832 - 234ms/epoch - 3ms/step
# Epoch 25/1000
# 75/75 - 0s - loss: 4.4379 - root_mean_squared_error: 2.1066 - val_loss: 3.8648 - val_root_mean_squared_error: 1.9659 - 294ms/epoch - 4ms/step
# Epoch 26/1000
# 75/75 - 0s - loss: 4.2500 - root_mean_squared_error: 2.0616 - val_loss: 3.8921 - val_root_mean_squared_error: 1.9728 - 211ms/epoch - 3ms/step
# Epoch 27/1000
# 75/75 - 0s - loss: 4.2360 - root_mean_squared_error: 2.0582 - val_loss: 3.8295 - val_root_mean_squared_error: 1.9569 - 252ms/epoch - 3ms/step
# Epoch 28/1000
# 75/75 - 0s - loss: 4.4018 - root_mean_squared_error: 2.0980 - val_loss: 3.9855 - val_root_mean_squared_error: 1.9964 - 220ms/epoch - 3ms/step
# Epoch 29/1000
# 75/75 - 0s - loss: 4.3530 - root_mean_squared_error: 2.0864 - val_loss: 3.8181 - val_root_mean_squared_error: 1.9540 - 221ms/epoch - 3ms/step
# Epoch 30/1000
# 75/75 - 0s - loss: 4.2757 - root_mean_squared_error: 2.0678 - val_loss: 3.7781 - val_root_mean_squared_error: 1.9437 - 222ms/epoch - 3ms/step
# Epoch 31/1000
# 75/75 - 0s - loss: 4.1931 - root_mean_squared_error: 2.0477 - val_loss: 3.7781 - val_root_mean_squared_error: 1.9437 - 228ms/epoch - 3ms/step
# Epoch 32/1000
# 75/75 - 0s - loss: 4.2695 - root_mean_squared_error: 2.0663 - val_loss: 3.8086 - val_root_mean_squared_error: 1.9516 - 246ms/epoch - 3ms/step
# Epoch 33/1000
# 75/75 - 0s - loss: 4.2012 - root_mean_squared_error: 2.0497 - val_loss: 3.8439 - val_root_mean_squared_error: 1.9606 - 230ms/epoch - 3ms/step
# Epoch 34/1000
# 75/75 - 0s - loss: 4.3112 - root_mean_squared_error: 2.0763 - val_loss: 3.7983 - val_root_mean_squared_error: 1.9489 - 214ms/epoch - 3ms/step
# Epoch 35/1000
# 75/75 - 0s - loss: 4.5651 - root_mean_squared_error: 2.1366 - val_loss: 3.7923 - val_root_mean_squared_error: 1.9474 - 219ms/epoch - 3ms/step
# Epoch 36/1000
# 75/75 - 0s - loss: 4.2062 - root_mean_squared_error: 2.0509 - val_loss: 3.7995 - val_root_mean_squared_error: 1.9492 - 261ms/epoch - 3ms/step
# Epoch 37/1000
# 75/75 - 0s - loss: 4.3199 - root_mean_squared_error: 2.0784 - val_loss: 3.7422 - val_root_mean_squared_error: 1.9345 - 224ms/epoch - 3ms/step
# Epoch 38/1000
# 75/75 - 0s - loss: 4.2039 - root_mean_squared_error: 2.0504 - val_loss: 3.8707 - val_root_mean_squared_error: 1.9674 - 214ms/epoch - 3ms/step
# Epoch 39/1000
# 75/75 - 0s - loss: 4.3348 - root_mean_squared_error: 2.0820 - val_loss: 3.7206 - val_root_mean_squared_error: 1.9289 - 222ms/epoch - 3ms/step
# Epoch 40/1000
# 75/75 - 0s - loss: 4.2002 - root_mean_squared_error: 2.0494 - val_loss: 3.6892 - val_root_mean_squared_error: 1.9207 - 217ms/epoch - 3ms/step
# Epoch 41/1000
# 75/75 - 0s - loss: 4.1706 - root_mean_squared_error: 2.0422 - val_loss: 3.7040 - val_root_mean_squared_error: 1.9246 - 180ms/epoch - 2ms/step
# Epoch 42/1000
# 75/75 - 0s - loss: 4.2873 - root_mean_squared_error: 2.0706 - val_loss: 3.7226 - val_root_mean_squared_error: 1.9294 - 212ms/epoch - 3ms/step
# Epoch 43/1000
# 75/75 - 0s - loss: 4.3021 - root_mean_squared_error: 2.0742 - val_loss: 3.7606 - val_root_mean_squared_error: 1.9392 - 233ms/epoch - 3ms/step
# Epoch 44/1000
# 75/75 - 0s - loss: 4.3908 - root_mean_squared_error: 2.0954 - val_loss: 3.6420 - val_root_mean_squared_error: 1.9084 - 257ms/epoch - 3ms/step
# Epoch 45/1000
# 75/75 - 0s - loss: 4.1574 - root_mean_squared_error: 2.0390 - val_loss: 3.6625 - val_root_mean_squared_error: 1.9138 - 219ms/epoch - 3ms/step
# Epoch 46/1000
# 75/75 - 0s - loss: 4.3820 - root_mean_squared_error: 2.0933 - val_loss: 3.7006 - val_root_mean_squared_error: 1.9237 - 234ms/epoch - 3ms/step
# Epoch 47/1000
# 75/75 - 0s - loss: 4.2496 - root_mean_squared_error: 2.0614 - val_loss: 3.6279 - val_root_mean_squared_error: 1.9047 - 238ms/epoch - 3ms/step
# Epoch 48/1000
# 75/75 - 0s - loss: 4.1447 - root_mean_squared_error: 2.0358 - val_loss: 3.6499 - val_root_mean_squared_error: 1.9105 - 274ms/epoch - 4ms/step
# Epoch 49/1000
# 75/75 - 0s - loss: 4.1452 - root_mean_squared_error: 2.0360 - val_loss: 3.6175 - val_root_mean_squared_error: 1.9020 - 207ms/epoch - 3ms/step
# Epoch 50/1000
# 75/75 - 0s - loss: 4.4155 - root_mean_squared_error: 2.1013 - val_loss: 3.6392 - val_root_mean_squared_error: 1.9077 - 209ms/epoch - 3ms/step
# Epoch 51/1000
# 75/75 - 0s - loss: 4.3837 - root_mean_squared_error: 2.0937 - val_loss: 3.6443 - val_root_mean_squared_error: 1.9090 - 201ms/epoch - 3ms/step
# Epoch 52/1000
# 75/75 - 0s - loss: 4.4395 - root_mean_squared_error: 2.1070 - val_loss: 3.6632 - val_root_mean_squared_error: 1.9139 - 225ms/epoch - 3ms/step
# Epoch 53/1000
# 75/75 - 0s - loss: 4.3972 - root_mean_squared_error: 2.0970 - val_loss: 3.6528 - val_root_mean_squared_error: 1.9112 - 224ms/epoch - 3ms/step
# Epoch 54/1000
# 75/75 - 0s - loss: 4.1392 - root_mean_squared_error: 2.0345 - val_loss: 3.6351 - val_root_mean_squared_error: 1.9066 - 263ms/epoch - 4ms/step
# Epoch 55/1000
# 75/75 - 0s - loss: 4.2801 - root_mean_squared_error: 2.0688 - val_loss: 3.6204 - val_root_mean_squared_error: 1.9027 - 210ms/epoch - 3ms/step
# Epoch 56/1000
# 75/75 - 0s - loss: 4.2513 - root_mean_squared_error: 2.0619 - val_loss: 3.7047 - val_root_mean_squared_error: 1.9248 - 206ms/epoch - 3ms/step
# Epoch 57/1000
# 75/75 - 0s - loss: 4.3720 - root_mean_squared_error: 2.0909 - val_loss: 3.6407 - val_root_mean_squared_error: 1.9081 - 231ms/epoch - 3ms/step
# Epoch 58/1000
# 75/75 - 0s - loss: 4.3463 - root_mean_squared_error: 2.0848 - val_loss: 3.8295 - val_root_mean_squared_error: 1.9569 - 245ms/epoch - 3ms/step
# Epoch 59/1000
# 75/75 - 0s - loss: 4.3385 - root_mean_squared_error: 2.0829 - val_loss: 3.6186 - val_root_mean_squared_error: 1.9023 - 190ms/epoch - 3ms/step

# %%
plot_history('root_mean_squared_error')

# %%
y_train_predicted = model.predict(x_train)
y_test_predicted = model.predict(x_test)
# Out:
# 75/75 [==============================] - 0s 1ms/step
# 36/36 [==============================] - 0s 1ms/step

# %%
def plot_predictions(y_pred, y_true, title):
    plt.style.use('ggplot') 
    plt.scatter(y_pred, y_true, s=10, alpha=0.5)
    plt.xlabel("predicted")
    plt.ylabel("true")
    plt.title(title)
   

plot_predictions(y_train_predicted, y_train, title='Predictions on the training set')

# %%
plot_predictions(y_test_predicted, y_test, title='Predictions on the test set')

# %%
train_metrics = model.evaluate(x_train, y_train, return_dict=True)
test_metrics = model.evaluate(x_test, y_test, return_dict=True)
print('Train RMSE: {:.2f}, Test RMSE: {:.2f}'.format(train_metrics['root_mean_squared_error'], test_metrics['root_mean_squared_error']))
# Out:
# 75/75 [==============================] - 0s 2ms/step - loss: 3.6186 - root_mean_squared_error: 1.9023
# 36/36 [==============================] - 0s 2ms/step - loss: 2.7687 - root_mean_squared_error: 1.6640
# Train RMSE: 1.90, Test RMSE: 1.66

# %%
x_test
# Out:
#       Temperatur (°C)  rel. Luftfeuchte (%)  Windgeschwindigkeit (m/s)  \
# 2920              0.6                  95.7                        1.1
# 2921             -0.6                  98.5                        1.9
# 2922              5.9                  94.0                        3.3
# 2923              4.7                  83.8                        3.2
# 2924              4.1                  85.2                        2.0
# ...               ...                   ...                        ...
# 4132              7.6                  67.2                        1.8
# 4133              9.7                  69.3                        2.4
# 4134             10.3                  69.7                        3.5
# 4135              9.8                  54.0                        1.8
# 4136             12.8                  53.6                        1.9
#
#       Windrichtung (°)  Luftdruck (hPa)
# 2920             200.0           1031.4
# 2921             210.0           1024.0
# 2922             231.0           1013.9
# 2923             282.0           1020.7
# 2924             222.0           1030.3
# ...                ...              ...
# 4132             278.0           1019.2
# 4133             102.0           1013.1
# 4134             322.0           1015.8
# 4135             305.0           1022.5
# 4136             229.0           1015.3
#
# [1122 rows x 5 columns]

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_test_predicted, squared=False)
# Out:
# 1.663954955491914

# %%
plot_history(['root_mean_squared_error', 'val_root_mean_squared_error'])
